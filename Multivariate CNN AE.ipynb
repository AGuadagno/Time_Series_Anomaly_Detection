# %%
# Importing libraries

import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import itertools as it
import matplotlib.pyplot as plt

from datetime import datetime
from scipy.stats import multivariate_normal
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

plt.rc('font', size=16)

import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers

# Setting random seed for reproducibility

seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# 2022-08-29 09:23:23.614402: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Opening the dataframe
ABB_data = pd.read_csv('../input/electricity-demand/Multivariate_Labeled_2.csv', parse_dates=['DateTime'], delimiter=',')
ABB_data.drop(columns="DateTime", inplace=True)
ABB_data
# Out:
#        CB_First_Floor  CB_Second_Floor   AvgT   AvgH  Anomaly_Label    Year  \
# 0                37.0             36.0   4.70  80.40            0.0  2017.0
# 1                32.0             33.0   4.75  79.35            0.0  2017.0
# 2                32.0             32.0   4.60  78.90            0.0  2017.0
# 3                32.0             33.0   4.50  79.25            0.0  2017.0
# 4                33.0             33.0   4.40  80.40            0.0  2017.0
# ...               ...              ...    ...    ...            ...     ...
# 75835            41.0             41.0  10.95  83.25            0.0  2019.0
# 75836            42.0             42.0  10.80  84.60            0.0  2019.0
# 75837            43.0             43.0  10.65  86.05            0.0  2019.0
# 75838            42.0             42.0  10.30  86.90            0.0  2019.0
# 75839            42.0             42.0   9.95  87.80            0.0  2019.0
#
#        Month  Day  Hour   Min  Sec  Day_Of_The_Week
# 0        2.0  9.0   0.0   0.0  0.0              3.0
# 1        2.0  9.0   0.0  15.0  0.0              3.0
# 2        2.0  9.0   0.0  30.0  0.0              3.0
# 3        2.0  9.0   0.0  45.0  0.0              3.0
# 4        2.0  9.0   1.0   0.0  0.0              3.0
# ...      ...  ...   ...   ...  ...              ...
# 75835    4.0  9.0  22.0  45.0  0.0              1.0
# 75836    4.0  9.0  23.0   0.0  0.0              1.0
# 75837    4.0  9.0  23.0  15.0  0.0              1.0
# 75838    4.0  9.0  23.0  30.0  0.0              1.0
# 75839    4.0  9.0  23.0  45.0  0.0              1.0
#
# [75840 rows x 12 columns]

# %%
# Dataframe preprocessing

# Converting data types
ABB_data['CB_First_Floor'] = ABB_data['CB_First_Floor'].astype(np.float32)
ABB_data['CB_Second_Floor'] = ABB_data['CB_Second_Floor'].astype(np.float32)
ABB_data['AvgT'] = ABB_data['AvgT'].astype(np.float32)
ABB_data['AvgH'] = ABB_data['AvgH'].astype(np.float32)
ABB_data['Anomaly_Label'] = ABB_data['Anomaly_Label'].astype(np.float32)
ABB_data['Year'] = ABB_data['Year'].astype(np.float32)
ABB_data['Month'] = ABB_data['Month'].astype(np.float32)
ABB_data['Day'] = ABB_data['Day'].astype(np.float32)
ABB_data['Hour'] = ABB_data['Hour'].astype(np.float32)
ABB_data['Min'] = ABB_data['Min'].astype(np.float32)
ABB_data['Sec'] = ABB_data['Sec'].astype(np.float32)
ABB_data['Day_Of_The_Week'] = ABB_data['Day_Of_The_Week'].astype(np.float32)

# Printing the dataframe's info
ABB_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75840 entries, 0 to 75839
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CB_First_Floor   75840 non-null  float32
#  1   CB_Second_Floor  75840 non-null  float32
#  2   AvgT             75840 non-null  float32
#  3   AvgH             75840 non-null  float32
#  4   Anomaly_Label    75840 non-null  float32
#  5   Year             75840 non-null  float32
#  6   Month            75840 non-null  float32
#  7   Day              75840 non-null  float32
#  8   Hour             75840 non-null  float32
#  9   Min              75840 non-null  float32
#  10  Sec              75840 non-null  float32
#  11  Day_Of_The_Week  75840 non-null  float32
# dtypes: float32(12)
# memory usage: 3.5 MB

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(15,10))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
    
# Plotting time series
inspect_dataframe(ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week"]], ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week"]].columns)

# %%
# Columns used for the following split in train, test and validation sets
ABB_data['Test'] = 0
ABB_data['Validation'] = 0
ABB_data['Train_P1'] = 0
ABB_data['Train_P2'] = 0

# %%
# TEST SET

# Some random weeks
week = [89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112]
for j in week:
    Slice_Multivariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Test'] = 1

# %%
# VALIDATION SET

# Some random weeks
week = [55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78]
for j in week:
    Slice_Multivariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Validation'] = 1

# %%
# TRAINING SET

week = [x for x in np.arange(0, 55, 1)]
for j in week:
    Slice_Univariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Train_P1'] = 1
    
week = [x for x in np.arange(79, 89, 1)]
for j in week:
    Slice_Univariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Train_P2'] = 1

# %%
# Plotting time series
inspect_dataframe(ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week", "Train_P1", "Train_P2", "Validation", "Test"]], ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week", "Train_P1", "Train_P2", "Validation", "Test"]].columns)

# %%
# TRAIN, TEST, VALIDATION SETS
X_train_temp_P1 = ABB_data[ABB_data['Train_P1']==1].copy()
X_train_temp_P2 = ABB_data[ABB_data['Train_P2']==1].copy()
X_validation_temp = ABB_data[ABB_data['Validation']==1].copy()
X_test_temp = ABB_data[ABB_data['Test']==1].copy()

# %%
# Training, Validation and Test set - Anomalies (not used for training)
Anomaly_Train_P1 = X_train_temp_P1[['Anomaly_Label']]
Anomaly_Train_P2 = X_train_temp_P2[['Anomaly_Label']]
Anomaly_Validation = X_validation_temp[['Anomaly_Label']]
Anomaly_Test = X_test_temp[['Anomaly_Label']]

# %%
X_train_temp_global = pd.concat([X_train_temp_P1,X_train_temp_P2],axis=0)
X_train_temp_global.shape
# Out:
# (43680, 16)

# %%
# STANDARDIZATION

mean = X_train_temp_global.mean()
std_dev = X_train_temp_global.std()
print(mean, std_dev)

X_train_raw_P1 = (X_train_temp_P1-mean)/std_dev
X_train_raw_P2 = (X_train_temp_P2-mean)/std_dev
X_validation_raw = (X_validation_temp-mean)/std_dev
X_test_raw = (X_test_temp-mean)/std_dev

print(X_test_raw.shape[0]+X_validation_raw.shape[0]+X_train_raw_P1.shape[0]+X_train_raw_P2.shape[0] == ABB_data.shape[0])
# Out:
# CB_First_Floor       56.138874
# CB_Second_Floor      55.814743
# AvgT                 14.077893
# AvgH                 71.934387
# Anomaly_Label         0.000000
# Year               2017.283569
# Month                 6.725275
# Day                  15.931869
# Hour                 11.500000
# Min                  22.500000
# Sec                   0.000000
# Day_Of_The_Week       3.000000
# Test                  0.000000
# Validation            0.000000
# Train_P1              0.846154
# Train_P2              0.153846
# dtype: float64 CB_First_Floor     19.434896
# CB_Second_Floor    19.353765
# AvgT                8.412517
# AvgH               19.357885
# Anomaly_Label       0.000000
# Year                0.450710
# Month               3.393199
# Day                 8.644081
# Hour                6.922266
# Min                16.770702
# Sec                 0.000000
# Day_Of_The_Week     2.000023
# Test                0.000000
# Validation          0.000000
# Train_P1            0.360805
# Train_P2            0.360805
# dtype: float64
# True

# %%
# Anomalies are not considered during the training
X_train_raw_P1 = X_train_raw_P1[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_train_raw_P2 = X_train_raw_P2[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_validation_raw = X_validation_raw[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_test_raw = X_test_raw[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_train_raw_P1.shape, X_train_raw_P2.shape, X_validation_raw.shape, X_test_raw.shape
# Out:
# ((36960, 3), (6720, 3), (16128, 3), (16032, 3))

# %%
# Plotting time series
inspect_dataframe(X_test_raw, X_test_raw.columns)

# %% [markdown]
# ## Training Preparation

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Training parameters

window = 672       # 1 week
stride = 8         # 1 hour
latent_dim = 4     # Latent dimension
epochs = 300       # Number of epochs (no early stopping)
batch_size = 8     # Batch size
f = 3              # Filters' dimensions

# %%
# Function used to create (overlapped) windows that we will use for the training
def build_sequences(df, anomaly, window=window, stride=stride):
    
    assert len(df) > window
    dataset = []
    anomalies = []
    temp_df = df.copy().values
    temp_an = anomaly.copy().values
    padding_len = (len(df)-window)%stride # Padding computed considering the stride
    print("PADDING: " + str(padding_len)) #DEBUG

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float32')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_an.shape[1]), dtype='float32')
        temp_an = np.concatenate((padding,temp_an))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window+1,stride):
        dataset.append(temp_df[idx:idx+window])
        anomalies.append(temp_an[idx:idx+window])

    dataset = np.array(dataset)
    anomalies = np.array(anomalies)
    return dataset, anomalies

# %%
X_train_P1, A_train_P1 = build_sequences(X_train_raw_P1, Anomaly_Train_P1, window=window, stride=stride)
X_train_P2, A_train_P2 = build_sequences(X_train_raw_P2, Anomaly_Train_P2, window=window, stride=stride)
X_val, A_val = build_sequences(X_validation_raw, Anomaly_Validation, window=window, stride=stride)
X_train_P1.shape,X_train_P2.shape
# Out:
# PADDING: 0
# PADDING: 0
# PADDING: 0
# ((4537, 672, 3), (757, 672, 3))

# %%
# Temp test set - plotting purposes
X_test, A_test = build_sequences(X_test_raw, Anomaly_Test, window=window, stride=stride)
# Out:
# PADDING: 0

# %%
X_train = np.concatenate([X_train_P1,X_train_P2],axis=0)
A_train = np.concatenate([A_train_P1,A_train_P2],axis=0)
X_train.shape, A_train.shape
# Out:
# ((5294, 672, 3), (5294, 672, 1))

# %%
# Building the model

input_shape = X_train.shape[1:]
output_shape = X_train.shape[1:]

#Encoder
encoder_input = tf.keras.Input(shape=input_shape)

x = tfkl.Conv1D(16, f, activation="relu", strides=1, padding="same")(encoder_input)
x = tfkl.MaxPool1D(pool_size=2, strides=2)(x)
x = tfkl.Conv1D(32, f, activation="relu", strides=1, padding="same")(x)
x = tfkl.MaxPool1D(pool_size=2, strides=2)(x)

x = tfkl.Flatten()(x)
x = tfkl.Dense(latent_dim, activation='linear')(x)

#Decoder
x = tfkl.Dense(units=84*X_train.shape[2])(x)
x = tfkl.Reshape((84,X_train.shape[2]))(x)
x = tfkl.Conv1DTranspose(32,f,2, padding='same', activation='relu')(x)
x = tfkl.Conv1DTranspose(16,f,2, padding='same', activation='relu')(x)
decoder_output = tfkl.Conv1DTranspose(X_train.shape[2],f,2, padding='same', activation='linear')(x)

#Model
autoencoder = tfk.Model(inputs=encoder_input, outputs=decoder_output, name='Autoencoder')
autoencoder.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=[tfk.metrics.MeanSquaredError()])
autoencoder.summary()
# Out:
# Model: "Autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 672, 3)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 672, 16)           160
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 336, 16)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 336, 32)           1568
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 168, 32)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 5376)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 21508
# _________________________________________________________________
# dense_1 (Dense)              (None, 252)               1260
# _________________________________________________________________
# reshape (Reshape)            (None, 84, 3)             0
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 168, 32)           320
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 336, 16)           1552
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 672, 3)            147
# =================================================================
# Total params: 26,515
# Trainable params: 26,515
# Non-trainable params: 0
# _________________________________________________________________

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Training
history = autoencoder.fit(
    X_train,
    X_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data = (X_val,X_val),
    callbacks=[
        tfk.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-5),
    ]
).history
# Out:
# 2022-08-29 09:23:28.108702: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/300
# 662/662 [==============================] - 11s 15ms/step - loss: 0.5971 - mean_squared_error: 0.5971 - val_loss: 0.4389 - val_mean_squared_error: 0.4389
# Epoch 2/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.4168 - mean_squared_error: 0.4168 - val_loss: 0.3471 - val_mean_squared_error: 0.3471
# Epoch 3/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.3745 - mean_squared_error: 0.3745 - val_loss: 0.3180 - val_mean_squared_error: 0.3180
# Epoch 4/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.3417 - mean_squared_error: 0.3417 - val_loss: 0.2743 - val_mean_squared_error: 0.2743
# Epoch 5/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.2573 - mean_squared_error: 0.2573 - val_loss: 0.1791 - val_mean_squared_error: 0.1791
# Epoch 6/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1997 - mean_squared_error: 0.1997 - val_loss: 0.1517 - val_mean_squared_error: 0.1517
# Epoch 7/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1818 - mean_squared_error: 0.1818 - val_loss: 0.1399 - val_mean_squared_error: 0.1399
# Epoch 8/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1717 - mean_squared_error: 0.1717 - val_loss: 0.1319 - val_mean_squared_error: 0.1319
# Epoch 9/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1633 - mean_squared_error: 0.1633 - val_loss: 0.1236 - val_mean_squared_error: 0.1236
# Epoch 10/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1576 - mean_squared_error: 0.1576 - val_loss: 0.1205 - val_mean_squared_error: 0.1205
# Epoch 11/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1541 - mean_squared_error: 0.1541 - val_loss: 0.1215 - val_mean_squared_error: 0.1215
# Epoch 12/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1499 - mean_squared_error: 0.1499 - val_loss: 0.1180 - val_mean_squared_error: 0.1180
# Epoch 13/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1466 - mean_squared_error: 0.1466 - val_loss: 0.1123 - val_mean_squared_error: 0.1123
# Epoch 14/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1436 - mean_squared_error: 0.1436 - val_loss: 0.1147 - val_mean_squared_error: 0.1147
# Epoch 15/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1403 - mean_squared_error: 0.1403 - val_loss: 0.1077 - val_mean_squared_error: 0.1077
# Epoch 16/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1387 - mean_squared_error: 0.1387 - val_loss: 0.1071 - val_mean_squared_error: 0.1071
# Epoch 17/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1373 - mean_squared_error: 0.1373 - val_loss: 0.1055 - val_mean_squared_error: 0.1055
# Epoch 18/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1353 - mean_squared_error: 0.1353 - val_loss: 0.1027 - val_mean_squared_error: 0.1027
# Epoch 19/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1332 - mean_squared_error: 0.1332 - val_loss: 0.1022 - val_mean_squared_error: 0.1022
# Epoch 20/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1326 - mean_squared_error: 0.1326 - val_loss: 0.1062 - val_mean_squared_error: 0.1062
# Epoch 21/300
# 662/662 [==============================] - 10s 14ms/step - loss: 0.1311 - mean_squared_error: 0.1311 - val_loss: 0.1016 - val_mean_squared_error: 0.1016
# Epoch 22/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1300 - mean_squared_error: 0.1300 - val_loss: 0.1022 - val_mean_squared_error: 0.1022
# Epoch 23/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1281 - mean_squared_error: 0.1281 - val_loss: 0.1001 - val_mean_squared_error: 0.1001
# Epoch 24/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1279 - mean_squared_error: 0.1279 - val_loss: 0.0973 - val_mean_squared_error: 0.0973
# Epoch 25/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1264 - mean_squared_error: 0.1264 - val_loss: 0.0938 - val_mean_squared_error: 0.0938
# Epoch 26/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1255 - mean_squared_error: 0.1255 - val_loss: 0.0941 - val_mean_squared_error: 0.0941
# Epoch 27/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1247 - mean_squared_error: 0.1247 - val_loss: 0.0919 - val_mean_squared_error: 0.0919
# Epoch 28/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1243 - mean_squared_error: 0.1243 - val_loss: 0.0961 - val_mean_squared_error: 0.0961
# Epoch 29/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1233 - mean_squared_error: 0.1233 - val_loss: 0.0981 - val_mean_squared_error: 0.0981
# Epoch 30/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1224 - mean_squared_error: 0.1224 - val_loss: 0.0908 - val_mean_squared_error: 0.0908
# Epoch 31/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1219 - mean_squared_error: 0.1219 - val_loss: 0.0928 - val_mean_squared_error: 0.0928
# Epoch 32/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1210 - mean_squared_error: 0.1210 - val_loss: 0.0913 - val_mean_squared_error: 0.0913
# Epoch 33/300
# 662/662 [==============================] - 10s 14ms/step - loss: 0.1209 - mean_squared_error: 0.1209 - val_loss: 0.0920 - val_mean_squared_error: 0.0920
# Epoch 34/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1200 - mean_squared_error: 0.1200 - val_loss: 0.0905 - val_mean_squared_error: 0.0905
# Epoch 35/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1186 - mean_squared_error: 0.1186 - val_loss: 0.0890 - val_mean_squared_error: 0.0890
# Epoch 36/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1187 - mean_squared_error: 0.1187 - val_loss: 0.0905 - val_mean_squared_error: 0.0905
# Epoch 37/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1184 - mean_squared_error: 0.1184 - val_loss: 0.0884 - val_mean_squared_error: 0.0884
# Epoch 38/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1174 - mean_squared_error: 0.1174 - val_loss: 0.0883 - val_mean_squared_error: 0.0883
# Epoch 39/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1174 - mean_squared_error: 0.1174 - val_loss: 0.0885 - val_mean_squared_error: 0.0885
# Epoch 40/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1170 - mean_squared_error: 0.1170 - val_loss: 0.0862 - val_mean_squared_error: 0.0862
# Epoch 41/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1165 - mean_squared_error: 0.1165 - val_loss: 0.0883 - val_mean_squared_error: 0.0883
# Epoch 42/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1157 - mean_squared_error: 0.1157 - val_loss: 0.0880 - val_mean_squared_error: 0.0880
# Epoch 43/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1155 - mean_squared_error: 0.1155 - val_loss: 0.0862 - val_mean_squared_error: 0.0862
# Epoch 44/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1154 - mean_squared_error: 0.1154 - val_loss: 0.0850 - val_mean_squared_error: 0.0850
# Epoch 45/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1148 - mean_squared_error: 0.1148 - val_loss: 0.0865 - val_mean_squared_error: 0.0865
# Epoch 46/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1145 - mean_squared_error: 0.1145 - val_loss: 0.0847 - val_mean_squared_error: 0.0847
# Epoch 47/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1147 - mean_squared_error: 0.1147 - val_loss: 0.0830 - val_mean_squared_error: 0.0830
# Epoch 48/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1137 - mean_squared_error: 0.1137 - val_loss: 0.0834 - val_mean_squared_error: 0.0834
# Epoch 49/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1132 - mean_squared_error: 0.1132 - val_loss: 0.0859 - val_mean_squared_error: 0.0859
# Epoch 50/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1132 - mean_squared_error: 0.1132 - val_loss: 0.0858 - val_mean_squared_error: 0.0858
# Epoch 51/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1124 - mean_squared_error: 0.1124 - val_loss: 0.0852 - val_mean_squared_error: 0.0852
# Epoch 52/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1124 - mean_squared_error: 0.1124 - val_loss: 0.0821 - val_mean_squared_error: 0.0821
# Epoch 53/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1124 - mean_squared_error: 0.1124 - val_loss: 0.0836 - val_mean_squared_error: 0.0836
# Epoch 54/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1121 - mean_squared_error: 0.1121 - val_loss: 0.0822 - val_mean_squared_error: 0.0822
# Epoch 55/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1115 - mean_squared_error: 0.1115 - val_loss: 0.0836 - val_mean_squared_error: 0.0836
# Epoch 56/300
# 662/662 [==============================] - 10s 14ms/step - loss: 0.1112 - mean_squared_error: 0.1112 - val_loss: 0.0824 - val_mean_squared_error: 0.0824
# Epoch 57/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 0.0822 - val_mean_squared_error: 0.0822
# Epoch 58/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1070 - mean_squared_error: 0.1070 - val_loss: 0.0780 - val_mean_squared_error: 0.0780
# Epoch 59/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1067 - mean_squared_error: 0.1067 - val_loss: 0.0813 - val_mean_squared_error: 0.0813
# Epoch 60/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1067 - mean_squared_error: 0.1067 - val_loss: 0.0786 - val_mean_squared_error: 0.0786
# Epoch 61/300
# 662/662 [==============================] - 10s 14ms/step - loss: 0.1064 - mean_squared_error: 0.1064 - val_loss: 0.0785 - val_mean_squared_error: 0.0785
# Epoch 62/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1066 - mean_squared_error: 0.1066 - val_loss: 0.0793 - val_mean_squared_error: 0.0793
# Epoch 63/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1062 - mean_squared_error: 0.1062 - val_loss: 0.0779 - val_mean_squared_error: 0.0779
# Epoch 64/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1043 - mean_squared_error: 0.1043 - val_loss: 0.0784 - val_mean_squared_error: 0.0784
# Epoch 65/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1043 - mean_squared_error: 0.1043 - val_loss: 0.0771 - val_mean_squared_error: 0.0771
# Epoch 66/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1042 - mean_squared_error: 0.1042 - val_loss: 0.0767 - val_mean_squared_error: 0.0767
# Epoch 67/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1042 - mean_squared_error: 0.1042 - val_loss: 0.0766 - val_mean_squared_error: 0.0766
# Epoch 68/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1041 - mean_squared_error: 0.1041 - val_loss: 0.0777 - val_mean_squared_error: 0.0777
# Epoch 69/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1041 - mean_squared_error: 0.1041 - val_loss: 0.0757 - val_mean_squared_error: 0.0757
# Epoch 70/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1039 - mean_squared_error: 0.1039 - val_loss: 0.0764 - val_mean_squared_error: 0.0764
# Epoch 71/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1038 - mean_squared_error: 0.1038 - val_loss: 0.0772 - val_mean_squared_error: 0.0772
# Epoch 72/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1039 - mean_squared_error: 0.1039 - val_loss: 0.0760 - val_mean_squared_error: 0.0760
# Epoch 73/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1037 - mean_squared_error: 0.1037 - val_loss: 0.0771 - val_mean_squared_error: 0.0771
# Epoch 74/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1036 - mean_squared_error: 0.1036 - val_loss: 0.0770 - val_mean_squared_error: 0.0770
# Epoch 75/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1027 - mean_squared_error: 0.1027 - val_loss: 0.0755 - val_mean_squared_error: 0.0755
# Epoch 76/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1026 - mean_squared_error: 0.1026 - val_loss: 0.0747 - val_mean_squared_error: 0.0747
# Epoch 77/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1026 - mean_squared_error: 0.1026 - val_loss: 0.0750 - val_mean_squared_error: 0.0750
# Epoch 78/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1026 - mean_squared_error: 0.1026 - val_loss: 0.0771 - val_mean_squared_error: 0.0771
# Epoch 79/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1025 - mean_squared_error: 0.1025 - val_loss: 0.0751 - val_mean_squared_error: 0.0751
# Epoch 80/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1025 - mean_squared_error: 0.1025 - val_loss: 0.0756 - val_mean_squared_error: 0.0756
# Epoch 81/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1025 - mean_squared_error: 0.1025 - val_loss: 0.0754 - val_mean_squared_error: 0.0754
# Epoch 82/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1020 - mean_squared_error: 0.1020 - val_loss: 0.0754 - val_mean_squared_error: 0.0754
# Epoch 83/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1019 - mean_squared_error: 0.1019 - val_loss: 0.0754 - val_mean_squared_error: 0.0754
# Epoch 84/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1019 - mean_squared_error: 0.1019 - val_loss: 0.0749 - val_mean_squared_error: 0.0749
# Epoch 85/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1019 - mean_squared_error: 0.1019 - val_loss: 0.0749 - val_mean_squared_error: 0.0749
# Epoch 86/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1019 - mean_squared_error: 0.1019 - val_loss: 0.0751 - val_mean_squared_error: 0.0751
# Epoch 87/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1016 - mean_squared_error: 0.1016 - val_loss: 0.0744 - val_mean_squared_error: 0.0744
# Epoch 88/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1016 - mean_squared_error: 0.1016 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 89/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1016 - mean_squared_error: 0.1016 - val_loss: 0.0752 - val_mean_squared_error: 0.0752
# Epoch 90/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1016 - mean_squared_error: 0.1016 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 91/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1016 - mean_squared_error: 0.1016 - val_loss: 0.0748 - val_mean_squared_error: 0.0748
# Epoch 92/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1015 - mean_squared_error: 0.1015 - val_loss: 0.0750 - val_mean_squared_error: 0.0750
# Epoch 93/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 94/300
# 662/662 [==============================] - 10s 14ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 95/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 96/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 97/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0743 - val_mean_squared_error: 0.0743
# Epoch 98/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 99/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 100/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0743 - val_mean_squared_error: 0.0743
# Epoch 101/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 102/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1014 - mean_squared_error: 0.1014 - val_loss: 0.0749 - val_mean_squared_error: 0.0749
# Epoch 103/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0744 - val_mean_squared_error: 0.0744
# Epoch 104/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0744 - val_mean_squared_error: 0.0744
# Epoch 105/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0744 - val_mean_squared_error: 0.0744
# Epoch 106/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0744 - val_mean_squared_error: 0.0744
# Epoch 107/300
# 662/662 [==============================] - 9s 13ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 108/300
# 662/662 [==============================] - 10s 15ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 109/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0746 - val_mean_squared_error: 0.0746
# Epoch 110/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0748 - val_mean_squared_error: 0.0748
# Epoch 111/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0745 - val_mean_squared_error: 0.0745
# Epoch 112/300
# 662/662 [==============================] - 9s 14ms/step - loss: 0.1013 - mean_squared_error: 0.1013 - val_loss: 0.0744 - val_mean_squared_error: 0.0744

# %% [markdown]
# ## Example of prediction on the test set

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(30,20))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()

# %%
# Example of prediction on the test set
i = 1
j = i+1
Univariate_print = X_test_raw.iloc[i*672:j*672].copy()
X = np.expand_dims(Univariate_print, axis=0)
prediction = autoencoder.predict(X)
prediction.shape
# Out:
# (1, 672, 3)

# %%
# Adding anomalies to the plot (not used during training)
anomaly = X_test_temp['Anomaly_Label'].iloc[i*672:j*672].copy()

# %%
# Function to plot expected values and predicted values
target_labels = X_test_raw.columns

def inspect_multivariate_prediction(X, y, a, pred, columns): 
   
    figs, axs = plt.subplots(4, 1, sharex=True, figsize=(15,10)) 
    for i, col in enumerate(columns[:4]): 
        axs[i].plot(np.arange(len(X[0,:,i])), X[0,:,i]) 
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])*2), y[0,:,i], color='orange') 
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])*2), pred[0,:,i], color='green') 
        axs[i].set_title(col) 
            
    axs[3].plot(np.arange(len(X[0,:,i])), a) 
    axs[3].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])*2), a) 
    axs[3].set_title('Anomaly') 
    plt.show()
    
# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly, prediction, target_labels)

# %% [markdown]
# ## Computing reconstruction error

# %%
# Function used to create non-overlapped windows starting from the TRAINING set
def build_sequences_reconstruction(df, window, stride):
    dataset = []
    temp_df = df.copy().values
    padding_len = (len(df)-window)%stride

    for idx in np.arange(0,len(temp_df)-window+1,stride):
        dataset.append(temp_df[idx:idx+window])

    dataset = np.array(dataset)
    return dataset

# %%
# Non overlapped windows - Training set
X_train_non_overlapped_P1 = build_sequences_reconstruction(X_train_raw_P1, window=window, stride=window)
X_train_non_overlapped_P2 = build_sequences_reconstruction(X_train_raw_P2, window=window, stride=window)

X_train_non_overlapped = np.concatenate([X_train_non_overlapped_P1,X_train_non_overlapped_P2],axis=0)

X_train_non_overlapped.shape
# Out:
# (65, 672, 3)

# %%
X_test_overlapped = build_sequences_reconstruction(X_test_raw, window=window, stride=stride)

X_test_overlapped.shape
# Out:
# (1921, 672, 3)

# %%
# Making predictions on non-overlapped windows of the training set
train_reconstructions = autoencoder.predict(X_train_non_overlapped)
train_reconstructions.shape
# Out:
# (65, 672, 3)

# %%
# Making predictions on overlapped windows of the test set
test_reconstructions = autoencoder.predict(X_test_overlapped)
test_reconstructions.shape
# Out:
# (1921, 672, 3)

# %%
# Computing reconstruction error - Test set (redundant data because of overlapping)
rec_error = np.abs(X_test_overlapped-test_reconstructions) # || True - Predicted ||
rec_error.shape
# Out:
# (1921, 672, 3)

# %%
# Function used to plot predictions (reconstructions) made on training data using the model
def inspect_multivariate_prediction_reconstruction(X, y, a, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(pred))
        print('Plotting sequence number: ' + str(idx))

    figs, axs = plt.subplots(4, 1, sharex=True, figsize=(17,10))
    for i, col in enumerate(columns[:4]):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
    plt.show()

# %%
# Plotting reconstructions
inspect_multivariate_prediction_reconstruction(X_train_non_overlapped, X_train_non_overlapped, A_train, train_reconstructions, target_labels, window)
# Out:
# Plotting sequence number: 51

# %%
# Array that will contain reconstruction errors (floor by floor) - TRAINING SET
reconstruction_errors = np.empty(shape=(0, 2))

# Computing reconstruction errors
for i in range(X_train_non_overlapped.shape[0]):
    error = np.abs(X_train_non_overlapped[i]-train_reconstructions[i])
    error = error[:,:2] # Not interested in the day of the week
    reconstruction_errors = np.concatenate((reconstruction_errors,error), axis=0)
    
mean_error = np.mean(reconstruction_errors, axis = 0) # Mean reconstruction error
std_error = np.std(reconstruction_errors, axis = 0) # Std dev of the reconstruction error
max_error = np.max(reconstruction_errors, axis = 0) # Max error on the training set
  
print(reconstruction_errors.shape)
print(mean_error)
print(std_error)
print(max_error)
# Out:
# (43680, 2)
# [0.25970609 0.25982645]
# [0.23492546 0.23407676]
# [2.25457166 2.28510267]

# %%
# Array that will contain reconstruction errors (floor by floor) - TEST SET

reconstruction_test = np.empty(shape=(0, 2)) # Predictions made on the test set using the model
reconstruction_errors_test = np.empty(shape=(0, 2)) # Errors made in predicting the test set

# First window
i = 0
error = np.abs(X_test_overlapped[i]-test_reconstructions[i])
error = error[:,:2] # Not interested in the day of the week
reconstruction_errors_test = np.concatenate((reconstruction_errors_test,error), axis=0)
reconstruction_test = np.concatenate((reconstruction_test, test_reconstructions[i,:,:2]), axis=0)
print(reconstruction_errors_test.shape)
print(reconstruction_test.shape)

# For all the windows following the first one we need to consider only the last "stride" elements
for i in range(1,X_test_overlapped.shape[0]):
    error = np.abs(X_test_overlapped[i,-stride:,:]-test_reconstructions[i,-stride:,:])
    error = error[:,:2] # Not interested in the day of the week
    reconstruction_errors_test = np.concatenate((reconstruction_errors_test,error), axis=0)
    reconstruction_test = np.concatenate((reconstruction_test, test_reconstructions[i,-stride:,:2]), axis=0)
                                        
print(reconstruction_errors_test.shape)
print(reconstruction_test.shape)
# Out:
# (672, 2)
# (672, 2)
# (16032, 2)
# (16032, 2)

# %%
# Function used to predict anomalies
def predict_anomalies(reconstruction_errors, error_threshold):
    
    # Inizially we don't have predicted anomalies
    anomaly_predicted = np.zeros(shape=(X_test_raw.shape[0]))
    
    # First window
    i = 0 # We start from element 0 of the test set
    seq = reconstruction_errors[0] # We start from the first window of the test set 
    for sample in seq: 
        epsilon = sample[:2] - error_threshold # We check if the reconstruction error is greater than the threshold
        if any(x>0 for x in epsilon) == True:
            anomaly_predicted[i] = 1
        i = i+1
            
    # Sequences following the first one
    for s in range(1, reconstruction_errors.shape[0]):
        for k in range (reconstruction_errors.shape[1]-stride, reconstruction_errors.shape[1]): # k in [672-stride, 672]         
            epsilon = reconstruction_errors[s,k,:2] - error_threshold # We check if the reconstruction error is greater than the threshold
            if any(x>0 for x in epsilon) == True:
                anomaly_predicted[i] = 1
            i = i+1 

    return anomaly_predicted

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Grid search threshold parameters

range_of_val = [x for x in np.arange(3, 8, 0.1)]
best_val = [0,0]
F1_MAX = 0

for i in range_of_val:
    for j in range_of_val:
        threshold_error_mean_std_TEMP = 0
        threshold_error_mean_std_TEMP = mean_error + [i,j]*std_error # mean + n*std_dev
        anomaly_predicted_mean_std_TEMP = 0
        anomaly_predicted_mean_std_TEMP = predict_anomalies(rec_error, threshold_error_mean_std_TEMP)
        f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted_mean_std_TEMP)
        if(f1>F1_MAX):
            F1_MAX = f1
            best_val = [i,j]
            print("best threshold parameters: " + str(best_val) + " best f1: " + str(F1_MAX))
            
threshold_error_mean_std = mean_error + [best_val[0],best_val[1]]*std_error # mean + n*std_dev
anomaly_predicted_mean_std = predict_anomalies(rec_error, threshold_error_mean_std)
                
threshold_error_max = max_error # Max error on the training set
anomaly_predicted_max = predict_anomalies(rec_error, threshold_error_max)

anomaly_predicted_mean_std.sum(), anomaly_predicted_max.sum(), anomaly_predicted_mean_std.shape, anomaly_predicted_max.shape, threshold_error_mean_std, threshold_error_max
# Out:
# best threshold parameters: [3.0, 3.0] best f1: 0.44153957879448075
# best threshold parameters: [3.0, 3.1] best f1: 0.4476047904191616
# best threshold parameters: [3.0, 3.2] best f1: 0.4526873580620742
# best threshold parameters: [3.0, 3.3000000000000003] best f1: 0.4547528517110266
# best threshold parameters: [3.0, 3.4000000000000004] best f1: 0.45614035087719296
# best threshold parameters: [3.0, 3.5000000000000004] best f1: 0.45648854961832064
# best threshold parameters: [3.0, 3.6000000000000005] best f1: 0.45683728036669213
# best threshold parameters: [3.0, 3.7000000000000006] best f1: 0.45718654434250766
# best threshold parameters: [3.0, 4.000000000000001] best f1: 0.4575363427697016
# best threshold parameters: [3.0, 4.200000000000001] best f1: 0.4578866768759571
# best threshold parameters: [3.0, 4.400000000000001] best f1: 0.4585889570552147
# best threshold parameters: [3.0, 4.500000000000002] best f1: 0.4592933947772657
# best threshold parameters: [3.0, 4.600000000000001] best f1: 0.4596464258262875
# best threshold parameters: [3.0, 4.700000000000001] best f1: 0.46035411855273284
# best threshold parameters: [3.0, 5.000000000000002] best f1: 0.46070878274268107
# best threshold parameters: [3.0, 5.3000000000000025] best f1: 0.4610639938319198
# best threshold parameters: [3.0, 5.400000000000002] best f1: 0.4614197530864198
# best threshold parameters: [3.1, 3.2] best f1: 0.465818759936407
# best threshold parameters: [3.1, 3.3000000000000003] best f1: 0.46709470304975925
# best threshold parameters: [3.1, 3.4000000000000004] best f1: 0.4685990338164251
# best threshold parameters: [3.1, 3.5000000000000004] best f1: 0.4704931285367825
# best threshold parameters: [3.1, 3.6000000000000005] best f1: 0.47087378640776695
# best threshold parameters: [3.1, 3.7000000000000006] best f1: 0.47125506072874496
# best threshold parameters: [3.1, 4.000000000000001] best f1: 0.47163695299837927
# best threshold parameters: [3.1, 4.200000000000001] best f1: 0.4720194647201946
# best threshold parameters: [3.1, 4.400000000000001] best f1: 0.4727863525588952
# best threshold parameters: [3.1, 4.500000000000002] best f1: 0.4735557363710333
# best threshold parameters: [3.1, 4.600000000000001] best f1: 0.47394136807817594
# best threshold parameters: [3.1, 4.700000000000001] best f1: 0.4747145187601957
# best threshold parameters: [3.1, 5.000000000000002] best f1: 0.47510204081632657
# best threshold parameters: [3.1, 5.3000000000000025] best f1: 0.47549019607843135
# best threshold parameters: [3.1, 5.400000000000002] best f1: 0.4758789860997547
# best threshold parameters: [3.2, 3.3000000000000003] best f1: 0.48113998323554064
# best threshold parameters: [3.2, 3.4000000000000004] best f1: 0.4847972972972973
# best threshold parameters: [3.2, 3.5000000000000004] best f1: 0.4872665534804753
# best threshold parameters: [3.2, 3.6000000000000005] best f1: 0.4880952380952381
# best threshold parameters: [3.2, 3.7000000000000006] best f1: 0.48851063829787233
# best threshold parameters: [3.2, 3.900000000000001] best f1: 0.48892674616695053
# best threshold parameters: [3.2, 4.000000000000001] best f1: 0.4893435635123614
# best threshold parameters: [3.2, 4.200000000000001] best f1: 0.4897610921501706
# best threshold parameters: [3.2, 4.400000000000001] best f1: 0.49059829059829063
# best threshold parameters: [3.2, 4.500000000000002] best f1: 0.4914383561643835
# best threshold parameters: [3.2, 4.600000000000001] best f1: 0.4918594687232219
# best threshold parameters: [3.2, 4.700000000000001] best f1: 0.4927038626609442
# best threshold parameters: [3.2, 5.000000000000002] best f1: 0.49312714776632305
# best threshold parameters: [3.2, 5.3000000000000025] best f1: 0.4935511607910576
# best threshold parameters: [3.2, 5.400000000000002] best f1: 0.4939759036144578
# best threshold parameters: [3.3000000000000003, 3.6000000000000005] best f1: 0.49515418502202646
# best threshold parameters: [3.3000000000000003, 3.7000000000000006] best f1: 0.4960282436010591
# best threshold parameters: [3.3000000000000003, 3.900000000000001] best f1: 0.49646643109540634
# best threshold parameters: [3.3000000000000003, 4.000000000000001] best f1: 0.4969053934571176
# best threshold parameters: [3.3000000000000003, 4.200000000000001] best f1: 0.4977856510186005
# best threshold parameters: [3.3000000000000003, 4.400000000000001] best f1: 0.4986690328305235
# best threshold parameters: [3.3000000000000003, 4.500000000000002] best f1: 0.4995555555555556
# best threshold parameters: [3.3000000000000003, 4.600000000000001] best f1: 0.5
# best threshold parameters: [3.3000000000000003, 4.700000000000001] best f1: 0.500891265597148
# best threshold parameters: [3.3000000000000003, 5.000000000000002] best f1: 0.5013380909901873
# best threshold parameters: [3.3000000000000003, 5.3000000000000025] best f1: 0.5017857142857144
# best threshold parameters: [3.3000000000000003, 5.400000000000002] best f1: 0.5022341376228775
# best threshold parameters: [3.4000000000000004, 4.700000000000001] best f1: 0.5027422303473492
# best threshold parameters: [3.4000000000000004, 5.000000000000002] best f1: 0.5032021957913999
# best threshold parameters: [3.4000000000000004, 5.3000000000000025] best f1: 0.5036630036630036
# best threshold parameters: [3.4000000000000004, 5.400000000000002] best f1: 0.5041246562786434
# best threshold parameters: [3.6000000000000005, 4.700000000000001] best f1: 0.5044510385756678
# best threshold parameters: [3.6000000000000005, 5.000000000000002] best f1: 0.504950495049505
# best threshold parameters: [3.6000000000000005, 5.3000000000000025] best f1: 0.5054509415262637
# best threshold parameters: [3.6000000000000005, 5.400000000000002] best f1: 0.5059523809523809
# (465.0,
#  33.0,
#  (16032,),
#  (16032,),
#  array([1.10543774, 1.52384095]),
#  array([2.25457166, 2.28510267]))

# %%
padding_len = (len(X_test_raw)-window)%stride
size = X_test_raw.shape[0]-padding_len
X_test_raw = X_test_raw[:size]
X_test_raw.shape[1]
# Out:
# 3

# %%
# Adding predictions and predicted anomalies to X_test_raw
X_test_raw['Reconstr_1_Floor'] = reconstruction_test[:,0] # Prediction on floor 1
X_test_raw['Reconstr_2_Floor'] = reconstruction_test[:,1] # Prediction on floor 2
X_test_raw['Anomaly_Label_GT'] = Anomaly_Test # Ground truth anomalies
X_test_raw['Anomaly_Predicted_Mean_Std'] = anomaly_predicted_mean_std[:X_test_raw.shape[0]] # Anomalies predicted using mean and std dev
X_test_raw['Anomaly_Predicted_Max'] = anomaly_predicted_max[:X_test_raw.shape[0]] # Anomalies predicted using max error on the training set
X_test_raw['Error_1_Floor'] = reconstruction_errors_test[:,0] # Prediction error on floor 1
X_test_raw['Error_2_Floor'] = reconstruction_errors_test[:,1] # Prediction error on floor 2
X_test_raw.head()
# Out:
#        CB_First_Floor  CB_Second_Floor  Day_Of_The_Week  Reconstr_1_Floor  \
# 59808       -0.110053        -0.145436              0.0         -0.342371
# 59809       -0.110053        -0.145436              0.0         -0.824496
# 59810       -0.110053        -0.093767              0.0         -0.834961
# 59811       -0.161507        -0.145436              0.0         -0.663587
# 59812       -0.161507        -0.145436              0.0         -0.655315
#
#        Reconstr_2_Floor  Anomaly_Label_GT  Anomaly_Predicted_Mean_Std  \
# 59808         -0.344750               0.0                         0.0
# 59809         -0.826089               0.0                         0.0
# 59810         -0.837457               0.0                         0.0
# 59811         -0.663625               0.0                         0.0
# 59812         -0.654885               0.0                         0.0
#
#        Anomaly_Predicted_Max  Error_1_Floor  Error_2_Floor
# 59808                    0.0       0.232317       0.199313
# 59809                    0.0       0.714443       0.680653
# 59810                    0.0       0.724907       0.743690
# 59811                    0.0       0.502080       0.518188
# 59812                    0.0       0.493807       0.509449

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(30,20))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()

# %%
# Plotting reconstructions for a check
import datetime as dt

i=89 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# %%
def inspect_multivariate_prediction(X, y, a_true, a_predicted_mean_std, a_predicted_max, pred, columns, error_1F, error_2F): 
   
    figs, axs = plt.subplots(7, 1, sharex=True, figsize=(17,17)) 
    for i, col in enumerate(columns[:2]): 
        axs[i].plot(np.arange(len(X[:,i])), X[:,i]) 
        axs[i].plot(np.arange(len(X[:,i]), len(X[:,i])*2), y[:,i], color='orange') 
        axs[i].plot(np.arange(len(X[:,i]), len(X[:,i])*2), pred[:,i], color='green') 
        axs[i].set_title(col) 
        
    axs[2].plot(np.arange(len(X[:,i])), error_1F) 
    axs[2].plot(np.arange(len(X[:,i]), len(X[:,i])*2), error_1F) 
    axs[2].set_title('error_1F') 
     
    axs[3].plot(np.arange(len(X[:,i])), error_2F) 
    axs[3].plot(np.arange(len(X[:,i]), len(X[:,i])*2), error_2F) 
    axs[3].set_title('error_2F') 
            
    axs[4].plot(np.arange(len(X[:,i])), a_true) 
    axs[4].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_true) 
    axs[4].set_title('Anomaly_True') 
    
    axs[5].plot(np.arange(len(X[:,i])), a_predicted_mean_std) 
    axs[5].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_predicted_mean_std) 
    axs[5].set_title('Anomaly_Predicted_Mean_Std_Dev')
    
    axs[6].plot(np.arange(len(X[:,i])), a_predicted_max) 
    axs[6].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_predicted_max) 
    axs[6].set_title('Anomaly_Predicted_Max') 
    plt.show()

# %%
# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
anomaly_predicted = anomaly_predicted_mean_std

# Compute the confusion matrix
cm = confusion_matrix(y_true=Anomaly_Test, y_pred=anomaly_predicted)

# Compute the classification metrics
accuracy = accuracy_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
precision = precision_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
recall = recall_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Accuracy: 0.9689
# Precision: 0.5484
# Recall: 0.4696
# F1: 0.506

# %%
anomaly_predicted = anomaly_predicted_max

# Compute the confusion matrix
cm = confusion_matrix(y_true=Anomaly_Test, y_pred=anomaly_predicted)

# Compute the classification metrics
accuracy = accuracy_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
precision = precision_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
recall = recall_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Accuracy: 0.9682
# Precision: 1.0
# Recall: 0.0608
# F1: 0.1146
