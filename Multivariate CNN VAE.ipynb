# %%
# Importing libraries

import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import itertools as it
import matplotlib.pyplot as plt

from datetime import datetime
from scipy.stats import multivariate_normal
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

plt.rc('font', size=16)

import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers

# Setting random seed for reproducibility

seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# 2022-08-29 10:22:32.961148: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Opening the dataframe
ABB_data = pd.read_csv('../input/electricity-demand/Multivariate_Labeled_2.csv', parse_dates=['DateTime'], delimiter=',')
ABB_data.drop(columns="DateTime", inplace=True)
ABB_data
# Out:
#        CB_First_Floor  CB_Second_Floor   AvgT   AvgH  Anomaly_Label    Year  \
# 0                37.0             36.0   4.70  80.40            0.0  2017.0
# 1                32.0             33.0   4.75  79.35            0.0  2017.0
# 2                32.0             32.0   4.60  78.90            0.0  2017.0
# 3                32.0             33.0   4.50  79.25            0.0  2017.0
# 4                33.0             33.0   4.40  80.40            0.0  2017.0
# ...               ...              ...    ...    ...            ...     ...
# 75835            41.0             41.0  10.95  83.25            0.0  2019.0
# 75836            42.0             42.0  10.80  84.60            0.0  2019.0
# 75837            43.0             43.0  10.65  86.05            0.0  2019.0
# 75838            42.0             42.0  10.30  86.90            0.0  2019.0
# 75839            42.0             42.0   9.95  87.80            0.0  2019.0
#
#        Month  Day  Hour   Min  Sec  Day_Of_The_Week
# 0        2.0  9.0   0.0   0.0  0.0              3.0
# 1        2.0  9.0   0.0  15.0  0.0              3.0
# 2        2.0  9.0   0.0  30.0  0.0              3.0
# 3        2.0  9.0   0.0  45.0  0.0              3.0
# 4        2.0  9.0   1.0   0.0  0.0              3.0
# ...      ...  ...   ...   ...  ...              ...
# 75835    4.0  9.0  22.0  45.0  0.0              1.0
# 75836    4.0  9.0  23.0   0.0  0.0              1.0
# 75837    4.0  9.0  23.0  15.0  0.0              1.0
# 75838    4.0  9.0  23.0  30.0  0.0              1.0
# 75839    4.0  9.0  23.0  45.0  0.0              1.0
#
# [75840 rows x 12 columns]

# %%
# Dataframe preprocessing

# Converting data types
ABB_data['CB_First_Floor'] = ABB_data['CB_First_Floor'].astype(np.float32)
ABB_data['CB_Second_Floor'] = ABB_data['CB_Second_Floor'].astype(np.float32)
ABB_data['AvgT'] = ABB_data['AvgT'].astype(np.float32)
ABB_data['AvgH'] = ABB_data['AvgH'].astype(np.float32)
ABB_data['Anomaly_Label'] = ABB_data['Anomaly_Label'].astype(np.float32)
ABB_data['Year'] = ABB_data['Year'].astype(np.float32)
ABB_data['Month'] = ABB_data['Month'].astype(np.float32)
ABB_data['Day'] = ABB_data['Day'].astype(np.float32)
ABB_data['Hour'] = ABB_data['Hour'].astype(np.float32)
ABB_data['Min'] = ABB_data['Min'].astype(np.float32)
ABB_data['Sec'] = ABB_data['Sec'].astype(np.float32)
ABB_data['Day_Of_The_Week'] = ABB_data['Day_Of_The_Week'].astype(np.float32)

# Printing the dataframe's info
ABB_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75840 entries, 0 to 75839
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CB_First_Floor   75840 non-null  float32
#  1   CB_Second_Floor  75840 non-null  float32
#  2   AvgT             75840 non-null  float32
#  3   AvgH             75840 non-null  float32
#  4   Anomaly_Label    75840 non-null  float32
#  5   Year             75840 non-null  float32
#  6   Month            75840 non-null  float32
#  7   Day              75840 non-null  float32
#  8   Hour             75840 non-null  float32
#  9   Min              75840 non-null  float32
#  10  Sec              75840 non-null  float32
#  11  Day_Of_The_Week  75840 non-null  float32
# dtypes: float32(12)
# memory usage: 3.5 MB

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(15,10))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
    
# Plotting time series
inspect_dataframe(ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week"]], ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week"]].columns)

# %%
# Columns used for the following split in train, test and validation sets
ABB_data['Test'] = 0
ABB_data['Validation'] = 0
ABB_data['Train_P1'] = 0
ABB_data['Train_P2'] = 0

# %%
# TEST SET

# Some random weeks
week = [89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112]
for j in week:
    Slice_Multivariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Test'] = 1

# %%
# VALIDATION SET

# Some random weeks
week = [55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78]
for j in week:
    Slice_Multivariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Validation'] = 1

# %%
# TRAINING SET

week = [x for x in np.arange(0, 55, 1)]
for j in week:
    Slice_Univariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Train_P1'] = 1
    
week = [x for x in np.arange(79, 89, 1)]
for j in week:
    Slice_Univariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    ABB_data.iloc[(j)*672:(j+1)*672]['Train_P2'] = 1

# %%
# Plotting time series
inspect_dataframe(ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week", "Train_P1", "Train_P2", "Validation", "Test"]], ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week", "Train_P1", "Train_P2", "Validation", "Test"]].columns)

# %%
# TRAIN, TEST, VALIDATION SETS
X_train_temp_P1 = ABB_data[ABB_data['Train_P1']==1].copy()
X_train_temp_P2 = ABB_data[ABB_data['Train_P2']==1].copy()
X_validation_temp = ABB_data[ABB_data['Validation']==1].copy()
X_test_temp = ABB_data[ABB_data['Test']==1].copy()

# %%
# Training, Validation and Test set - Anomalies (not used for training)
Anomaly_Train_P1 = X_train_temp_P1[['Anomaly_Label']]
Anomaly_Train_P2 = X_train_temp_P2[['Anomaly_Label']]
Anomaly_Validation = X_validation_temp[['Anomaly_Label']]
Anomaly_Test = X_test_temp[['Anomaly_Label']]

# %%
X_train_temp_global = pd.concat([X_train_temp_P1,X_train_temp_P2],axis=0)
X_train_temp_global.shape
# Out:
# (43680, 16)

# %%
# STANDARDIZATION

mean = X_train_temp_global.mean()
std_dev = X_train_temp_global.std()
print(mean, std_dev)

X_train_raw_P1 = (X_train_temp_P1-mean)/std_dev
X_train_raw_P2 = (X_train_temp_P2-mean)/std_dev
X_validation_raw = (X_validation_temp-mean)/std_dev
X_test_raw = (X_test_temp-mean)/std_dev

print(X_test_raw.shape[0]+X_validation_raw.shape[0]+X_train_raw_P1.shape[0]+X_train_raw_P2.shape[0] == ABB_data.shape[0])
# Out:
# CB_First_Floor       56.138874
# CB_Second_Floor      55.814743
# AvgT                 14.077893
# AvgH                 71.934387
# Anomaly_Label         0.000000
# Year               2017.283569
# Month                 6.725275
# Day                  15.931869
# Hour                 11.500000
# Min                  22.500000
# Sec                   0.000000
# Day_Of_The_Week       3.000000
# Test                  0.000000
# Validation            0.000000
# Train_P1              0.846154
# Train_P2              0.153846
# dtype: float64 CB_First_Floor     19.434896
# CB_Second_Floor    19.353765
# AvgT                8.412517
# AvgH               19.357885
# Anomaly_Label       0.000000
# Year                0.450710
# Month               3.393199
# Day                 8.644081
# Hour                6.922266
# Min                16.770702
# Sec                 0.000000
# Day_Of_The_Week     2.000023
# Test                0.000000
# Validation          0.000000
# Train_P1            0.360805
# Train_P2            0.360805
# dtype: float64
# True

# %%
# Anomalies are not considered during the training
X_train_raw_P1 = X_train_raw_P1[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_train_raw_P2 = X_train_raw_P2[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_validation_raw = X_validation_raw[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_test_raw = X_test_raw[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_train_raw_P1.shape, X_train_raw_P2.shape, X_validation_raw.shape, X_test_raw.shape
# Out:
# ((36960, 3), (6720, 3), (16128, 3), (16032, 3))

# %%
# Plotting time series
inspect_dataframe(X_test_raw, X_test_raw.columns)

# %% [markdown]
# ## Training Preparation

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Training parameters

window = 672       # 1 week
stride = 8         # 1 hour
latent_dim = 4     # Latent dimension
epochs = 300       # Number of epochs (no early stopping)
batch_size = 8     # Batch size
f = 3              # Filters' dimensions
alpha = 0.5
M = 200

# %%
# Function used to create (overlapped) windows that we will use for the training
def build_sequences(df, anomaly, window=window, stride=stride):
    
    assert len(df) > window
    dataset = []
    anomalies = []
    temp_df = df.copy().values
    temp_an = anomaly.copy().values
    padding_len = (len(df)-window)%stride # Padding computed considering the stride
    print("PADDING: " + str(padding_len)) #DEBUG

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float32')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_an.shape[1]), dtype='float32')
        temp_an = np.concatenate((padding,temp_an))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window+1,stride):
        dataset.append(temp_df[idx:idx+window])
        anomalies.append(temp_an[idx:idx+window])

    dataset = np.array(dataset)
    anomalies = np.array(anomalies)
    return dataset, anomalies

# %%
X_train_P1, A_train_P1 = build_sequences(X_train_raw_P1, Anomaly_Train_P1, window=window, stride=stride)
X_train_P2, A_train_P2 = build_sequences(X_train_raw_P2, Anomaly_Train_P2, window=window, stride=stride)
X_val, A_val = build_sequences(X_validation_raw, Anomaly_Validation, window=window, stride=stride)
X_train_P1.shape,X_train_P2.shape
# Out:
# PADDING: 0
# PADDING: 0
# PADDING: 0
# ((4537, 672, 3), (757, 672, 3))

# %%
# Temp test set - plotting purposes
X_test, A_test = build_sequences(X_test_raw, Anomaly_Test, window=window, stride=stride)
# Out:
# PADDING: 0

# %%
X_train = np.concatenate([X_train_P1,X_train_P2],axis=0)
A_train = np.concatenate([A_train_P1,A_train_P2],axis=0)
X_train.shape, A_train.shape
# Out:
# ((5294, 672, 3), (5294, 672, 1))

# %%
# Building the model

from keras import backend as K
from tensorflow.keras import Input

input_shape = X_train.shape[1:]
output_shape = X_train.shape[1:]


###########
# ENCODER #
###########

encoder_input = tf.keras.Input(shape=input_shape)

x = tfkl.Conv1D(16, f, activation="relu", strides=1, padding="same")(encoder_input)
x = tfkl.MaxPool1D(pool_size=2, strides=2)(x)
x = tfkl.Conv1D(32, f, activation="relu", strides=1, padding="same")(x)
x = tfkl.MaxPool1D(pool_size=2, strides=2)(x)

x = tfkl.Flatten()(x)
x = tfkl.Dense(latent_dim, activation='linear')(x)

# Latent representation: mean + log of std.dev.
z_mu = tfkl.Dense(latent_dim, name='latent_mu')(x) # Mean
z_sigma = tfkl.Dense(latent_dim, name='latent_sigma')(x) # Std.Dev.

# Reparametrization trick
def sample_z1(args):
    z_mean, z_log_var = args
    eps = tf.keras.backend.random_normal(shape=(K.shape(z_mean)[0], K.int_shape(z_mean)[1]))
    return z_mean + tf.exp(alpha * z_log_var) * eps

# Sampling a vector from the latent distribution
z = tfkl.Lambda(sample_z1, output_shape=(latent_dim, ), name='z')([z_mu, z_sigma])

encoder = tfk.Model(encoder_input, [z_mu, z_sigma, z], name='encoder')
print(encoder.summary())
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 672, 3)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 672, 16)      160         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 336, 16)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 336, 32)      1568        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 168, 32)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 5376)         0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            21508       flatten[0][0]
# __________________________________________________________________________________________________
# latent_mu (Dense)               (None, 4)            20          dense[0][0]
# __________________________________________________________________________________________________
# latent_sigma (Dense)            (None, 4)            20          dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 4)            0           latent_mu[0][0]
#                                                                  latent_sigma[0][0]
# ==================================================================================================
# Total params: 23,276
# Trainable params: 23,276
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
###########
# DECODER #
###########

decoder_input = Input(shape=(latent_dim, ), name='decoder_input')
x = tfkl.Dense(units=84*X_train.shape[2])(decoder_input)
x = tfkl.Reshape((84,X_train.shape[2]))(x)
x = tfkl.Conv1DTranspose(32,f,2, padding='same', activation='relu')(x)
x = tfkl.Conv1DTranspose(16,f,2, padding='same', activation='relu')(x)
decoder_output = tfkl.Conv1DTranspose(X_train.shape[2],f,2, padding='same', activation='linear')(x)

# Define and summarize decoder model
decoder = tfk.Model(decoder_input, decoder_output, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 4)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 252)               1260
# _________________________________________________________________
# reshape (Reshape)            (None, 84, 3)             0
# _________________________________________________________________
# conv1d_transpose (Conv1DTran (None, 168, 32)           320
# _________________________________________________________________
# conv1d_transpose_1 (Conv1DTr (None, 336, 16)           1552
# _________________________________________________________________
# conv1d_transpose_2 (Conv1DTr (None, 672, 3)            147
# =================================================================
# Total params: 3,279
# Trainable params: 3,279
# Non-trainable params: 0
# _________________________________________________________________

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
class VAE(tfk.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tfk.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tfk.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tfk.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, y_true):
        with tf.GradientTape() as tape:
            
            encoder_mu, encoder_log_var, z = self.encoder(y_true)
            y_predict = self.decoder(z)
          
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tfk.losses.mse(y_true, y_predict), axis=1))
            
            kl_loss = -0.5 * (1 + encoder_log_var - tf.square(encoder_mu) - tf.exp(encoder_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
            total_loss = reconstruction_loss + kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result()
        }
    
    def test_step(self, data): #https://github.com/keras-team/keras-io/issues/38

        encoder_mu, encoder_log_var, z = self.encoder(data)
        y_predict = self.decoder(z)
          
        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tfk.losses.mse(data, y_predict), axis=1))
            
        kl_loss = -0.5 * (1 + encoder_log_var - tf.square(encoder_mu) - tf.exp(encoder_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
        total_loss = reconstruction_loss + kl_loss
        
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=tfk.optimizers.Adam())
vae.fit(x = X_train,
        validation_data = (X_val, None),
        epochs=150, 
        batch_size=batch_size)
vae.fit(x = X_train,
        validation_data = (X_val, None),
        epochs=epochs, 
        batch_size=batch_size,
        callbacks=[tfk.callbacks.EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)])
# Out:
# 2022-08-29 10:22:37.186316: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 662/662 [==============================] - 9s 12ms/step - loss: 556.6915 - reconstruction_loss: 460.1994 - kl_loss: 9.1533 - val_loss: 319.5967 - val_reconstruction_loss: 312.1787 - val_kl_loss: 7.4180
# Epoch 2/150
# 662/662 [==============================] - 7s 11ms/step - loss: 408.1057 - reconstruction_loss: 396.7794 - kl_loss: 9.7098 - val_loss: 318.3248 - val_reconstruction_loss: 310.4516 - val_kl_loss: 7.8732
# Epoch 3/150
# 662/662 [==============================] - 7s 11ms/step - loss: 402.7421 - reconstruction_loss: 381.8967 - kl_loss: 11.1630 - val_loss: 302.5319 - val_reconstruction_loss: 293.4847 - val_kl_loss: 9.0472
# Epoch 4/150
# 662/662 [==============================] - 7s 11ms/step - loss: 324.1219 - reconstruction_loss: 273.6149 - kl_loss: 14.5522 - val_loss: 124.6323 - val_reconstruction_loss: 112.8164 - val_kl_loss: 11.8159
# Epoch 5/150
# 662/662 [==============================] - 8s 12ms/step - loss: 194.7811 - reconstruction_loss: 166.2726 - kl_loss: 16.4030 - val_loss: 105.3010 - val_reconstruction_loss: 92.8126 - val_kl_loss: 12.4884
# Epoch 6/150
# 662/662 [==============================] - 7s 11ms/step - loss: 151.4493 - reconstruction_loss: 126.5961 - kl_loss: 16.2111 - val_loss: 78.9542 - val_reconstruction_loss: 65.7337 - val_kl_loss: 13.2205
# Epoch 7/150
# 662/662 [==============================] - 8s 11ms/step - loss: 123.5926 - reconstruction_loss: 102.8041 - kl_loss: 15.9619 - val_loss: 69.5018 - val_reconstruction_loss: 56.3318 - val_kl_loss: 13.1700
# Epoch 8/150
# 662/662 [==============================] - 8s 12ms/step - loss: 107.4264 - reconstruction_loss: 89.8644 - kl_loss: 15.6274 - val_loss: 63.5163 - val_reconstruction_loss: 50.3538 - val_kl_loss: 13.1625
# Epoch 9/150
# 662/662 [==============================] - 8s 12ms/step - loss: 99.5404 - reconstruction_loss: 82.5833 - kl_loss: 15.3386 - val_loss: 51.5049 - val_reconstruction_loss: 37.8891 - val_kl_loss: 13.6158
# Epoch 10/150
# 662/662 [==============================] - 8s 12ms/step - loss: 92.2990 - reconstruction_loss: 77.1432 - kl_loss: 15.1246 - val_loss: 52.1034 - val_reconstruction_loss: 38.8891 - val_kl_loss: 13.2143
# Epoch 11/150
# 662/662 [==============================] - 8s 12ms/step - loss: 89.2071 - reconstruction_loss: 73.3692 - kl_loss: 14.9400 - val_loss: 57.7703 - val_reconstruction_loss: 44.9935 - val_kl_loss: 12.7768
# Epoch 12/150
# 662/662 [==============================] - 8s 12ms/step - loss: 83.7881 - reconstruction_loss: 68.4990 - kl_loss: 14.7515 - val_loss: 44.0361 - val_reconstruction_loss: 31.0715 - val_kl_loss: 12.9645
# Epoch 13/150
# 662/662 [==============================] - 8s 12ms/step - loss: 80.2681 - reconstruction_loss: 65.0136 - kl_loss: 14.6689 - val_loss: 44.9860 - val_reconstruction_loss: 32.1244 - val_kl_loss: 12.8615
# Epoch 14/150
# 662/662 [==============================] - 8s 11ms/step - loss: 76.7164 - reconstruction_loss: 62.2528 - kl_loss: 14.5100 - val_loss: 43.9196 - val_reconstruction_loss: 31.5157 - val_kl_loss: 12.4039
# Epoch 15/150
# 662/662 [==============================] - 8s 12ms/step - loss: 74.6946 - reconstruction_loss: 59.7883 - kl_loss: 14.3660 - val_loss: 42.8825 - val_reconstruction_loss: 30.4758 - val_kl_loss: 12.4067
# Epoch 16/150
# 662/662 [==============================] - 8s 12ms/step - loss: 72.1521 - reconstruction_loss: 58.4284 - kl_loss: 14.1949 - val_loss: 47.0911 - val_reconstruction_loss: 34.3826 - val_kl_loss: 12.7084
# Epoch 17/150
# 662/662 [==============================] - 8s 13ms/step - loss: 71.0124 - reconstruction_loss: 56.9438 - kl_loss: 14.1603 - val_loss: 35.3624 - val_reconstruction_loss: 23.2193 - val_kl_loss: 12.1430
# Epoch 18/150
# 662/662 [==============================] - 8s 11ms/step - loss: 69.8007 - reconstruction_loss: 55.5646 - kl_loss: 14.0928 - val_loss: 34.7512 - val_reconstruction_loss: 22.6718 - val_kl_loss: 12.0794
# Epoch 19/150
# 662/662 [==============================] - 8s 12ms/step - loss: 68.5699 - reconstruction_loss: 54.1961 - kl_loss: 13.9868 - val_loss: 40.7776 - val_reconstruction_loss: 28.5849 - val_kl_loss: 12.1927
# Epoch 20/150
# 662/662 [==============================] - 8s 12ms/step - loss: 67.0877 - reconstruction_loss: 52.8577 - kl_loss: 13.8523 - val_loss: 40.8110 - val_reconstruction_loss: 28.7735 - val_kl_loss: 12.0374
# Epoch 21/150
# 662/662 [==============================] - 8s 11ms/step - loss: 65.5606 - reconstruction_loss: 52.1877 - kl_loss: 13.7101 - val_loss: 39.5190 - val_reconstruction_loss: 27.8257 - val_kl_loss: 11.6933
# Epoch 22/150
# 662/662 [==============================] - 8s 13ms/step - loss: 64.9888 - reconstruction_loss: 51.2012 - kl_loss: 13.6819 - val_loss: 39.5333 - val_reconstruction_loss: 27.7433 - val_kl_loss: 11.7900
# Epoch 23/150
# 662/662 [==============================] - 8s 12ms/step - loss: 64.1258 - reconstruction_loss: 50.9605 - kl_loss: 13.6354 - val_loss: 40.3796 - val_reconstruction_loss: 28.7780 - val_kl_loss: 11.6017
# Epoch 24/150
# 662/662 [==============================] - 8s 12ms/step - loss: 64.0892 - reconstruction_loss: 50.2350 - kl_loss: 13.5215 - val_loss: 34.5185 - val_reconstruction_loss: 22.8772 - val_kl_loss: 11.6413
# Epoch 25/150
# 662/662 [==============================] - 8s 12ms/step - loss: 63.8127 - reconstruction_loss: 49.5388 - kl_loss: 13.4586 - val_loss: 34.1802 - val_reconstruction_loss: 22.6216 - val_kl_loss: 11.5586
# Epoch 26/150
# 662/662 [==============================] - 8s 12ms/step - loss: 62.5846 - reconstruction_loss: 49.0795 - kl_loss: 13.4789 - val_loss: 43.5446 - val_reconstruction_loss: 31.9196 - val_kl_loss: 11.6250
# Epoch 27/150
# 662/662 [==============================] - 8s 13ms/step - loss: 61.8126 - reconstruction_loss: 48.6582 - kl_loss: 13.4476 - val_loss: 39.5032 - val_reconstruction_loss: 27.9901 - val_kl_loss: 11.5131
# Epoch 28/150
# 662/662 [==============================] - 8s 12ms/step - loss: 62.0027 - reconstruction_loss: 48.2073 - kl_loss: 13.3654 - val_loss: 34.8580 - val_reconstruction_loss: 23.1898 - val_kl_loss: 11.6681
# Epoch 29/150
# 662/662 [==============================] - 8s 12ms/step - loss: 61.5179 - reconstruction_loss: 47.9038 - kl_loss: 13.3770 - val_loss: 44.8490 - val_reconstruction_loss: 33.2206 - val_kl_loss: 11.6285
# Epoch 30/150
# 662/662 [==============================] - 8s 12ms/step - loss: 61.3602 - reconstruction_loss: 47.5624 - kl_loss: 13.3241 - val_loss: 35.1938 - val_reconstruction_loss: 23.4037 - val_kl_loss: 11.7901
# Epoch 31/150
# 662/662 [==============================] - 8s 12ms/step - loss: 60.5520 - reconstruction_loss: 47.1554 - kl_loss: 13.3590 - val_loss: 36.2288 - val_reconstruction_loss: 24.7733 - val_kl_loss: 11.4555
# Epoch 32/150
# 662/662 [==============================] - 8s 13ms/step - loss: 59.5334 - reconstruction_loss: 46.6891 - kl_loss: 13.2484 - val_loss: 37.4383 - val_reconstruction_loss: 25.8325 - val_kl_loss: 11.6057
# Epoch 33/150
# 662/662 [==============================] - 8s 12ms/step - loss: 59.8685 - reconstruction_loss: 46.6115 - kl_loss: 13.2379 - val_loss: 35.2981 - val_reconstruction_loss: 23.7073 - val_kl_loss: 11.5909
# Epoch 34/150
# 662/662 [==============================] - 8s 12ms/step - loss: 59.6940 - reconstruction_loss: 46.3664 - kl_loss: 13.2879 - val_loss: 32.4349 - val_reconstruction_loss: 20.6661 - val_kl_loss: 11.7688
# Epoch 35/150
# 662/662 [==============================] - 8s 11ms/step - loss: 59.3818 - reconstruction_loss: 45.9697 - kl_loss: 13.2957 - val_loss: 33.9452 - val_reconstruction_loss: 22.4435 - val_kl_loss: 11.5017
# Epoch 36/150
# 662/662 [==============================] - 8s 13ms/step - loss: 59.1036 - reconstruction_loss: 45.8946 - kl_loss: 13.3206 - val_loss: 33.0824 - val_reconstruction_loss: 21.4790 - val_kl_loss: 11.6033
# Epoch 37/150
# 662/662 [==============================] - 8s 12ms/step - loss: 59.3819 - reconstruction_loss: 45.6090 - kl_loss: 13.3245 - val_loss: 44.4364 - val_reconstruction_loss: 32.8615 - val_kl_loss: 11.5749
# Epoch 38/150
# 662/662 [==============================] - 8s 12ms/step - loss: 59.0584 - reconstruction_loss: 45.5076 - kl_loss: 13.2862 - val_loss: 31.1296 - val_reconstruction_loss: 19.5849 - val_kl_loss: 11.5447
# Epoch 39/150
# 662/662 [==============================] - 8s 12ms/step - loss: 58.6965 - reconstruction_loss: 45.3626 - kl_loss: 13.2981 - val_loss: 32.6422 - val_reconstruction_loss: 21.0961 - val_kl_loss: 11.5461
# Epoch 40/150
# 662/662 [==============================] - 8s 12ms/step - loss: 58.3729 - reconstruction_loss: 44.8718 - kl_loss: 13.3064 - val_loss: 32.7374 - val_reconstruction_loss: 21.1777 - val_kl_loss: 11.5597
# Epoch 41/150
# 662/662 [==============================] - 8s 12ms/step - loss: 58.5839 - reconstruction_loss: 44.9654 - kl_loss: 13.2440 - val_loss: 32.8034 - val_reconstruction_loss: 21.3493 - val_kl_loss: 11.4541
# Epoch 42/150
# 662/662 [==============================] - 9s 13ms/step - loss: 57.3764 - reconstruction_loss: 44.6603 - kl_loss: 13.2709 - val_loss: 34.3059 - val_reconstruction_loss: 22.7740 - val_kl_loss: 11.5319
# Epoch 43/150
# 662/662 [==============================] - 8s 12ms/step - loss: 57.2807 - reconstruction_loss: 44.2276 - kl_loss: 13.2111 - val_loss: 36.2257 - val_reconstruction_loss: 24.7433 - val_kl_loss: 11.4824
# Epoch 44/150
# 662/662 [==============================] - 8s 11ms/step - loss: 59.0540 - reconstruction_loss: 44.6273 - kl_loss: 13.2260 - val_loss: 30.3669 - val_reconstruction_loss: 18.7670 - val_kl_loss: 11.5999
# Epoch 45/150
# 662/662 [==============================] - 7s 11ms/step - loss: 57.3624 - reconstruction_loss: 44.1006 - kl_loss: 13.2550 - val_loss: 32.1787 - val_reconstruction_loss: 20.6281 - val_kl_loss: 11.5505
# Epoch 46/150
# 662/662 [==============================] - 7s 11ms/step - loss: 57.1226 - reconstruction_loss: 43.9713 - kl_loss: 13.2263 - val_loss: 31.1112 - val_reconstruction_loss: 19.6035 - val_kl_loss: 11.5077
# Epoch 47/150
# 662/662 [==============================] - 7s 11ms/step - loss: 58.6068 - reconstruction_loss: 44.2607 - kl_loss: 13.2754 - val_loss: 30.8500 - val_reconstruction_loss: 19.3050 - val_kl_loss: 11.5451
# Epoch 48/150
# 662/662 [==============================] - 8s 12ms/step - loss: 56.8914 - reconstruction_loss: 43.6164 - kl_loss: 13.2450 - val_loss: 29.8315 - val_reconstruction_loss: 18.3960 - val_kl_loss: 11.4355
# Epoch 49/150
# 662/662 [==============================] - 7s 11ms/step - loss: 56.5586 - reconstruction_loss: 43.4001 - kl_loss: 13.1986 - val_loss: 33.2072 - val_reconstruction_loss: 21.7181 - val_kl_loss: 11.4891
# Epoch 50/150
# 662/662 [==============================] - 8s 11ms/step - loss: 57.2846 - reconstruction_loss: 43.3600 - kl_loss: 13.2365 - val_loss: 40.0592 - val_reconstruction_loss: 28.7053 - val_kl_loss: 11.3539
# Epoch 51/150
# 662/662 [==============================] - 7s 11ms/step - loss: 57.1540 - reconstruction_loss: 43.4827 - kl_loss: 13.2134 - val_loss: 30.3520 - val_reconstruction_loss: 18.8873 - val_kl_loss: 11.4648
# Epoch 52/150
# 662/662 [==============================] - 7s 11ms/step - loss: 55.9175 - reconstruction_loss: 43.2022 - kl_loss: 13.2126 - val_loss: 32.2590 - val_reconstruction_loss: 20.6068 - val_kl_loss: 11.6523
# Epoch 53/150
# 662/662 [==============================] - 8s 12ms/step - loss: 56.6588 - reconstruction_loss: 43.0638 - kl_loss: 13.2632 - val_loss: 40.0526 - val_reconstruction_loss: 28.5537 - val_kl_loss: 11.4990
# Epoch 54/150
# 662/662 [==============================] - 8s 12ms/step - loss: 56.1215 - reconstruction_loss: 42.9777 - kl_loss: 13.2223 - val_loss: 28.0907 - val_reconstruction_loss: 16.6189 - val_kl_loss: 11.4719
# Epoch 55/150
# 662/662 [==============================] - 7s 11ms/step - loss: 55.6907 - reconstruction_loss: 42.5528 - kl_loss: 13.1858 - val_loss: 33.4081 - val_reconstruction_loss: 22.1125 - val_kl_loss: 11.2956
# Epoch 56/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.9095 - reconstruction_loss: 42.6195 - kl_loss: 13.1705 - val_loss: 34.1263 - val_reconstruction_loss: 22.6830 - val_kl_loss: 11.4433
# Epoch 57/150
# 662/662 [==============================] - 7s 11ms/step - loss: 55.4704 - reconstruction_loss: 42.7319 - kl_loss: 13.1414 - val_loss: 31.7458 - val_reconstruction_loss: 20.1686 - val_kl_loss: 11.5771
# Epoch 58/150
# 662/662 [==============================] - 8s 12ms/step - loss: 55.5374 - reconstruction_loss: 42.3067 - kl_loss: 13.1700 - val_loss: 31.8706 - val_reconstruction_loss: 20.3907 - val_kl_loss: 11.4799
# Epoch 59/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.4720 - reconstruction_loss: 42.0175 - kl_loss: 13.1862 - val_loss: 43.9125 - val_reconstruction_loss: 32.5188 - val_kl_loss: 11.3937
# Epoch 60/150
# 662/662 [==============================] - 8s 11ms/step - loss: 55.7898 - reconstruction_loss: 42.4637 - kl_loss: 13.1749 - val_loss: 32.2880 - val_reconstruction_loss: 20.7864 - val_kl_loss: 11.5016
# Epoch 61/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.8596 - reconstruction_loss: 41.9125 - kl_loss: 13.1602 - val_loss: 36.2774 - val_reconstruction_loss: 24.8835 - val_kl_loss: 11.3938
# Epoch 62/150
# 662/662 [==============================] - 7s 11ms/step - loss: 55.2352 - reconstruction_loss: 42.0288 - kl_loss: 13.1561 - val_loss: 31.4728 - val_reconstruction_loss: 19.8301 - val_kl_loss: 11.6427
# Epoch 63/150
# 662/662 [==============================] - 8s 12ms/step - loss: 54.8957 - reconstruction_loss: 41.8117 - kl_loss: 13.2139 - val_loss: 30.2952 - val_reconstruction_loss: 18.8628 - val_kl_loss: 11.4324
# Epoch 64/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.9390 - reconstruction_loss: 41.8085 - kl_loss: 13.1494 - val_loss: 29.3697 - val_reconstruction_loss: 18.0861 - val_kl_loss: 11.2836
# Epoch 65/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.5536 - reconstruction_loss: 41.8584 - kl_loss: 13.1630 - val_loss: 33.6012 - val_reconstruction_loss: 22.1635 - val_kl_loss: 11.4377
# Epoch 66/150
# 662/662 [==============================] - 8s 12ms/step - loss: 55.0954 - reconstruction_loss: 41.5117 - kl_loss: 13.1757 - val_loss: 36.7526 - val_reconstruction_loss: 25.2328 - val_kl_loss: 11.5197
# Epoch 67/150
# 662/662 [==============================] - 8s 12ms/step - loss: 54.5694 - reconstruction_loss: 41.5557 - kl_loss: 13.1691 - val_loss: 31.1474 - val_reconstruction_loss: 19.5824 - val_kl_loss: 11.5650
# Epoch 68/150
# 662/662 [==============================] - 9s 13ms/step - loss: 54.8792 - reconstruction_loss: 41.3651 - kl_loss: 13.1744 - val_loss: 31.9998 - val_reconstruction_loss: 20.4594 - val_kl_loss: 11.5404
# Epoch 69/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.8272 - reconstruction_loss: 41.5052 - kl_loss: 13.1848 - val_loss: 28.7673 - val_reconstruction_loss: 17.1960 - val_kl_loss: 11.5713
# Epoch 70/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.0242 - reconstruction_loss: 41.1884 - kl_loss: 13.1952 - val_loss: 31.8954 - val_reconstruction_loss: 20.3811 - val_kl_loss: 11.5143
# Epoch 71/150
# 662/662 [==============================] - 7s 11ms/step - loss: 54.0827 - reconstruction_loss: 41.2114 - kl_loss: 13.1663 - val_loss: 28.7724 - val_reconstruction_loss: 17.3399 - val_kl_loss: 11.4325
# Epoch 72/150
# 662/662 [==============================] - 8s 12ms/step - loss: 54.1607 - reconstruction_loss: 41.2834 - kl_loss: 13.1420 - val_loss: 28.3964 - val_reconstruction_loss: 16.8899 - val_kl_loss: 11.5064
# Epoch 73/150
# 662/662 [==============================] - 8s 12ms/step - loss: 54.2178 - reconstruction_loss: 41.0516 - kl_loss: 13.1880 - val_loss: 33.4061 - val_reconstruction_loss: 21.8881 - val_kl_loss: 11.5179
# Epoch 74/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.6854 - reconstruction_loss: 40.8441 - kl_loss: 13.1860 - val_loss: 27.5484 - val_reconstruction_loss: 16.0607 - val_kl_loss: 11.4876
# Epoch 75/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.5995 - reconstruction_loss: 40.9205 - kl_loss: 13.1716 - val_loss: 36.7371 - val_reconstruction_loss: 25.2306 - val_kl_loss: 11.5065
# Epoch 76/150
# 662/662 [==============================] - 8s 12ms/step - loss: 53.5846 - reconstruction_loss: 40.8333 - kl_loss: 13.1555 - val_loss: 28.6115 - val_reconstruction_loss: 17.0810 - val_kl_loss: 11.5306
# Epoch 77/150
# 662/662 [==============================] - 8s 11ms/step - loss: 53.7376 - reconstruction_loss: 40.5580 - kl_loss: 13.1768 - val_loss: 28.1384 - val_reconstruction_loss: 16.6169 - val_kl_loss: 11.5215
# Epoch 78/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.8981 - reconstruction_loss: 40.6684 - kl_loss: 13.1328 - val_loss: 37.2838 - val_reconstruction_loss: 25.8133 - val_kl_loss: 11.4705
# Epoch 79/150
# 662/662 [==============================] - 8s 12ms/step - loss: 53.4766 - reconstruction_loss: 40.5295 - kl_loss: 13.1614 - val_loss: 30.5645 - val_reconstruction_loss: 19.1516 - val_kl_loss: 11.4129
# Epoch 80/150
# 662/662 [==============================] - 8s 12ms/step - loss: 53.1211 - reconstruction_loss: 40.5881 - kl_loss: 13.1526 - val_loss: 28.5092 - val_reconstruction_loss: 17.0291 - val_kl_loss: 11.4800
# Epoch 81/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.6264 - reconstruction_loss: 40.3509 - kl_loss: 13.1576 - val_loss: 36.3308 - val_reconstruction_loss: 24.8939 - val_kl_loss: 11.4369
# Epoch 82/150
# 662/662 [==============================] - 8s 11ms/step - loss: 53.4318 - reconstruction_loss: 40.3350 - kl_loss: 13.1965 - val_loss: 31.2245 - val_reconstruction_loss: 19.6422 - val_kl_loss: 11.5823
# Epoch 83/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.3957 - reconstruction_loss: 40.1891 - kl_loss: 13.1232 - val_loss: 30.6531 - val_reconstruction_loss: 19.1791 - val_kl_loss: 11.4739
# Epoch 84/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.2212 - reconstruction_loss: 40.0229 - kl_loss: 13.1439 - val_loss: 29.7964 - val_reconstruction_loss: 18.2949 - val_kl_loss: 11.5015
# Epoch 85/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.9340 - reconstruction_loss: 40.0793 - kl_loss: 13.1336 - val_loss: 32.4282 - val_reconstruction_loss: 20.8649 - val_kl_loss: 11.5633
# Epoch 86/150
# 662/662 [==============================] - 8s 13ms/step - loss: 53.1131 - reconstruction_loss: 39.9472 - kl_loss: 13.1589 - val_loss: 28.5023 - val_reconstruction_loss: 16.9970 - val_kl_loss: 11.5052
# Epoch 87/150
# 662/662 [==============================] - 7s 11ms/step - loss: 53.0835 - reconstruction_loss: 39.9381 - kl_loss: 13.1789 - val_loss: 29.1396 - val_reconstruction_loss: 17.4990 - val_kl_loss: 11.6406
# Epoch 88/150
# 662/662 [==============================] - 7s 11ms/step - loss: 52.0591 - reconstruction_loss: 39.7678 - kl_loss: 13.1641 - val_loss: 37.5800 - val_reconstruction_loss: 26.0768 - val_kl_loss: 11.5032
# Epoch 89/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.8779 - reconstruction_loss: 39.7357 - kl_loss: 13.1758 - val_loss: 31.2756 - val_reconstruction_loss: 19.7693 - val_kl_loss: 11.5063
# Epoch 90/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.4610 - reconstruction_loss: 39.7598 - kl_loss: 13.1453 - val_loss: 40.9737 - val_reconstruction_loss: 29.4036 - val_kl_loss: 11.5701
# Epoch 91/150
# 662/662 [==============================] - 7s 11ms/step - loss: 52.8329 - reconstruction_loss: 39.5094 - kl_loss: 13.2046 - val_loss: 30.9378 - val_reconstruction_loss: 19.3769 - val_kl_loss: 11.5609
# Epoch 92/150
# 662/662 [==============================] - 8s 11ms/step - loss: 52.4741 - reconstruction_loss: 39.5425 - kl_loss: 13.1617 - val_loss: 29.7788 - val_reconstruction_loss: 18.2343 - val_kl_loss: 11.5444
# Epoch 93/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.9775 - reconstruction_loss: 39.5114 - kl_loss: 13.1610 - val_loss: 36.0480 - val_reconstruction_loss: 24.3807 - val_kl_loss: 11.6672
# Epoch 94/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.3496 - reconstruction_loss: 39.3969 - kl_loss: 13.2030 - val_loss: 31.9099 - val_reconstruction_loss: 20.3975 - val_kl_loss: 11.5124
# Epoch 95/150
# 662/662 [==============================] - 7s 11ms/step - loss: 52.2455 - reconstruction_loss: 39.3264 - kl_loss: 13.1455 - val_loss: 28.5073 - val_reconstruction_loss: 16.9727 - val_kl_loss: 11.5345
# Epoch 96/150
# 662/662 [==============================] - 8s 11ms/step - loss: 53.1349 - reconstruction_loss: 39.3810 - kl_loss: 13.1501 - val_loss: 37.0162 - val_reconstruction_loss: 25.4502 - val_kl_loss: 11.5660
# Epoch 97/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.6864 - reconstruction_loss: 39.2658 - kl_loss: 13.1388 - val_loss: 35.1692 - val_reconstruction_loss: 23.6303 - val_kl_loss: 11.5390
# Epoch 98/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.1703 - reconstruction_loss: 39.2257 - kl_loss: 13.1029 - val_loss: 29.5952 - val_reconstruction_loss: 18.0422 - val_kl_loss: 11.5530
# Epoch 99/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.8963 - reconstruction_loss: 39.2397 - kl_loss: 13.1460 - val_loss: 29.3538 - val_reconstruction_loss: 17.7594 - val_kl_loss: 11.5944
# Epoch 100/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.2593 - reconstruction_loss: 39.0766 - kl_loss: 13.1652 - val_loss: 28.6425 - val_reconstruction_loss: 17.1434 - val_kl_loss: 11.4991
# Epoch 101/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.5238 - reconstruction_loss: 39.3180 - kl_loss: 13.1307 - val_loss: 31.9400 - val_reconstruction_loss: 20.3202 - val_kl_loss: 11.6197
# Epoch 102/150
# 662/662 [==============================] - 8s 12ms/step - loss: 52.7015 - reconstruction_loss: 39.2916 - kl_loss: 13.1243 - val_loss: 34.0564 - val_reconstruction_loss: 22.4973 - val_kl_loss: 11.5592
# Epoch 103/150
# 662/662 [==============================] - 8s 11ms/step - loss: 52.3400 - reconstruction_loss: 38.9274 - kl_loss: 13.1416 - val_loss: 31.4803 - val_reconstruction_loss: 19.8809 - val_kl_loss: 11.5994
# Epoch 104/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.7489 - reconstruction_loss: 39.0262 - kl_loss: 13.1342 - val_loss: 27.8174 - val_reconstruction_loss: 16.2456 - val_kl_loss: 11.5718
# Epoch 105/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.4729 - reconstruction_loss: 38.7565 - kl_loss: 13.1707 - val_loss: 32.0826 - val_reconstruction_loss: 20.5079 - val_kl_loss: 11.5747
# Epoch 106/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.9417 - reconstruction_loss: 38.7356 - kl_loss: 13.1464 - val_loss: 30.9450 - val_reconstruction_loss: 19.3171 - val_kl_loss: 11.6279
# Epoch 107/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.8528 - reconstruction_loss: 38.8374 - kl_loss: 13.1604 - val_loss: 31.9028 - val_reconstruction_loss: 20.3295 - val_kl_loss: 11.5733
# Epoch 108/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.7552 - reconstruction_loss: 38.7437 - kl_loss: 13.1499 - val_loss: 28.2552 - val_reconstruction_loss: 16.6299 - val_kl_loss: 11.6252
# Epoch 109/150
# 662/662 [==============================] - 9s 13ms/step - loss: 51.1907 - reconstruction_loss: 38.6596 - kl_loss: 13.1293 - val_loss: 27.7844 - val_reconstruction_loss: 16.2059 - val_kl_loss: 11.5786
# Epoch 110/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.9661 - reconstruction_loss: 38.8705 - kl_loss: 13.0933 - val_loss: 27.4426 - val_reconstruction_loss: 15.8695 - val_kl_loss: 11.5731
# Epoch 111/150
# 662/662 [==============================] - 7s 11ms/step - loss: 51.8856 - reconstruction_loss: 38.6107 - kl_loss: 13.1118 - val_loss: 29.8706 - val_reconstruction_loss: 18.2721 - val_kl_loss: 11.5985
# Epoch 112/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.3331 - reconstruction_loss: 38.7876 - kl_loss: 13.1345 - val_loss: 29.7377 - val_reconstruction_loss: 18.0122 - val_kl_loss: 11.7255
# Epoch 113/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.1430 - reconstruction_loss: 38.4095 - kl_loss: 13.1576 - val_loss: 34.7692 - val_reconstruction_loss: 23.1328 - val_kl_loss: 11.6365
# Epoch 114/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.8312 - reconstruction_loss: 38.3488 - kl_loss: 13.1424 - val_loss: 32.5583 - val_reconstruction_loss: 20.9576 - val_kl_loss: 11.6007
# Epoch 115/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.9951 - reconstruction_loss: 38.5253 - kl_loss: 13.1064 - val_loss: 29.7985 - val_reconstruction_loss: 18.1763 - val_kl_loss: 11.6222
# Epoch 116/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.6014 - reconstruction_loss: 38.4382 - kl_loss: 13.1026 - val_loss: 33.8193 - val_reconstruction_loss: 22.0379 - val_kl_loss: 11.7814
# Epoch 117/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.7507 - reconstruction_loss: 38.7445 - kl_loss: 13.1549 - val_loss: 30.7313 - val_reconstruction_loss: 18.9846 - val_kl_loss: 11.7467
# Epoch 118/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.7038 - reconstruction_loss: 38.3558 - kl_loss: 13.1012 - val_loss: 34.6052 - val_reconstruction_loss: 22.9783 - val_kl_loss: 11.6269
# Epoch 119/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.5441 - reconstruction_loss: 38.2815 - kl_loss: 13.1259 - val_loss: 32.2655 - val_reconstruction_loss: 20.6935 - val_kl_loss: 11.5720
# Epoch 120/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.3595 - reconstruction_loss: 38.3952 - kl_loss: 13.1149 - val_loss: 31.7012 - val_reconstruction_loss: 20.0913 - val_kl_loss: 11.6099
# Epoch 121/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.7562 - reconstruction_loss: 38.1177 - kl_loss: 13.1042 - val_loss: 31.9981 - val_reconstruction_loss: 20.2861 - val_kl_loss: 11.7120
# Epoch 122/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.3050 - reconstruction_loss: 38.2834 - kl_loss: 13.0887 - val_loss: 34.0897 - val_reconstruction_loss: 22.5627 - val_kl_loss: 11.5270
# Epoch 123/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.4562 - reconstruction_loss: 38.2888 - kl_loss: 13.1084 - val_loss: 28.9123 - val_reconstruction_loss: 17.3134 - val_kl_loss: 11.5989
# Epoch 124/150
# 662/662 [==============================] - 8s 13ms/step - loss: 51.6007 - reconstruction_loss: 38.2264 - kl_loss: 13.1513 - val_loss: 29.2005 - val_reconstruction_loss: 17.4900 - val_kl_loss: 11.7105
# Epoch 125/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.5024 - reconstruction_loss: 38.1917 - kl_loss: 13.1447 - val_loss: 27.6865 - val_reconstruction_loss: 15.9701 - val_kl_loss: 11.7164
# Epoch 126/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.3558 - reconstruction_loss: 37.9648 - kl_loss: 13.1188 - val_loss: 31.2239 - val_reconstruction_loss: 19.5376 - val_kl_loss: 11.6862
# Epoch 127/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.5274 - reconstruction_loss: 38.0865 - kl_loss: 13.1278 - val_loss: 31.0028 - val_reconstruction_loss: 19.3006 - val_kl_loss: 11.7022
# Epoch 128/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.2179 - reconstruction_loss: 37.7957 - kl_loss: 13.1060 - val_loss: 34.7234 - val_reconstruction_loss: 23.0348 - val_kl_loss: 11.6885
# Epoch 129/150
# 662/662 [==============================] - 8s 13ms/step - loss: 50.7486 - reconstruction_loss: 37.7980 - kl_loss: 13.1304 - val_loss: 28.3912 - val_reconstruction_loss: 16.7273 - val_kl_loss: 11.6639
# Epoch 130/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.1700 - reconstruction_loss: 38.1200 - kl_loss: 13.1256 - val_loss: 31.2000 - val_reconstruction_loss: 19.5715 - val_kl_loss: 11.6286
# Epoch 131/150
# 662/662 [==============================] - 8s 11ms/step - loss: 50.8771 - reconstruction_loss: 37.7822 - kl_loss: 13.0870 - val_loss: 33.1068 - val_reconstruction_loss: 21.3635 - val_kl_loss: 11.7433
# Epoch 132/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.9054 - reconstruction_loss: 38.0139 - kl_loss: 13.0993 - val_loss: 30.9871 - val_reconstruction_loss: 19.2788 - val_kl_loss: 11.7083
# Epoch 133/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.3909 - reconstruction_loss: 37.8366 - kl_loss: 13.0967 - val_loss: 27.6858 - val_reconstruction_loss: 16.0228 - val_kl_loss: 11.6630
# Epoch 134/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.5009 - reconstruction_loss: 37.7600 - kl_loss: 13.1345 - val_loss: 32.1032 - val_reconstruction_loss: 20.4156 - val_kl_loss: 11.6876
# Epoch 135/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.1402 - reconstruction_loss: 37.8777 - kl_loss: 13.1095 - val_loss: 30.8028 - val_reconstruction_loss: 19.0633 - val_kl_loss: 11.7395
# Epoch 136/150
# 662/662 [==============================] - 7s 11ms/step - loss: 50.9271 - reconstruction_loss: 37.7864 - kl_loss: 13.1239 - val_loss: 29.0299 - val_reconstruction_loss: 17.2794 - val_kl_loss: 11.7505
# Epoch 137/150
# 662/662 [==============================] - 8s 11ms/step - loss: 51.3467 - reconstruction_loss: 37.7429 - kl_loss: 13.1542 - val_loss: 33.2480 - val_reconstruction_loss: 21.5541 - val_kl_loss: 11.6939
# Epoch 138/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.0157 - reconstruction_loss: 37.6472 - kl_loss: 13.1308 - val_loss: 35.7570 - val_reconstruction_loss: 24.0253 - val_kl_loss: 11.7316
# Epoch 139/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.5153 - reconstruction_loss: 37.4907 - kl_loss: 13.1293 - val_loss: 43.0792 - val_reconstruction_loss: 31.3143 - val_kl_loss: 11.7649
# Epoch 140/150
# 662/662 [==============================] - 8s 11ms/step - loss: 50.7101 - reconstruction_loss: 37.5368 - kl_loss: 13.0927 - val_loss: 33.0656 - val_reconstruction_loss: 21.2808 - val_kl_loss: 11.7848
# Epoch 141/150
# 662/662 [==============================] - 8s 11ms/step - loss: 49.6423 - reconstruction_loss: 37.3446 - kl_loss: 13.0963 - val_loss: 40.4056 - val_reconstruction_loss: 28.5735 - val_kl_loss: 11.8321
# Epoch 142/150
# 662/662 [==============================] - 8s 12ms/step - loss: 51.0910 - reconstruction_loss: 37.6245 - kl_loss: 13.1316 - val_loss: 28.2996 - val_reconstruction_loss: 16.6278 - val_kl_loss: 11.6717
# Epoch 143/150
# 662/662 [==============================] - 7s 11ms/step - loss: 50.6080 - reconstruction_loss: 37.4459 - kl_loss: 13.1079 - val_loss: 35.8852 - val_reconstruction_loss: 24.0891 - val_kl_loss: 11.7961
# Epoch 144/150
# 662/662 [==============================] - 7s 11ms/step - loss: 50.6822 - reconstruction_loss: 37.4505 - kl_loss: 13.0994 - val_loss: 31.8878 - val_reconstruction_loss: 20.1826 - val_kl_loss: 11.7053
# Epoch 145/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.9885 - reconstruction_loss: 37.4032 - kl_loss: 13.1294 - val_loss: 28.3764 - val_reconstruction_loss: 16.7089 - val_kl_loss: 11.6676
# Epoch 146/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.2657 - reconstruction_loss: 37.4825 - kl_loss: 13.1210 - val_loss: 29.6294 - val_reconstruction_loss: 17.9699 - val_kl_loss: 11.6595
# Epoch 147/150
# 662/662 [==============================] - 7s 11ms/step - loss: 50.1795 - reconstruction_loss: 37.3928 - kl_loss: 13.1384 - val_loss: 30.0176 - val_reconstruction_loss: 18.2972 - val_kl_loss: 11.7204
# Epoch 148/150
# 662/662 [==============================] - 7s 11ms/step - loss: 50.5164 - reconstruction_loss: 37.4325 - kl_loss: 13.1194 - val_loss: 29.3535 - val_reconstruction_loss: 17.7091 - val_kl_loss: 11.6444
# Epoch 149/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.4799 - reconstruction_loss: 37.3245 - kl_loss: 13.0835 - val_loss: 35.1996 - val_reconstruction_loss: 23.3870 - val_kl_loss: 11.8127
# Epoch 150/150
# 662/662 [==============================] - 8s 12ms/step - loss: 50.3484 - reconstruction_loss: 37.3593 - kl_loss: 13.1015 - val_loss: 30.7291 - val_reconstruction_loss: 19.0376 - val_kl_loss: 11.6915
# Epoch 1/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.1851 - reconstruction_loss: 37.1089 - kl_loss: 13.0810 - val_loss: 28.9128 - val_reconstruction_loss: 17.1887 - val_kl_loss: 11.7241
# Epoch 2/300
# 662/662 [==============================] - 7s 11ms/step - loss: 51.3064 - reconstruction_loss: 37.3844 - kl_loss: 13.1041 - val_loss: 29.2779 - val_reconstruction_loss: 17.5496 - val_kl_loss: 11.7283
# Epoch 3/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.5799 - reconstruction_loss: 37.2995 - kl_loss: 13.0967 - val_loss: 33.1329 - val_reconstruction_loss: 21.4398 - val_kl_loss: 11.6931
# Epoch 4/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.1563 - reconstruction_loss: 37.2073 - kl_loss: 13.0721 - val_loss: 31.0479 - val_reconstruction_loss: 19.3142 - val_kl_loss: 11.7337
# Epoch 5/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.9478 - reconstruction_loss: 37.2328 - kl_loss: 13.1268 - val_loss: 31.3364 - val_reconstruction_loss: 19.5892 - val_kl_loss: 11.7471
# Epoch 6/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.3148 - reconstruction_loss: 37.1984 - kl_loss: 13.1286 - val_loss: 36.3221 - val_reconstruction_loss: 24.5038 - val_kl_loss: 11.8184
# Epoch 7/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.9105 - reconstruction_loss: 37.3386 - kl_loss: 13.1200 - val_loss: 29.7863 - val_reconstruction_loss: 18.0042 - val_kl_loss: 11.7822
# Epoch 8/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.8862 - reconstruction_loss: 37.1288 - kl_loss: 13.1319 - val_loss: 30.8392 - val_reconstruction_loss: 19.1287 - val_kl_loss: 11.7105
# Epoch 9/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.5158 - reconstruction_loss: 37.3872 - kl_loss: 13.1053 - val_loss: 29.7531 - val_reconstruction_loss: 17.9776 - val_kl_loss: 11.7755
# Epoch 10/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.7878 - reconstruction_loss: 37.2219 - kl_loss: 13.1239 - val_loss: 32.1739 - val_reconstruction_loss: 20.5129 - val_kl_loss: 11.6610
# Epoch 11/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.1654 - reconstruction_loss: 37.2343 - kl_loss: 13.1084 - val_loss: 34.5271 - val_reconstruction_loss: 22.7164 - val_kl_loss: 11.8107
# Epoch 12/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.1829 - reconstruction_loss: 37.1665 - kl_loss: 13.1611 - val_loss: 26.7002 - val_reconstruction_loss: 14.9251 - val_kl_loss: 11.7752
# Epoch 13/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.4999 - reconstruction_loss: 37.2213 - kl_loss: 13.1361 - val_loss: 39.7102 - val_reconstruction_loss: 27.9899 - val_kl_loss: 11.7203
# Epoch 14/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.9120 - reconstruction_loss: 37.2870 - kl_loss: 13.1337 - val_loss: 29.1279 - val_reconstruction_loss: 17.3820 - val_kl_loss: 11.7459
# Epoch 15/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.0424 - reconstruction_loss: 37.1296 - kl_loss: 13.1116 - val_loss: 32.0648 - val_reconstruction_loss: 20.3144 - val_kl_loss: 11.7504
# Epoch 16/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.6836 - reconstruction_loss: 36.9393 - kl_loss: 13.1025 - val_loss: 32.5314 - val_reconstruction_loss: 20.9334 - val_kl_loss: 11.5980
# Epoch 17/300
# 662/662 [==============================] - 8s 13ms/step - loss: 49.6667 - reconstruction_loss: 36.9701 - kl_loss: 13.1020 - val_loss: 28.6385 - val_reconstruction_loss: 16.8565 - val_kl_loss: 11.7821
# Epoch 18/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.0540 - reconstruction_loss: 36.9537 - kl_loss: 13.1506 - val_loss: 28.8006 - val_reconstruction_loss: 17.0104 - val_kl_loss: 11.7901
# Epoch 19/300
# 662/662 [==============================] - 8s 11ms/step - loss: 50.4098 - reconstruction_loss: 36.8827 - kl_loss: 13.1379 - val_loss: 35.4269 - val_reconstruction_loss: 23.5422 - val_kl_loss: 11.8847
# Epoch 20/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.8883 - reconstruction_loss: 36.9728 - kl_loss: 13.1337 - val_loss: 28.6924 - val_reconstruction_loss: 16.9834 - val_kl_loss: 11.7090
# Epoch 21/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.6170 - reconstruction_loss: 36.8952 - kl_loss: 13.0911 - val_loss: 27.3419 - val_reconstruction_loss: 15.6563 - val_kl_loss: 11.6856
# Epoch 22/300
# 662/662 [==============================] - 8s 11ms/step - loss: 50.0670 - reconstruction_loss: 37.0787 - kl_loss: 13.0855 - val_loss: 35.2553 - val_reconstruction_loss: 23.5604 - val_kl_loss: 11.6948
# Epoch 23/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.9240 - reconstruction_loss: 36.9568 - kl_loss: 13.0981 - val_loss: 32.3667 - val_reconstruction_loss: 20.6638 - val_kl_loss: 11.7029
# Epoch 24/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.8832 - reconstruction_loss: 36.8098 - kl_loss: 13.1055 - val_loss: 32.5414 - val_reconstruction_loss: 20.8303 - val_kl_loss: 11.7110
# Epoch 25/300
# 662/662 [==============================] - 8s 13ms/step - loss: 50.9306 - reconstruction_loss: 37.0579 - kl_loss: 13.1166 - val_loss: 26.5078 - val_reconstruction_loss: 14.8253 - val_kl_loss: 11.6825
# Epoch 26/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.8677 - reconstruction_loss: 36.7993 - kl_loss: 13.0701 - val_loss: 36.1933 - val_reconstruction_loss: 24.4485 - val_kl_loss: 11.7448
# Epoch 27/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.1623 - reconstruction_loss: 36.7275 - kl_loss: 13.0838 - val_loss: 26.7842 - val_reconstruction_loss: 15.1460 - val_kl_loss: 11.6382
# Epoch 28/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.3350 - reconstruction_loss: 36.8433 - kl_loss: 13.1144 - val_loss: 33.3966 - val_reconstruction_loss: 21.4558 - val_kl_loss: 11.9408
# Epoch 29/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.0665 - reconstruction_loss: 36.9060 - kl_loss: 13.1155 - val_loss: 38.0483 - val_reconstruction_loss: 26.2234 - val_kl_loss: 11.8248
# Epoch 30/300
# 662/662 [==============================] - 9s 13ms/step - loss: 50.2504 - reconstruction_loss: 36.9064 - kl_loss: 13.0811 - val_loss: 27.5235 - val_reconstruction_loss: 15.8258 - val_kl_loss: 11.6977
# Epoch 31/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.7181 - reconstruction_loss: 36.7922 - kl_loss: 13.1107 - val_loss: 31.8239 - val_reconstruction_loss: 20.0129 - val_kl_loss: 11.8110
# Epoch 32/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.4458 - reconstruction_loss: 36.8444 - kl_loss: 13.1230 - val_loss: 28.0521 - val_reconstruction_loss: 16.3156 - val_kl_loss: 11.7365
# Epoch 33/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.9922 - reconstruction_loss: 36.8640 - kl_loss: 13.1296 - val_loss: 38.4051 - val_reconstruction_loss: 26.6645 - val_kl_loss: 11.7406
# Epoch 34/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.7064 - reconstruction_loss: 36.7241 - kl_loss: 13.0970 - val_loss: 32.5228 - val_reconstruction_loss: 20.7341 - val_kl_loss: 11.7887
# Epoch 35/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.8072 - reconstruction_loss: 36.5723 - kl_loss: 13.0978 - val_loss: 26.4091 - val_reconstruction_loss: 14.7952 - val_kl_loss: 11.6139
# Epoch 36/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.8329 - reconstruction_loss: 36.7868 - kl_loss: 13.0908 - val_loss: 27.1967 - val_reconstruction_loss: 15.5181 - val_kl_loss: 11.6786
# Epoch 37/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.8519 - reconstruction_loss: 36.6838 - kl_loss: 13.0965 - val_loss: 28.2094 - val_reconstruction_loss: 16.4906 - val_kl_loss: 11.7188
# Epoch 38/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.1261 - reconstruction_loss: 36.9604 - kl_loss: 13.0996 - val_loss: 30.2492 - val_reconstruction_loss: 18.4500 - val_kl_loss: 11.7992
# Epoch 39/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.7878 - reconstruction_loss: 36.7903 - kl_loss: 13.1373 - val_loss: 29.6940 - val_reconstruction_loss: 17.9008 - val_kl_loss: 11.7932
# Epoch 40/300
# 662/662 [==============================] - 8s 13ms/step - loss: 49.7682 - reconstruction_loss: 36.6193 - kl_loss: 13.1143 - val_loss: 30.1420 - val_reconstruction_loss: 18.3949 - val_kl_loss: 11.7471
# Epoch 41/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.0802 - reconstruction_loss: 36.7600 - kl_loss: 13.0905 - val_loss: 31.9017 - val_reconstruction_loss: 20.1183 - val_kl_loss: 11.7834
# Epoch 42/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.2938 - reconstruction_loss: 36.6185 - kl_loss: 13.1096 - val_loss: 28.9652 - val_reconstruction_loss: 17.1998 - val_kl_loss: 11.7654
# Epoch 43/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.3385 - reconstruction_loss: 36.5957 - kl_loss: 13.0806 - val_loss: 38.3324 - val_reconstruction_loss: 26.5344 - val_kl_loss: 11.7980
# Epoch 44/300
# 662/662 [==============================] - 8s 11ms/step - loss: 50.7272 - reconstruction_loss: 36.7206 - kl_loss: 13.1022 - val_loss: 28.0282 - val_reconstruction_loss: 16.2094 - val_kl_loss: 11.8188
# Epoch 45/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.5911 - reconstruction_loss: 36.5911 - kl_loss: 13.1066 - val_loss: 30.2563 - val_reconstruction_loss: 18.3482 - val_kl_loss: 11.9081
# Epoch 46/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.7102 - reconstruction_loss: 36.6275 - kl_loss: 13.1200 - val_loss: 27.7720 - val_reconstruction_loss: 16.0543 - val_kl_loss: 11.7177
# Epoch 47/300
# 662/662 [==============================] - 8s 12ms/step - loss: 50.4743 - reconstruction_loss: 36.6939 - kl_loss: 13.0783 - val_loss: 32.0766 - val_reconstruction_loss: 20.3127 - val_kl_loss: 11.7639
# Epoch 48/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.5705 - reconstruction_loss: 36.5903 - kl_loss: 13.1303 - val_loss: 29.2273 - val_reconstruction_loss: 17.4588 - val_kl_loss: 11.7685
# Epoch 49/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.6895 - reconstruction_loss: 36.7103 - kl_loss: 13.0800 - val_loss: 31.9274 - val_reconstruction_loss: 20.1318 - val_kl_loss: 11.7956
# Epoch 50/300
# 662/662 [==============================] - 7s 11ms/step - loss: 50.0519 - reconstruction_loss: 36.4631 - kl_loss: 13.1052 - val_loss: 34.7061 - val_reconstruction_loss: 22.9674 - val_kl_loss: 11.7387
# Epoch 51/300
# 662/662 [==============================] - 9s 13ms/step - loss: 49.8531 - reconstruction_loss: 36.4784 - kl_loss: 13.0848 - val_loss: 30.5752 - val_reconstruction_loss: 18.8784 - val_kl_loss: 11.6967
# Epoch 52/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.3316 - reconstruction_loss: 36.7870 - kl_loss: 13.0823 - val_loss: 28.9102 - val_reconstruction_loss: 17.0545 - val_kl_loss: 11.8557
# Epoch 53/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.9248 - reconstruction_loss: 36.6320 - kl_loss: 13.1023 - val_loss: 29.4862 - val_reconstruction_loss: 17.6523 - val_kl_loss: 11.8339
# Epoch 54/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.7221 - reconstruction_loss: 36.5906 - kl_loss: 13.1217 - val_loss: 29.3032 - val_reconstruction_loss: 17.5299 - val_kl_loss: 11.7733
# Epoch 55/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.4503 - reconstruction_loss: 36.3437 - kl_loss: 13.1488 - val_loss: 34.5042 - val_reconstruction_loss: 22.7637 - val_kl_loss: 11.7405
# Epoch 56/300
# 662/662 [==============================] - 9s 13ms/step - loss: 48.8236 - reconstruction_loss: 36.4834 - kl_loss: 13.1216 - val_loss: 29.0269 - val_reconstruction_loss: 17.2203 - val_kl_loss: 11.8066
# Epoch 57/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.3021 - reconstruction_loss: 36.6061 - kl_loss: 13.0999 - val_loss: 30.3392 - val_reconstruction_loss: 18.4593 - val_kl_loss: 11.8799
# Epoch 58/300
# 662/662 [==============================] - 8s 11ms/step - loss: 49.8372 - reconstruction_loss: 36.5777 - kl_loss: 13.1291 - val_loss: 29.8351 - val_reconstruction_loss: 18.0034 - val_kl_loss: 11.8318
# Epoch 59/300
# 662/662 [==============================] - 8s 11ms/step - loss: 48.6861 - reconstruction_loss: 36.3757 - kl_loss: 13.1277 - val_loss: 39.3881 - val_reconstruction_loss: 27.6044 - val_kl_loss: 11.7837
# Epoch 60/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.8417 - reconstruction_loss: 36.6222 - kl_loss: 13.1248 - val_loss: 26.9975 - val_reconstruction_loss: 15.2500 - val_kl_loss: 11.7476
# Epoch 61/300
# 662/662 [==============================] - 7s 11ms/step - loss: 49.3913 - reconstruction_loss: 36.3407 - kl_loss: 13.1349 - val_loss: 29.5643 - val_reconstruction_loss: 17.7043 - val_kl_loss: 11.8600
# Epoch 62/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.6800 - reconstruction_loss: 36.4403 - kl_loss: 13.1108 - val_loss: 30.4565 - val_reconstruction_loss: 18.7489 - val_kl_loss: 11.7075
# Epoch 63/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.1890 - reconstruction_loss: 36.3832 - kl_loss: 13.0947 - val_loss: 33.0699 - val_reconstruction_loss: 21.2564 - val_kl_loss: 11.8134
# Epoch 64/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.6762 - reconstruction_loss: 36.4791 - kl_loss: 13.1399 - val_loss: 28.9480 - val_reconstruction_loss: 17.1206 - val_kl_loss: 11.8274
# Epoch 65/300
# 662/662 [==============================] - 8s 12ms/step - loss: 49.1719 - reconstruction_loss: 36.3756 - kl_loss: 13.1266 - val_loss: 28.9694 - val_reconstruction_loss: 17.2394 - val_kl_loss: 11.7300

# %% [markdown]
# ## Example of prediction on the test set

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(30,20))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()

# %%
_, _, encoded_data = encoder(X_test) 
predictions = decoder(encoded_data)

for l in range(M-1):
    _, _, encoded_data = encoder(X_test) 
    reconstruction = decoder(encoded_data)
    predictions = predictions + reconstruction
    
predictions = predictions/M
print(predictions.shape)
# Out:
# (1921, 672, 3)

# %%
def inspect_multivariate_prediction(X, y, a, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(pred))

    figs, axs = plt.subplots(len(columns) + 1, 1, sharex=True, figsize=(17,10))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
           
    axs[len(columns)].plot(np.arange(len(X[0,:,i])), a[idx,:])
    axs[len(columns)].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope, ), a[idx,:])
    axs[len(columns)].set_title('Anomaly')
    plt.show()

# %%
# Plotting predictions
target_labels = X_test_raw.columns
inspect_multivariate_prediction(X_test, X_test, A_test, predictions, target_labels, window)

# %% [markdown]
# ## Computing reconstruction error

# %%
# Function used to create non-overlapped windows starting from the TRAINING set
def build_sequences_reconstruction(df, window, stride):
    dataset = []
    temp_df = df.copy().values
    padding_len = (len(df)-window)%stride

    for idx in np.arange(0,len(temp_df)-window+1,stride):
        dataset.append(temp_df[idx:idx+window])

    dataset = np.array(dataset)
    return dataset

# %%
# Non overlapped windows - Training set
X_train_non_overlapped_P1 = build_sequences_reconstruction(X_train_raw_P1, window=window, stride=window)
X_train_non_overlapped_P2 = build_sequences_reconstruction(X_train_raw_P2, window=window, stride=window)

X_train_non_overlapped = np.concatenate([X_train_non_overlapped_P1,X_train_non_overlapped_P2],axis=0)

X_train_non_overlapped.shape
# Out:
# (65, 672, 3)

# %%
# Overlapped windows - Test set
X_test_overlapped = build_sequences_reconstruction(X_test_raw, window=window, stride=stride)
X_test_overlapped.shape
# Out:
# (1921, 672, 3)

# %%
# Making predictions on non-overlapped windows of the training set
encoded_data = encoder(X_train_non_overlapped)[-1]
print(encoded_data.shape)
train_reconstructions = decoder(encoded_data)
print(train_reconstructions.shape)

for l in range(M-1):
    encoded_data = encoder(X_train_non_overlapped)[-1]
    train_prediction = decoder(encoded_data)
    train_reconstructions = train_prediction + train_reconstructions
    
train_reconstructions = train_reconstructions/M
print(train_reconstructions.shape)
# Out:
# (65, 4)
# (65, 672, 3)
# (65, 672, 3)

# %%
# Making predictions on overlapped windows of the test set
encoded_data = encoder(X_test_overlapped)[-1]
print(encoded_data.shape)
test_reconstructions = decoder(encoded_data)
print(test_reconstructions.shape)

for l in range(M-1):
    encoded_data = encoder(X_test_overlapped)[-1]
    test_prediction = decoder(encoded_data)
    test_reconstructions = test_prediction + test_reconstructions
    
test_reconstructions = test_reconstructions/M
print(test_reconstructions.shape)
# Out:
# (1921, 4)
# (1921, 672, 3)
# (1921, 672, 3)

# %%
# Computing reconstruction error - Test set (redundant data because of overlapping)
rec_error = np.abs(X_test_overlapped-test_reconstructions) # || True - Predicted ||
rec_error.shape
# Out:
# (1921, 672, 3)

# %%
# Function used to plot predictions (reconstructions) made on training data using the model
def inspect_multivariate_prediction_reconstruction(X, y, a, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(pred))
        print('Plotting sequence number: ' + str(idx))

    figs, axs = plt.subplots(3, 1, sharex=True, figsize=(17,7))
    for i, col in enumerate(columns[:4]):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
    plt.show()

# %%
# Plotting reconstructions of the TRAINING set
inspect_multivariate_prediction_reconstruction(X_train_non_overlapped, X_train_non_overlapped, A_train, train_reconstructions, target_labels, window)
# Out:
# Plotting sequence number: 26

# %%
# Array that will contain reconstruction errors (floor by floor) - TRAINING SET
reconstruction_errors = np.empty(shape=(0, 2))

# Computing reconstruction errors
for i in range(X_train_non_overlapped.shape[0]):
    error = np.abs(X_train_non_overlapped[i]-train_reconstructions[i])
    error = error[:,:2] # Not interested in the day of the week
    reconstruction_errors = np.concatenate((reconstruction_errors,error), axis=0)
    
mean_error = np.mean(reconstruction_errors, axis = 0) # Mean reconstruction error
std_error = np.std(reconstruction_errors, axis = 0) # Std dev of the reconstruction error
max_error = np.max(reconstruction_errors, axis = 0) # Max error on the training set
  
print(reconstruction_errors.shape)
print(mean_error)
print(std_error)
print(max_error)
# Out:
# (43680, 2)
# [0.20308083 0.20393365]
# [0.19294389 0.19273215]
# [1.87506831 1.85382974]

# %%
# Array that will contain reconstruction errors (floor by floor) - TEST SET

reconstruction_test = np.empty(shape=(0, 2)) # Predictions made on the test set using the model
reconstruction_errors_test = np.empty(shape=(0, 2)) # Errors made in predicting the test set

# First window
i = 0
error = np.abs(X_test_overlapped[i]-test_reconstructions[i])
error = error[:,:2] # Not interested in the day of the week
reconstruction_errors_test = np.concatenate((reconstruction_errors_test,error), axis=0)
reconstruction_test = np.concatenate((reconstruction_test, test_reconstructions[i,:,:2]), axis=0)
print(reconstruction_errors_test.shape)
print(reconstruction_test.shape)

# For all the windows following the first one we need to consider only the last "stride" elements
for i in range(1,X_test_overlapped.shape[0]):
    error = np.abs(X_test_overlapped[i,-stride:,:]-test_reconstructions[i,-stride:,:])
    error = error[:,:2] # Not interested in the day of the week
    reconstruction_errors_test = np.concatenate((reconstruction_errors_test,error), axis=0)
    reconstruction_test = np.concatenate((reconstruction_test, test_reconstructions[i,-stride:,:2]), axis=0)
                                        
print(reconstruction_errors_test.shape)
print(reconstruction_test.shape)
# Out:
# (672, 2)
# (672, 2)
# (16032, 2)
# (16032, 2)

# %%
# Function used to predict anomalies
def predict_anomalies(reconstruction_errors, error_threshold):
    
    # Inizially we don't have predicted anomalies
    anomaly_predicted = np.zeros(shape=(X_test_raw.shape[0]))
    
    # First window
    i = 0 # We start from element 0 of the test set
    seq = reconstruction_errors[0] # We start from the first window of the test set 
    for sample in seq: 
        epsilon = sample[:2] - error_threshold # We check if the reconstruction error is greater than the threshold
        if any(x>0 for x in epsilon) == True:
            anomaly_predicted[i] = 1
        i = i+1
            
    # Sequences following the first one
    for s in range(1, reconstruction_errors.shape[0]):
        for k in range (reconstruction_errors.shape[1]-stride, reconstruction_errors.shape[1]): # k in [672-stride, 672]         
            epsilon = reconstruction_errors[s,k,:2] - error_threshold # We check if the reconstruction error is greater than the threshold
            if any(x>0 for x in epsilon) == True:
                anomaly_predicted[i] = 1
            i = i+1 

    return anomaly_predicted

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Grid search threshold parameters

range_of_val = [x for x in np.arange(4, 8, 0.1)]
best_val = [0,0]
F1_MAX = 0

for i in range_of_val:
    for j in range_of_val:
        threshold_error_mean_std_TEMP = 0
        threshold_error_mean_std_TEMP = mean_error + [i,j]*std_error # mean + n*std_dev
        anomaly_predicted_mean_std_TEMP = 0
        anomaly_predicted_mean_std_TEMP = predict_anomalies(rec_error, threshold_error_mean_std_TEMP)
        f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted_mean_std_TEMP)
        if(f1>F1_MAX):
            F1_MAX = f1
            best_val = [i,j]
            print("best threshold parameters: " + str(best_val) + " best f1: " + str(F1_MAX))
            
threshold_error_mean_std = mean_error + [best_val[0],best_val[1]]*std_error # mean + n*std_dev
anomaly_predicted_mean_std = predict_anomalies(rec_error, threshold_error_mean_std)
                
threshold_error_max = max_error # Max error on the training set
anomaly_predicted_max = predict_anomalies(rec_error, threshold_error_max)

anomaly_predicted_mean_std.sum(), anomaly_predicted_max.sum(), anomaly_predicted_mean_std.shape, anomaly_predicted_max.shape, threshold_error_mean_std, threshold_error_max
# Out:
# best threshold parameters: [4.0, 4.0] best f1: 0.48126232741617353
# best threshold parameters: [4.0, 4.1] best f1: 0.4879679144385026
# best threshold parameters: [4.1, 4.199999999999999] best f1: 0.4899095337508698
# best threshold parameters: [4.199999999999999, 4.1] best f1: 0.49198606271777
# best threshold parameters: [4.199999999999999, 4.199999999999999] best f1: 0.4953604568165596
# best threshold parameters: [4.199999999999999, 4.299999999999999] best f1: 0.4992700729927007
# best threshold parameters: [4.199999999999999, 4.399999999999999] best f1: 0.5011021307861866
# best threshold parameters: [4.199999999999999, 4.499999999999998] best f1: 0.5014705882352941
# best threshold parameters: [4.299999999999999, 4.299999999999999] best f1: 0.5026022304832714
# best threshold parameters: [4.299999999999999, 4.399999999999999] best f1: 0.5083459787556904
# best threshold parameters: [4.399999999999999, 4.399999999999999] best f1: 0.5159285159285159
# best threshold parameters: [4.399999999999999, 4.499999999999998] best f1: 0.5201581027667985
# best threshold parameters: [4.399999999999999, 4.599999999999998] best f1: 0.5202863961813843
# best threshold parameters: [4.399999999999999, 4.6999999999999975] best f1: 0.5207006369426751
# best threshold parameters: [4.499999999999998, 4.399999999999999] best f1: 0.5229793977812995
# best threshold parameters: [4.499999999999998, 4.499999999999998] best f1: 0.5308441558441558
# best threshold parameters: [4.499999999999998, 4.599999999999998] best f1: 0.5363036303630363
# best threshold parameters: [4.599999999999998, 4.499999999999998] best f1: 0.5378289473684211
# best threshold parameters: [4.599999999999998, 4.599999999999998] best f1: 0.5449957947855341
# best threshold parameters: [4.599999999999998, 4.6999999999999975] best f1: 0.5485519591141397
# best threshold parameters: [4.6999999999999975, 4.599999999999998] best f1: 0.550552251486831
# best threshold parameters: [4.6999999999999975, 4.6999999999999975] best f1: 0.5558441558441558
# best threshold parameters: [4.6999999999999975, 4.799999999999997] best f1: 0.5588752196836555
# best threshold parameters: [4.799999999999997, 4.799999999999997] best f1: 0.5612153708668454
# best threshold parameters: [4.899999999999997, 4.799999999999997] best f1: 0.5647058823529413
# best threshold parameters: [4.9999999999999964, 4.799999999999997] best f1: 0.5683060109289618
# best threshold parameters: [4.9999999999999964, 5.099999999999996] best f1: 0.5689488910318226
# best threshold parameters: [4.9999999999999964, 5.199999999999996] best f1: 0.5705996131528046
# best threshold parameters: [5.099999999999996, 5.199999999999996] best f1: 0.5736738703339882
# best threshold parameters: [5.199999999999996, 5.299999999999995] best f1: 0.5754527162977867
# best threshold parameters: [5.199999999999996, 5.399999999999995] best f1: 0.5763397371081901
# best threshold parameters: [5.299999999999995, 5.299999999999995] best f1: 0.5781409601634321
# best threshold parameters: [5.299999999999995, 5.399999999999995] best f1: 0.579381443298969
# best threshold parameters: [5.399999999999995, 5.199999999999996] best f1: 0.5795339412360688
# best threshold parameters: [5.499999999999995, 5.399999999999995] best f1: 0.5798319327731093
# best threshold parameters: [5.599999999999994, 5.399999999999995] best f1: 0.5822784810126582
# best threshold parameters: [5.699999999999994, 5.399999999999995] best f1: 0.5828933474128828
# (404.0,
#  88.0,
#  (16032,),
#  (16032,),
#  array([1.30286101, 1.24468725]),
#  array([1.87506831, 1.85382974]))

# %%
padding_len = (len(X_test_raw)-window)%stride
size = X_test_raw.shape[0]-padding_len
X_test_raw = X_test_raw[:size]
X_test_raw.shape[1]
# Out:
# 3

# %%
# Adding predictions and predicted anomalies to X_test_raw
X_test_raw['Reconstr_1_Floor'] = reconstruction_test[:,0] # Prediction on floor 1
X_test_raw['Reconstr_2_Floor'] = reconstruction_test[:,1] # Prediction on floor 2
X_test_raw['Anomaly_Label_GT'] = Anomaly_Test # Ground truth anomalies
X_test_raw['Anomaly_Predicted_Mean_Std'] = anomaly_predicted_mean_std[:X_test_raw.shape[0]] # Anomalies predicted using mean and std dev
X_test_raw['Anomaly_Predicted_Max'] = anomaly_predicted_max[:X_test_raw.shape[0]] # Anomalies predicted using max error on the training set
X_test_raw['Error_1_Floor'] = reconstruction_errors_test[:,0] # Prediction error on floor 1
X_test_raw['Error_2_Floor'] = reconstruction_errors_test[:,1] # Prediction error on floor 2
X_test_raw.head()
# Out:
#        CB_First_Floor  CB_Second_Floor  Day_Of_The_Week  Reconstr_1_Floor  \
# 59808       -0.110053        -0.145436              0.0         -0.780237
# 59809       -0.110053        -0.145436              0.0         -1.087014
# 59810       -0.110053        -0.093767              0.0         -0.958072
# 59811       -0.161507        -0.145436              0.0         -0.795215
# 59812       -0.161507        -0.145436              0.0         -0.936466
#
#        Reconstr_2_Floor  Anomaly_Label_GT  Anomaly_Predicted_Mean_Std  \
# 59808         -0.779426               0.0                         0.0
# 59809         -1.090354               0.0                         0.0
# 59810         -0.957340               0.0                         0.0
# 59811         -0.798554               0.0                         0.0
# 59812         -0.933949               0.0                         0.0
#
#        Anomaly_Predicted_Max  Error_1_Floor  Error_2_Floor
# 59808                    0.0       0.670184       0.633989
# 59809                    0.0       0.976960       0.944918
# 59810                    0.0       0.848019       0.863573
# 59811                    0.0       0.633708       0.653118
# 59812                    0.0       0.774959       0.788512

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(30,20))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()

# %%
# Plotting reconstructions for a check
import datetime as dt

i=89 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# %%
def inspect_multivariate_prediction(X, y, a_true, a_predicted_mean_std, a_predicted_max, pred, columns, error_1F, error_2F): 
   
    figs, axs = plt.subplots(7, 1, sharex=True, figsize=(17,17)) 
    for i, col in enumerate(columns[:2]): 
        axs[i].plot(np.arange(len(X[:,i])), X[:,i]) 
        axs[i].plot(np.arange(len(X[:,i]), len(X[:,i])*2), y[:,i], color='orange') 
        axs[i].plot(np.arange(len(X[:,i]), len(X[:,i])*2), pred[:,i], color='green') 
        axs[i].set_title(col) 
        
    axs[2].plot(np.arange(len(X[:,i])), error_1F) 
    axs[2].plot(np.arange(len(X[:,i]), len(X[:,i])*2), error_1F) 
    axs[2].set_title('error_1F') 
     
    axs[3].plot(np.arange(len(X[:,i])), error_2F) 
    axs[3].plot(np.arange(len(X[:,i]), len(X[:,i])*2), error_2F) 
    axs[3].set_title('error_2F') 
            
    axs[4].plot(np.arange(len(X[:,i])), a_true) 
    axs[4].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_true) 
    axs[4].set_title('Anomaly_True') 
    
    axs[5].plot(np.arange(len(X[:,i])), a_predicted_mean_std) 
    axs[5].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_predicted_mean_std) 
    axs[5].set_title('Anomaly_Predicted_Mean_Std_Dev')
    
    axs[6].plot(np.arange(len(X[:,i])), a_predicted_max) 
    axs[6].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_predicted_max) 
    axs[6].set_title('Anomaly_Predicted_Max') 
    plt.show()

# %%
# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
anomaly_predicted = anomaly_predicted_mean_std

# Compute the confusion matrix
cm = confusion_matrix(y_true=Anomaly_Test, y_pred=anomaly_predicted)

# Compute the classification metrics
accuracy = accuracy_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
precision = precision_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
recall = recall_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Accuracy: 0.9754
# Precision: 0.6832
# Recall: 0.5083
# F1: 0.5829

# %%
anomaly_predicted = anomaly_predicted_max

# Compute the confusion matrix
cm = confusion_matrix(y_true=Anomaly_Test, y_pred=anomaly_predicted)

# Compute the classification metrics
accuracy = accuracy_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
precision = precision_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
recall = recall_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Accuracy: 0.9712
# Precision: 0.9659
# Recall: 0.1565
# F1: 0.2694
