# %%
# Importing libraries

import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import itertools as it
import matplotlib.pyplot as plt

from datetime import datetime
from scipy.stats import multivariate_normal
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

plt.rc('font', size=16)

import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers

# Setting random seed for reproducibility

seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# 2022-10-22 08:09:23.091527: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:23.286069: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:23.287049: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:23.288989: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-22 08:09:23.294274: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:23.295006: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:23.295686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:25.900901: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:25.901787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:25.902450: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-22 08:09:25.903109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Opening the dataframe
ABB_data = pd.read_csv('../input/electricity-demand/Multivariate_Labeled_2.csv', parse_dates=['DateTime'], delimiter=',')
ABB_data.drop(columns="DateTime", inplace=True)
ABB_data
# Out:
#        CB_First_Floor  CB_Second_Floor   AvgT   AvgH  Anomaly_Label    Year  \
# 0                37.0             36.0   4.70  80.40            0.0  2017.0
# 1                32.0             33.0   4.75  79.35            0.0  2017.0
# 2                32.0             32.0   4.60  78.90            0.0  2017.0
# 3                32.0             33.0   4.50  79.25            0.0  2017.0
# 4                33.0             33.0   4.40  80.40            0.0  2017.0
# ...               ...              ...    ...    ...            ...     ...
# 75835            41.0             41.0  10.95  83.25            0.0  2019.0
# 75836            42.0             42.0  10.80  84.60            0.0  2019.0
# 75837            43.0             43.0  10.65  86.05            0.0  2019.0
# 75838            42.0             42.0  10.30  86.90            0.0  2019.0
# 75839            42.0             42.0   9.95  87.80            0.0  2019.0
#
#        Month  Day  Hour   Min  Sec  Day_Of_The_Week
# 0        2.0  9.0   0.0   0.0  0.0              3.0
# 1        2.0  9.0   0.0  15.0  0.0              3.0
# 2        2.0  9.0   0.0  30.0  0.0              3.0
# 3        2.0  9.0   0.0  45.0  0.0              3.0
# 4        2.0  9.0   1.0   0.0  0.0              3.0
# ...      ...  ...   ...   ...  ...              ...
# 75835    4.0  9.0  22.0  45.0  0.0              1.0
# 75836    4.0  9.0  23.0   0.0  0.0              1.0
# 75837    4.0  9.0  23.0  15.0  0.0              1.0
# 75838    4.0  9.0  23.0  30.0  0.0              1.0
# 75839    4.0  9.0  23.0  45.0  0.0              1.0
#
# [75840 rows x 12 columns]

# %%
# Dataframe preprocessing

# Converting data types
ABB_data['CB_First_Floor'] = ABB_data['CB_First_Floor'].astype(np.float32)
ABB_data['CB_Second_Floor'] = ABB_data['CB_Second_Floor'].astype(np.float32)
ABB_data['AvgT'] = ABB_data['AvgT'].astype(np.float32)
ABB_data['AvgH'] = ABB_data['AvgH'].astype(np.float32)
ABB_data['Anomaly_Label'] = ABB_data['Anomaly_Label'].astype(np.float32)
ABB_data['Year'] = ABB_data['Year'].astype(np.float32)
ABB_data['Month'] = ABB_data['Month'].astype(np.float32)
ABB_data['Day'] = ABB_data['Day'].astype(np.float32)
ABB_data['Hour'] = ABB_data['Hour'].astype(np.float32)
ABB_data['Min'] = ABB_data['Min'].astype(np.float32)
ABB_data['Sec'] = ABB_data['Sec'].astype(np.float32)
ABB_data['Day_Of_The_Week'] = ABB_data['Day_Of_The_Week'].astype(np.float32)

# Printing the dataframe's info
ABB_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75840 entries, 0 to 75839
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CB_First_Floor   75840 non-null  float32
#  1   CB_Second_Floor  75840 non-null  float32
#  2   AvgT             75840 non-null  float32
#  3   AvgH             75840 non-null  float32
#  4   Anomaly_Label    75840 non-null  float32
#  5   Year             75840 non-null  float32
#  6   Month            75840 non-null  float32
#  7   Day              75840 non-null  float32
#  8   Hour             75840 non-null  float32
#  9   Min              75840 non-null  float32
#  10  Sec              75840 non-null  float32
#  11  Day_Of_The_Week  75840 non-null  float32
# dtypes: float32(12)
# memory usage: 3.5 MB

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(15,10))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()
    
# Plotting time series
inspect_dataframe(ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week"]], ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week"]].columns)

# %%
# Columns used for the following split in train, test and validation sets
ABB_data['Test'] = 0
ABB_data['Validation'] = 0
ABB_data['Train_P1'] = 0
ABB_data['Train_P2'] = 0

# %%
# TEST SET

# Some random weeks
week = [89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111]
for j in week:
    Slice_Multivariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    for k in range((j)*672,((j+1)*672)):
        ABB_data.at[k, 'Test'] = 1
        
j=112
for k in range((j)*672,((j+1)*672)-96):
        ABB_data.at[k, 'Test'] = 1

# %%
# VALIDATION SET

# Some random weeks
week = [55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78]
for j in week:
    Slice_Multivariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    for k in range((j)*672,(j+1)*672):
        ABB_data.at[k, 'Validation'] = 1

# %%
# TRAINING SET

week = [x for x in np.arange(0, 55, 1)]
for j in week:
    Slice_Univariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    for k in range((j)*672,(j+1)*672):
        ABB_data.at[k, 'Train_P1'] = 1
    
week = [x for x in np.arange(79, 89, 1)]
for j in week:
    Slice_Univariate_data = ABB_data.iloc[(j)*672:(j+1)*672]
    for k in range((j)*672,(j+1)*672):
        ABB_data.at[k, 'Train_P2'] = 1

# %%
# Plotting time series
inspect_dataframe(ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week", "Train_P1", "Train_P2", "Validation", "Test"]], ABB_data[["CB_First_Floor", "CB_Second_Floor", "Anomaly_Label", "Day_Of_The_Week", "Train_P1", "Train_P2", "Validation", "Test"]].columns)

# %%
# TRAIN, TEST, VALIDATION SETS
X_train_temp_P1 = ABB_data[ABB_data['Train_P1']==1].copy()
X_train_temp_P2 = ABB_data[ABB_data['Train_P2']==1].copy()
X_validation_temp = ABB_data[ABB_data['Validation']==1].copy()
X_test_temp = ABB_data[ABB_data['Test']==1].copy()

# %%
# Training, Validation and Test set - Anomalies (not used for training)
Anomaly_Train_P1 = X_train_temp_P1[['Anomaly_Label']]
Anomaly_Train_P2 = X_train_temp_P2[['Anomaly_Label']]
Anomaly_Validation = X_validation_temp[['Anomaly_Label']]
Anomaly_Test = X_test_temp[['Anomaly_Label']]

# %%
Anomaly_Test.isna().sum()
# Out:
# Anomaly_Label    0
# dtype: int64

# %%
X_train_temp_global = pd.concat([X_train_temp_P1,X_train_temp_P2],axis=0)
X_train_temp_global.shape
# Out:
# (43680, 16)

# %%
# STANDARDIZATION

mean = X_train_temp_global.mean()
std_dev = X_train_temp_global.std()
print(mean, std_dev)

X_train_raw_P1 = (X_train_temp_P1-mean)/std_dev
X_train_raw_P2 = (X_train_temp_P2-mean)/std_dev
X_validation_raw = (X_validation_temp-mean)/std_dev
X_test_raw = (X_test_temp-mean)/std_dev

print(X_test_raw.shape[0]+X_validation_raw.shape[0]+X_train_raw_P1.shape[0]+X_train_raw_P2.shape[0] == ABB_data.shape[0])
# Out:
# CB_First_Floor       56.138874
# CB_Second_Floor      55.814743
# AvgT                 14.077893
# AvgH                 71.934387
# Anomaly_Label         0.000000
# Year               2017.283569
# Month                 6.725275
# Day                  15.931869
# Hour                 11.500000
# Min                  22.500000
# Sec                   0.000000
# Day_Of_The_Week       3.000000
# Test                  0.000000
# Validation            0.000000
# Train_P1              0.846154
# Train_P2              0.153846
# dtype: float64 CB_First_Floor     19.434896
# CB_Second_Floor    19.353765
# AvgT                8.412517
# AvgH               19.357885
# Anomaly_Label       0.000000
# Year                0.450710
# Month               3.393199
# Day                 8.644081
# Hour                6.922266
# Min                16.770702
# Sec                 0.000000
# Day_Of_The_Week     2.000023
# Test                0.000000
# Validation          0.000000
# Train_P1            0.360805
# Train_P2            0.360805
# dtype: float64
# True

# %%
# Anomalies are not considered during the training
X_train_raw_P1 = X_train_raw_P1[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_train_raw_P2 = X_train_raw_P2[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_validation_raw = X_validation_raw[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_test_raw = X_test_raw[['CB_First_Floor', 'CB_Second_Floor', 'Day_Of_The_Week']]
X_train_raw_P1.shape, X_train_raw_P2.shape, X_validation_raw.shape, X_test_raw.shape
# Out:
# ((36960, 3), (6720, 3), (16128, 3), (16032, 3))

# %%
# Plotting time series
inspect_dataframe(X_test_raw, X_test_raw.columns)

# %% [markdown]
# ## Training Preparation

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Training parameters

window = 672       # 1 week
stride = 8         # 1 hour
latent_dim = 10    # Latent dimension
epochs = 300       # Number of epochs (no early stopping)
batch_size = 8     # Batch size
alpha = 0.5
M = 200

# %%
# Function used to create (overlapped) windows that we will use for the training
def build_sequences(df, anomaly, window=window, stride=stride):
    
    assert len(df) > window
    dataset = []
    anomalies = []
    temp_df = df.copy().values
    temp_an = anomaly.copy().values
    padding_len = (len(df)-window)%stride # Padding computed considering the stride
    print("PADDING: " + str(padding_len)) #DEBUG

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float32')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_an.shape[1]), dtype='float32')
        temp_an = np.concatenate((padding,temp_an))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window+1,stride):
        dataset.append(temp_df[idx:idx+window])
        anomalies.append(temp_an[idx:idx+window])

    dataset = np.array(dataset)
    anomalies = np.array(anomalies)
    return dataset, anomalies

# %%
X_train_P1, A_train_P1 = build_sequences(X_train_raw_P1, Anomaly_Train_P1, window=window, stride=stride)
X_train_P2, A_train_P2 = build_sequences(X_train_raw_P2, Anomaly_Train_P2, window=window, stride=stride)
X_val, A_val = build_sequences(X_validation_raw, Anomaly_Validation, window=window, stride=stride)
X_train_P1.shape,X_train_P2.shape
# Out:
# PADDING: 0
# PADDING: 0
# PADDING: 0
# ((4537, 672, 3), (757, 672, 3))

# %%
# Temp test set - plotting purposes
X_test, A_test = build_sequences(X_test_raw, Anomaly_Test, window=window, stride=stride)
# Out:
# PADDING: 0

# %%
X_train = np.concatenate([X_train_P1,X_train_P2],axis=0)
A_train = np.concatenate([A_train_P1,A_train_P2],axis=0)
X_train.shape, A_train.shape
# Out:
# ((5294, 672, 3), (5294, 672, 1))

# %%
# Reparametrization trick
def sample(args):
    z_mean, z_log_var = args
    eps = tf.keras.backend.random_normal(shape=(K.shape(z_mean)[0], K.int_shape(z_mean)[1]), seed=seed)
    return z_mean + tf.exp(alpha * z_log_var) * eps

# %%
# Building the model

from keras import backend as K
from tensorflow.keras import Input

input_shape = X_train.shape[1:]
output_shape = X_train.shape[1:]

###########
# ENCODER #
###########

encoder_input = tf.keras.Input(shape=input_shape)

x = tfkl.LSTM(64, return_sequences=False)(encoder_input)

x = tfkl.Dense(latent_dim, activation='linear')(x)

# Latent representation: mean + log of std.dev.
z_mu = tfkl.Dense(latent_dim, name='latent_mu')(x) # Mean
z_sigma = tfkl.Dense(latent_dim, name='latent_sigma')(x) # Std.Dev. 

# Sampling a vector from the latent distribution
z = tfkl.Lambda(sample, output_shape=(latent_dim, ), name='z')([z_mu, z_sigma])

encoder = tfk.Model(encoder_input, [z_mu, z_sigma, z], name='encoder')
print(encoder.summary())
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 672, 3)]     0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 64)           17408       input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           650         lstm[0][0]
# __________________________________________________________________________________________________
# latent_mu (Dense)               (None, 10)           110         dense[0][0]
# __________________________________________________________________________________________________
# latent_sigma (Dense)            (None, 10)           110         dense[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 10)           0           latent_mu[0][0]
#                                                                  latent_sigma[0][0]
# ==================================================================================================
# Total params: 18,278
# Trainable params: 18,278
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
###########
# DECODER #
###########

decoder_input = Input(shape=(latent_dim, ), name='decoder_input')
convlstm = tfkl.RepeatVector(window)(decoder_input)
convlstm = tfkl.LSTM(64, return_sequences=True)(convlstm)
decoder_output = tfkl.TimeDistributed(tfkl.Dense(output_shape[1]))(convlstm)

# Define and summarize decoder model
decoder = tfk.Model(decoder_input, decoder_output, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 10)]              0
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 672, 10)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 672, 64)           19200
# _________________________________________________________________
# time_distributed (TimeDistri (None, 672, 3)            195
# =================================================================
# Total params: 19,395
# Trainable params: 19,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
# Sampling + Reparametrization trick
def sample_z1(z_m, z_l_v):
    z_mean = z_m 
    z_log_var = z_l_v
    eps = tf.keras.backend.random_normal(shape=(K.shape(z_mean)[0], K.int_shape(z_mean)[1]), seed=seed)
    return z_mean + tf.exp(alpha * z_log_var) * eps

# %%
class VAE(tfk.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(VAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tfk.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tfk.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tfk.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    
    def forward(self, x):
        outputs = {}
        
        z_mu, z_log_var, _ = self.encoder(x)
        z = sample_z1(z_mu,z_log_var)
        reconstruction = self.decoder(z)
        
        outputs["z_mu"] = z_mu
        outputs["z_log_var"] = z_log_var
        outputs["z"] = z
        outputs["reconstruction"] = reconstruction
        
        return outputs

    def train_step(self, y_true):
        with tf.GradientTape() as tape:
            
            z_mu, z_log_var, _ = self.encoder(y_true)
            z = sample_z1(z_mu,z_log_var)
            y_predict = self.decoder(z)
          
            reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tfk.losses.mse(y_true, y_predict), axis=1))
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mu) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
            total_loss = reconstruction_loss + kl_loss
            
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result()
        }
    
    def test_step(self, data): #https://github.com/keras-team/keras-io/issues/38

        z_mu, z_log_var, _ = self.encoder(data)
        z = sample_z1(z_mu,z_log_var)
        y_predict = self.decoder(z)
          
        reconstruction_loss = tf.reduce_mean(tf.reduce_sum(tfk.losses.mse(data, y_predict), axis=1))
            
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mu) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            
        total_loss = reconstruction_loss + kl_loss
        
        return {
            "loss": total_loss,
            "reconstruction_loss": reconstruction_loss,
            "kl_loss": kl_loss
        }

# %%
vae = VAE(encoder, decoder)

seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

vae.compile(optimizer=tfk.optimizers.Adam())
vae.fit(x = X_train,
        validation_data = (X_val, None),
        epochs=100, 
        batch_size=batch_size)
vae.fit(x = X_train,
        validation_data = (X_val, None),
        epochs=epochs, 
        batch_size=batch_size,
        callbacks=[tfk.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True), tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5, min_lr=1e-5)]
       )
# Out:
# 2022-10-22 08:09:32.100839: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-10-22 08:09:35.606909: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 662/662 [==============================] - 40s 52ms/step - loss: 654.8038 - reconstruction_loss: 646.9282 - kl_loss: 2.5921 - val_loss: 446.5575 - val_reconstruction_loss: 445.4080 - val_kl_loss: 1.1495
# Epoch 2/100
# 662/662 [==============================] - 34s 51ms/step - loss: 656.3296 - reconstruction_loss: 648.2798 - kl_loss: 2.6870 - val_loss: 440.5663 - val_reconstruction_loss: 437.4166 - val_kl_loss: 3.1497
# Epoch 3/100
# 662/662 [==============================] - 34s 52ms/step - loss: 629.4912 - reconstruction_loss: 617.9920 - kl_loss: 3.6728 - val_loss: 423.1356 - val_reconstruction_loss: 420.3229 - val_kl_loss: 2.8126
# Epoch 4/100
# 662/662 [==============================] - 34s 52ms/step - loss: 613.1949 - reconstruction_loss: 603.1433 - kl_loss: 4.0924 - val_loss: 402.3018 - val_reconstruction_loss: 396.3241 - val_kl_loss: 5.9777
# Epoch 5/100
# 662/662 [==============================] - 34s 52ms/step - loss: 598.0487 - reconstruction_loss: 593.6807 - kl_loss: 3.2713 - val_loss: 401.8973 - val_reconstruction_loss: 399.7700 - val_kl_loss: 2.1274
# Epoch 6/100
# 662/662 [==============================] - 34s 52ms/step - loss: 593.3325 - reconstruction_loss: 594.8072 - kl_loss: 2.7941 - val_loss: 399.0787 - val_reconstruction_loss: 396.2604 - val_kl_loss: 2.8182
# Epoch 7/100
# 662/662 [==============================] - 34s 52ms/step - loss: 600.8936 - reconstruction_loss: 592.8564 - kl_loss: 2.6108 - val_loss: 398.0221 - val_reconstruction_loss: 395.1881 - val_kl_loss: 2.8340
# Epoch 8/100
# 662/662 [==============================] - 34s 52ms/step - loss: 594.0922 - reconstruction_loss: 589.6880 - kl_loss: 2.6308 - val_loss: 397.2548 - val_reconstruction_loss: 394.7514 - val_kl_loss: 2.5034
# Epoch 9/100
# 662/662 [==============================] - 34s 52ms/step - loss: 593.2266 - reconstruction_loss: 588.7749 - kl_loss: 2.4821 - val_loss: 397.0450 - val_reconstruction_loss: 394.3228 - val_kl_loss: 2.7222
# Epoch 10/100
# 662/662 [==============================] - 34s 51ms/step - loss: 589.1263 - reconstruction_loss: 587.7699 - kl_loss: 2.5203 - val_loss: 397.0993 - val_reconstruction_loss: 394.3441 - val_kl_loss: 2.7552
# Epoch 11/100
# 662/662 [==============================] - 34s 52ms/step - loss: 588.7127 - reconstruction_loss: 585.9669 - kl_loss: 2.4552 - val_loss: 396.9711 - val_reconstruction_loss: 394.3869 - val_kl_loss: 2.5843
# Epoch 12/100
# 662/662 [==============================] - 34s 52ms/step - loss: 588.7432 - reconstruction_loss: 585.4101 - kl_loss: 2.4297 - val_loss: 396.6844 - val_reconstruction_loss: 393.8550 - val_kl_loss: 2.8294
# Epoch 13/100
# 662/662 [==============================] - 34s 52ms/step - loss: 588.1909 - reconstruction_loss: 583.1269 - kl_loss: 2.4571 - val_loss: 396.7035 - val_reconstruction_loss: 394.2209 - val_kl_loss: 2.4826
# Epoch 14/100
# 662/662 [==============================] - 34s 52ms/step - loss: 584.3898 - reconstruction_loss: 582.1413 - kl_loss: 2.4372 - val_loss: 396.3064 - val_reconstruction_loss: 393.9071 - val_kl_loss: 2.3993
# Epoch 15/100
# 662/662 [==============================] - 34s 52ms/step - loss: 583.9119 - reconstruction_loss: 581.7917 - kl_loss: 2.4281 - val_loss: 396.6688 - val_reconstruction_loss: 394.3857 - val_kl_loss: 2.2831
# Epoch 16/100
# 662/662 [==============================] - 34s 51ms/step - loss: 581.3710 - reconstruction_loss: 581.7780 - kl_loss: 2.4071 - val_loss: 396.1734 - val_reconstruction_loss: 393.8228 - val_kl_loss: 2.3506
# Epoch 17/100
# 662/662 [==============================] - 34s 52ms/step - loss: 580.9607 - reconstruction_loss: 581.7014 - kl_loss: 2.4084 - val_loss: 397.0302 - val_reconstruction_loss: 394.7214 - val_kl_loss: 2.3088
# Epoch 18/100
# 662/662 [==============================] - 34s 51ms/step - loss: 582.9554 - reconstruction_loss: 581.6363 - kl_loss: 2.3997 - val_loss: 397.3064 - val_reconstruction_loss: 395.1084 - val_kl_loss: 2.1980
# Epoch 19/100
# 662/662 [==============================] - 34s 52ms/step - loss: 585.9048 - reconstruction_loss: 581.7197 - kl_loss: 2.4105 - val_loss: 397.2166 - val_reconstruction_loss: 394.9995 - val_kl_loss: 2.2172
# Epoch 20/100
# 662/662 [==============================] - 34s 51ms/step - loss: 581.1563 - reconstruction_loss: 581.5959 - kl_loss: 2.3797 - val_loss: 396.1364 - val_reconstruction_loss: 393.9537 - val_kl_loss: 2.1828
# Epoch 21/100
# 662/662 [==============================] - 33s 51ms/step - loss: 582.3354 - reconstruction_loss: 581.5151 - kl_loss: 2.3692 - val_loss: 396.2611 - val_reconstruction_loss: 394.1062 - val_kl_loss: 2.1549
# Epoch 22/100
# 662/662 [==============================] - 34s 52ms/step - loss: 584.7440 - reconstruction_loss: 581.5161 - kl_loss: 2.3478 - val_loss: 396.3559 - val_reconstruction_loss: 394.2762 - val_kl_loss: 2.0797
# Epoch 23/100
# 662/662 [==============================] - 34s 52ms/step - loss: 581.7492 - reconstruction_loss: 581.5773 - kl_loss: 2.3413 - val_loss: 396.2388 - val_reconstruction_loss: 394.1745 - val_kl_loss: 2.0643
# Epoch 24/100
# 662/662 [==============================] - 34s 51ms/step - loss: 584.3641 - reconstruction_loss: 581.5516 - kl_loss: 2.3426 - val_loss: 396.7499 - val_reconstruction_loss: 394.3859 - val_kl_loss: 2.3640
# Epoch 25/100
# 662/662 [==============================] - 33s 51ms/step - loss: 587.6552 - reconstruction_loss: 581.4386 - kl_loss: 2.3408 - val_loss: 396.2097 - val_reconstruction_loss: 394.1371 - val_kl_loss: 2.0727
# Epoch 26/100
# 662/662 [==============================] - 34s 51ms/step - loss: 583.9378 - reconstruction_loss: 581.4370 - kl_loss: 2.3289 - val_loss: 396.1268 - val_reconstruction_loss: 394.0807 - val_kl_loss: 2.0461
# Epoch 27/100
# 662/662 [==============================] - 34s 52ms/step - loss: 582.0057 - reconstruction_loss: 581.4136 - kl_loss: 2.3168 - val_loss: 396.0880 - val_reconstruction_loss: 393.8688 - val_kl_loss: 2.2192
# Epoch 28/100
# 662/662 [==============================] - 34s 52ms/step - loss: 585.8058 - reconstruction_loss: 581.3737 - kl_loss: 2.3304 - val_loss: 396.4440 - val_reconstruction_loss: 394.3605 - val_kl_loss: 2.0835
# Epoch 29/100
# 662/662 [==============================] - 33s 51ms/step - loss: 584.6834 - reconstruction_loss: 581.5668 - kl_loss: 2.3393 - val_loss: 395.7482 - val_reconstruction_loss: 393.8372 - val_kl_loss: 1.9110
# Epoch 30/100
# 662/662 [==============================] - 34s 52ms/step - loss: 585.9337 - reconstruction_loss: 581.3397 - kl_loss: 2.3235 - val_loss: 396.5429 - val_reconstruction_loss: 394.3557 - val_kl_loss: 2.1872
# Epoch 31/100
# 662/662 [==============================] - 34s 52ms/step - loss: 581.4120 - reconstruction_loss: 581.3784 - kl_loss: 2.3067 - val_loss: 397.5805 - val_reconstruction_loss: 395.7046 - val_kl_loss: 1.8759
# Epoch 32/100
# 662/662 [==============================] - 33s 51ms/step - loss: 581.6657 - reconstruction_loss: 581.3427 - kl_loss: 2.3080 - val_loss: 395.8752 - val_reconstruction_loss: 393.9042 - val_kl_loss: 1.9709
# Epoch 33/100
# 662/662 [==============================] - 34s 52ms/step - loss: 582.4629 - reconstruction_loss: 581.3239 - kl_loss: 2.3172 - val_loss: 396.9764 - val_reconstruction_loss: 394.7165 - val_kl_loss: 2.2599
# Epoch 34/100
# 662/662 [==============================] - 33s 50ms/step - loss: 584.5433 - reconstruction_loss: 581.3054 - kl_loss: 2.3174 - val_loss: 395.8715 - val_reconstruction_loss: 394.0076 - val_kl_loss: 1.8639
# Epoch 35/100
# 662/662 [==============================] - 35s 52ms/step - loss: 582.8357 - reconstruction_loss: 581.3099 - kl_loss: 2.2826 - val_loss: 396.5025 - val_reconstruction_loss: 394.5785 - val_kl_loss: 1.9240
# Epoch 36/100
# 662/662 [==============================] - 33s 50ms/step - loss: 580.4669 - reconstruction_loss: 581.3477 - kl_loss: 2.3018 - val_loss: 396.2432 - val_reconstruction_loss: 394.2403 - val_kl_loss: 2.0029
# Epoch 37/100
# 662/662 [==============================] - 34s 52ms/step - loss: 583.8143 - reconstruction_loss: 581.2401 - kl_loss: 2.3128 - val_loss: 396.1498 - val_reconstruction_loss: 394.2346 - val_kl_loss: 1.9153
# Epoch 38/100
# 662/662 [==============================] - 34s 51ms/step - loss: 584.8967 - reconstruction_loss: 581.2611 - kl_loss: 2.3089 - val_loss: 396.2967 - val_reconstruction_loss: 394.1996 - val_kl_loss: 2.0971
# Epoch 39/100
# 662/662 [==============================] - 34s 52ms/step - loss: 583.3467 - reconstruction_loss: 581.2328 - kl_loss: 2.2877 - val_loss: 396.2090 - val_reconstruction_loss: 394.2104 - val_kl_loss: 1.9986
# Epoch 40/100
# 662/662 [==============================] - 34s 52ms/step - loss: 583.9272 - reconstruction_loss: 581.3147 - kl_loss: 2.2850 - val_loss: 395.8493 - val_reconstruction_loss: 394.0288 - val_kl_loss: 1.8205
# Epoch 41/100
# 662/662 [==============================] - 33s 51ms/step - loss: 586.2588 - reconstruction_loss: 581.2766 - kl_loss: 2.3013 - val_loss: 395.9818 - val_reconstruction_loss: 393.9511 - val_kl_loss: 2.0307
# Epoch 42/100
# 662/662 [==============================] - 35s 52ms/step - loss: 582.2416 - reconstruction_loss: 581.2599 - kl_loss: 2.2946 - val_loss: 395.9441 - val_reconstruction_loss: 393.8991 - val_kl_loss: 2.0450
# Epoch 43/100
# 662/662 [==============================] - 34s 52ms/step - loss: 581.2850 - reconstruction_loss: 581.3170 - kl_loss: 2.2898 - val_loss: 396.1281 - val_reconstruction_loss: 394.0925 - val_kl_loss: 2.0357
# Epoch 44/100
# 662/662 [==============================] - 33s 50ms/step - loss: 588.4914 - reconstruction_loss: 581.2055 - kl_loss: 2.3078 - val_loss: 397.5821 - val_reconstruction_loss: 395.7369 - val_kl_loss: 1.8452
# Epoch 45/100
# 662/662 [==============================] - 33s 50ms/step - loss: 583.7909 - reconstruction_loss: 581.0437 - kl_loss: 2.4845 - val_loss: 396.2805 - val_reconstruction_loss: 394.0689 - val_kl_loss: 2.2116
# Epoch 46/100
# 662/662 [==============================] - 34s 52ms/step - loss: 582.1395 - reconstruction_loss: 577.9405 - kl_loss: 3.9632 - val_loss: 399.5037 - val_reconstruction_loss: 394.6762 - val_kl_loss: 4.8274
# Epoch 47/100
# 662/662 [==============================] - 34s 52ms/step - loss: 587.3661 - reconstruction_loss: 569.1520 - kl_loss: 6.5720 - val_loss: 260.8754 - val_reconstruction_loss: 253.0366 - val_kl_loss: 7.8388
# Epoch 48/100
# 662/662 [==============================] - 34s 52ms/step - loss: 466.7286 - reconstruction_loss: 427.4345 - kl_loss: 16.6861 - val_loss: 217.6590 - val_reconstruction_loss: 206.5199 - val_kl_loss: 11.1392
# Epoch 49/100
# 662/662 [==============================] - 34s 51ms/step - loss: 418.6468 - reconstruction_loss: 401.6748 - kl_loss: 14.7906 - val_loss: 233.8507 - val_reconstruction_loss: 224.4211 - val_kl_loss: 9.4296
# Epoch 50/100
# 662/662 [==============================] - 34s 51ms/step - loss: 404.6447 - reconstruction_loss: 389.3796 - kl_loss: 13.3043 - val_loss: 240.4840 - val_reconstruction_loss: 231.2884 - val_kl_loss: 9.1956
# Epoch 51/100
# 662/662 [==============================] - 34s 51ms/step - loss: 396.6365 - reconstruction_loss: 361.0261 - kl_loss: 13.1118 - val_loss: 205.2696 - val_reconstruction_loss: 195.1927 - val_kl_loss: 10.0769
# Epoch 52/100
# 662/662 [==============================] - 34s 51ms/step - loss: 332.8632 - reconstruction_loss: 317.9871 - kl_loss: 13.0416 - val_loss: 193.2354 - val_reconstruction_loss: 183.2699 - val_kl_loss: 9.9655
# Epoch 53/100
# 662/662 [==============================] - 34s 51ms/step - loss: 325.7025 - reconstruction_loss: 314.2353 - kl_loss: 13.0138 - val_loss: 198.4626 - val_reconstruction_loss: 188.1647 - val_kl_loss: 10.2980
# Epoch 54/100
# 662/662 [==============================] - 34s 51ms/step - loss: 325.0331 - reconstruction_loss: 309.1496 - kl_loss: 13.4816 - val_loss: 151.5969 - val_reconstruction_loss: 141.0797 - val_kl_loss: 10.5172
# Epoch 55/100
# 662/662 [==============================] - 34s 51ms/step - loss: 305.7643 - reconstruction_loss: 289.5571 - kl_loss: 13.9621 - val_loss: 175.9611 - val_reconstruction_loss: 164.2648 - val_kl_loss: 11.6963
# Epoch 56/100
# 662/662 [==============================] - 34s 52ms/step - loss: 288.4871 - reconstruction_loss: 269.1459 - kl_loss: 14.1364 - val_loss: 139.5482 - val_reconstruction_loss: 128.3696 - val_kl_loss: 11.1786
# Epoch 57/100
# 662/662 [==============================] - 33s 51ms/step - loss: 273.6448 - reconstruction_loss: 256.8309 - kl_loss: 14.1533 - val_loss: 142.1534 - val_reconstruction_loss: 130.8044 - val_kl_loss: 11.3489
# Epoch 58/100
# 662/662 [==============================] - 34s 51ms/step - loss: 262.2791 - reconstruction_loss: 242.8486 - kl_loss: 14.8320 - val_loss: 134.8704 - val_reconstruction_loss: 122.9145 - val_kl_loss: 11.9560
# Epoch 59/100
# 662/662 [==============================] - 34s 51ms/step - loss: 250.5085 - reconstruction_loss: 216.8220 - kl_loss: 15.7394 - val_loss: 97.4578 - val_reconstruction_loss: 84.3680 - val_kl_loss: 13.0898
# Epoch 60/100
# 662/662 [==============================] - 34s 51ms/step - loss: 193.5896 - reconstruction_loss: 174.7580 - kl_loss: 16.4092 - val_loss: 93.7329 - val_reconstruction_loss: 80.9631 - val_kl_loss: 12.7698
# Epoch 61/100
# 662/662 [==============================] - 34s 51ms/step - loss: 179.7534 - reconstruction_loss: 164.3969 - kl_loss: 16.1983 - val_loss: 91.9111 - val_reconstruction_loss: 78.9521 - val_kl_loss: 12.9590
# Epoch 62/100
# 662/662 [==============================] - 34s 52ms/step - loss: 177.4973 - reconstruction_loss: 160.7913 - kl_loss: 16.1305 - val_loss: 76.1810 - val_reconstruction_loss: 63.5416 - val_kl_loss: 12.6394
# Epoch 63/100
# 662/662 [==============================] - 34s 51ms/step - loss: 169.8375 - reconstruction_loss: 150.9570 - kl_loss: 15.7970 - val_loss: 86.7012 - val_reconstruction_loss: 74.1574 - val_kl_loss: 12.5438
# Epoch 64/100
# 662/662 [==============================] - 34s 52ms/step - loss: 165.8329 - reconstruction_loss: 154.8696 - kl_loss: 15.8161 - val_loss: 77.6621 - val_reconstruction_loss: 65.2474 - val_kl_loss: 12.4148
# Epoch 65/100
# 662/662 [==============================] - 34s 52ms/step - loss: 157.1141 - reconstruction_loss: 146.9514 - kl_loss: 15.7478 - val_loss: 70.8349 - val_reconstruction_loss: 58.9000 - val_kl_loss: 11.9349
# Epoch 66/100
# 662/662 [==============================] - 34s 51ms/step - loss: 152.3573 - reconstruction_loss: 135.2672 - kl_loss: 15.7136 - val_loss: 85.2656 - val_reconstruction_loss: 73.0684 - val_kl_loss: 12.1971
# Epoch 67/100
# 662/662 [==============================] - 35s 52ms/step - loss: 157.5321 - reconstruction_loss: 136.9172 - kl_loss: 15.7030 - val_loss: 65.8886 - val_reconstruction_loss: 53.8431 - val_kl_loss: 12.0454
# Epoch 68/100
# 662/662 [==============================] - 35s 52ms/step - loss: 140.8807 - reconstruction_loss: 126.7232 - kl_loss: 15.4990 - val_loss: 52.0202 - val_reconstruction_loss: 40.0160 - val_kl_loss: 12.0042
# Epoch 69/100
# 662/662 [==============================] - 34s 51ms/step - loss: 145.1330 - reconstruction_loss: 125.6718 - kl_loss: 15.7069 - val_loss: 54.7851 - val_reconstruction_loss: 42.6228 - val_kl_loss: 12.1622
# Epoch 70/100
# 662/662 [==============================] - 34s 51ms/step - loss: 139.8490 - reconstruction_loss: 116.7420 - kl_loss: 15.8951 - val_loss: 50.9225 - val_reconstruction_loss: 38.4451 - val_kl_loss: 12.4774
# Epoch 71/100
# 662/662 [==============================] - 34s 52ms/step - loss: 129.8346 - reconstruction_loss: 113.8475 - kl_loss: 15.8491 - val_loss: 79.0279 - val_reconstruction_loss: 66.5388 - val_kl_loss: 12.4892
# Epoch 72/100
# 662/662 [==============================] - 34s 52ms/step - loss: 130.2430 - reconstruction_loss: 114.0879 - kl_loss: 16.2580 - val_loss: 70.7373 - val_reconstruction_loss: 58.1097 - val_kl_loss: 12.6276
# Epoch 73/100
# 662/662 [==============================] - 34s 52ms/step - loss: 120.2711 - reconstruction_loss: 97.9062 - kl_loss: 15.7634 - val_loss: 60.9290 - val_reconstruction_loss: 48.6042 - val_kl_loss: 12.3248
# Epoch 74/100
# 662/662 [==============================] - 34s 52ms/step - loss: 120.7304 - reconstruction_loss: 108.7854 - kl_loss: 16.2017 - val_loss: 64.9898 - val_reconstruction_loss: 52.2873 - val_kl_loss: 12.7024
# Epoch 75/100
# 662/662 [==============================] - 34s 51ms/step - loss: 108.1231 - reconstruction_loss: 92.9341 - kl_loss: 15.9184 - val_loss: 50.7511 - val_reconstruction_loss: 38.2768 - val_kl_loss: 12.4742
# Epoch 76/100
# 662/662 [==============================] - 34s 52ms/step - loss: 112.0763 - reconstruction_loss: 95.2935 - kl_loss: 15.8953 - val_loss: 99.7693 - val_reconstruction_loss: 87.3421 - val_kl_loss: 12.4271
# Epoch 77/100
# 662/662 [==============================] - 34s 51ms/step - loss: 111.1571 - reconstruction_loss: 97.0890 - kl_loss: 15.9795 - val_loss: 69.5354 - val_reconstruction_loss: 57.0459 - val_kl_loss: 12.4894
# Epoch 78/100
# 662/662 [==============================] - 34s 52ms/step - loss: 104.5602 - reconstruction_loss: 91.3442 - kl_loss: 15.7228 - val_loss: 44.3440 - val_reconstruction_loss: 32.0521 - val_kl_loss: 12.2919
# Epoch 79/100
# 662/662 [==============================] - 34s 51ms/step - loss: 101.8154 - reconstruction_loss: 86.6131 - kl_loss: 15.2699 - val_loss: 50.9922 - val_reconstruction_loss: 39.0448 - val_kl_loss: 11.9474
# Epoch 80/100
# 662/662 [==============================] - 34s 52ms/step - loss: 104.3426 - reconstruction_loss: 100.8980 - kl_loss: 15.4446 - val_loss: 42.6866 - val_reconstruction_loss: 30.2663 - val_kl_loss: 12.4203
# Epoch 81/100
# 662/662 [==============================] - 35s 53ms/step - loss: 112.7111 - reconstruction_loss: 96.9674 - kl_loss: 15.5210 - val_loss: 41.8641 - val_reconstruction_loss: 30.0464 - val_kl_loss: 11.8177
# Epoch 82/100
# 662/662 [==============================] - 34s 51ms/step - loss: 113.1837 - reconstruction_loss: 96.4677 - kl_loss: 15.3652 - val_loss: 42.5015 - val_reconstruction_loss: 31.0885 - val_kl_loss: 11.4130
# Epoch 83/100
# 662/662 [==============================] - 34s 52ms/step - loss: 105.4177 - reconstruction_loss: 92.7287 - kl_loss: 14.8436 - val_loss: 62.2970 - val_reconstruction_loss: 50.8009 - val_kl_loss: 11.4961
# Epoch 84/100
# 662/662 [==============================] - 35s 52ms/step - loss: 110.8071 - reconstruction_loss: 96.7661 - kl_loss: 15.2467 - val_loss: 48.8058 - val_reconstruction_loss: 37.1240 - val_kl_loss: 11.6818
# Epoch 85/100
# 662/662 [==============================] - 35s 52ms/step - loss: 100.1683 - reconstruction_loss: 92.0150 - kl_loss: 14.8714 - val_loss: 43.7022 - val_reconstruction_loss: 32.1584 - val_kl_loss: 11.5437
# Epoch 86/100
# 662/662 [==============================] - 34s 52ms/step - loss: 99.6711 - reconstruction_loss: 81.9912 - kl_loss: 15.1043 - val_loss: 38.1214 - val_reconstruction_loss: 26.3824 - val_kl_loss: 11.7390
# Epoch 87/100
# 662/662 [==============================] - 34s 51ms/step - loss: 100.2674 - reconstruction_loss: 88.6163 - kl_loss: 15.0894 - val_loss: 73.3057 - val_reconstruction_loss: 61.2482 - val_kl_loss: 12.0574
# Epoch 88/100
# 662/662 [==============================] - 34s 51ms/step - loss: 88.3297 - reconstruction_loss: 78.2390 - kl_loss: 14.9407 - val_loss: 65.3620 - val_reconstruction_loss: 53.8003 - val_kl_loss: 11.5617
# Epoch 89/100
# 662/662 [==============================] - 34s 51ms/step - loss: 98.0099 - reconstruction_loss: 79.6340 - kl_loss: 14.8794 - val_loss: 40.7297 - val_reconstruction_loss: 29.3884 - val_kl_loss: 11.3412
# Epoch 90/100
# 662/662 [==============================] - 34s 51ms/step - loss: 97.9337 - reconstruction_loss: 81.1196 - kl_loss: 14.7998 - val_loss: 36.8691 - val_reconstruction_loss: 25.4794 - val_kl_loss: 11.3896
# Epoch 91/100
# 662/662 [==============================] - 35s 52ms/step - loss: 99.9591 - reconstruction_loss: 81.7651 - kl_loss: 14.7359 - val_loss: 33.4798 - val_reconstruction_loss: 22.2041 - val_kl_loss: 11.2757
# Epoch 92/100
# 662/662 [==============================] - 34s 51ms/step - loss: 88.4371 - reconstruction_loss: 80.2309 - kl_loss: 14.6248 - val_loss: 37.7632 - val_reconstruction_loss: 26.4302 - val_kl_loss: 11.3330
# Epoch 93/100
# 662/662 [==============================] - 34s 52ms/step - loss: 97.7167 - reconstruction_loss: 83.8034 - kl_loss: 14.8122 - val_loss: 38.3383 - val_reconstruction_loss: 26.9476 - val_kl_loss: 11.3907
# Epoch 94/100
# 662/662 [==============================] - 34s 52ms/step - loss: 85.8781 - reconstruction_loss: 78.4316 - kl_loss: 14.4951 - val_loss: 40.7518 - val_reconstruction_loss: 29.4659 - val_kl_loss: 11.2859
# Epoch 95/100
# 662/662 [==============================] - 34s 51ms/step - loss: 90.4951 - reconstruction_loss: 74.3162 - kl_loss: 14.2809 - val_loss: 41.9864 - val_reconstruction_loss: 30.7347 - val_kl_loss: 11.2517
# Epoch 96/100
# 662/662 [==============================] - 34s 51ms/step - loss: 90.2769 - reconstruction_loss: 74.4207 - kl_loss: 14.3700 - val_loss: 76.4156 - val_reconstruction_loss: 65.6359 - val_kl_loss: 10.7797
# Epoch 97/100
# 662/662 [==============================] - 34s 52ms/step - loss: 96.0106 - reconstruction_loss: 78.5944 - kl_loss: 14.3553 - val_loss: 39.0600 - val_reconstruction_loss: 28.1407 - val_kl_loss: 10.9193
# Epoch 98/100
# 662/662 [==============================] - 34s 52ms/step - loss: 92.4583 - reconstruction_loss: 82.1819 - kl_loss: 14.5278 - val_loss: 38.1070 - val_reconstruction_loss: 27.0996 - val_kl_loss: 11.0074
# Epoch 99/100
# 662/662 [==============================] - 34s 52ms/step - loss: 88.9653 - reconstruction_loss: 68.9295 - kl_loss: 14.2751 - val_loss: 34.1081 - val_reconstruction_loss: 23.6855 - val_kl_loss: 10.4226
# Epoch 100/100
# 662/662 [==============================] - 34s 52ms/step - loss: 87.0632 - reconstruction_loss: 73.8992 - kl_loss: 14.0219 - val_loss: 38.1442 - val_reconstruction_loss: 27.3128 - val_kl_loss: 10.8313
# Epoch 1/300
# 662/662 [==============================] - 34s 51ms/step - loss: 90.2161 - reconstruction_loss: 76.9290 - kl_loss: 14.1209 - val_loss: 35.2710 - val_reconstruction_loss: 24.6003 - val_kl_loss: 10.6707
# Epoch 2/300
# 662/662 [==============================] - 35s 52ms/step - loss: 96.1091 - reconstruction_loss: 74.8961 - kl_loss: 14.0685 - val_loss: 41.0079 - val_reconstruction_loss: 30.1698 - val_kl_loss: 10.8381
# Epoch 3/300
# 662/662 [==============================] - 35s 52ms/step - loss: 84.7389 - reconstruction_loss: 74.7613 - kl_loss: 14.0840 - val_loss: 59.9260 - val_reconstruction_loss: 49.1411 - val_kl_loss: 10.7849
# Epoch 4/300
# 662/662 [==============================] - 34s 51ms/step - loss: 81.2164 - reconstruction_loss: 66.5092 - kl_loss: 13.8791 - val_loss: 36.3233 - val_reconstruction_loss: 25.9996 - val_kl_loss: 10.3237
# Epoch 5/300
# 662/662 [==============================] - 34s 52ms/step - loss: 82.7192 - reconstruction_loss: 69.5197 - kl_loss: 13.7580 - val_loss: 41.9469 - val_reconstruction_loss: 31.3636 - val_kl_loss: 10.5833
# Epoch 6/300
# 662/662 [==============================] - 34s 51ms/step - loss: 98.5764 - reconstruction_loss: 77.8885 - kl_loss: 13.9975 - val_loss: 37.7487 - val_reconstruction_loss: 27.3713 - val_kl_loss: 10.3774
# Epoch 7/300
# 662/662 [==============================] - 35s 52ms/step - loss: 69.7511 - reconstruction_loss: 53.9193 - kl_loss: 13.1895 - val_loss: 28.8135 - val_reconstruction_loss: 19.2455 - val_kl_loss: 9.5679
# Epoch 8/300
# 662/662 [==============================] - 34s 52ms/step - loss: 66.4807 - reconstruction_loss: 54.8537 - kl_loss: 12.6151 - val_loss: 36.9291 - val_reconstruction_loss: 27.5291 - val_kl_loss: 9.4000
# Epoch 9/300
# 662/662 [==============================] - 34s 51ms/step - loss: 72.6247 - reconstruction_loss: 60.0499 - kl_loss: 12.6424 - val_loss: 29.8858 - val_reconstruction_loss: 20.3755 - val_kl_loss: 9.5102
# Epoch 10/300
# 662/662 [==============================] - 35s 52ms/step - loss: 64.9618 - reconstruction_loss: 54.5994 - kl_loss: 12.5355 - val_loss: 35.4911 - val_reconstruction_loss: 25.8235 - val_kl_loss: 9.6675
# Epoch 11/300
# 662/662 [==============================] - 34s 51ms/step - loss: 69.3253 - reconstruction_loss: 58.4714 - kl_loss: 12.4886 - val_loss: 31.2150 - val_reconstruction_loss: 21.8767 - val_kl_loss: 9.3383
# Epoch 12/300
# 662/662 [==============================] - 35s 52ms/step - loss: 67.9761 - reconstruction_loss: 57.2899 - kl_loss: 12.4195 - val_loss: 30.2530 - val_reconstruction_loss: 20.9163 - val_kl_loss: 9.3368
# Epoch 13/300
# 662/662 [==============================] - 34s 51ms/step - loss: 62.0380 - reconstruction_loss: 49.2858 - kl_loss: 12.2328 - val_loss: 30.2874 - val_reconstruction_loss: 21.1256 - val_kl_loss: 9.1618
# Epoch 14/300
# 662/662 [==============================] - 34s 52ms/step - loss: 61.4448 - reconstruction_loss: 49.8780 - kl_loss: 12.0803 - val_loss: 28.4726 - val_reconstruction_loss: 19.2986 - val_kl_loss: 9.1740
# Epoch 15/300
# 662/662 [==============================] - 34s 51ms/step - loss: 61.4177 - reconstruction_loss: 49.5550 - kl_loss: 12.0024 - val_loss: 29.2278 - val_reconstruction_loss: 20.1604 - val_kl_loss: 9.0674
# Epoch 16/300
# 662/662 [==============================] - 34s 51ms/step - loss: 60.8464 - reconstruction_loss: 49.1443 - kl_loss: 11.9715 - val_loss: 27.3724 - val_reconstruction_loss: 18.2952 - val_kl_loss: 9.0773
# Epoch 17/300
# 662/662 [==============================] - 34s 52ms/step - loss: 61.5148 - reconstruction_loss: 50.3312 - kl_loss: 11.9226 - val_loss: 33.9524 - val_reconstruction_loss: 24.9220 - val_kl_loss: 9.0304
# Epoch 18/300
# 662/662 [==============================] - 34s 52ms/step - loss: 60.8799 - reconstruction_loss: 49.7683 - kl_loss: 11.9145 - val_loss: 26.5612 - val_reconstruction_loss: 17.4265 - val_kl_loss: 9.1347
# Epoch 19/300
# 662/662 [==============================] - 35s 52ms/step - loss: 60.5287 - reconstruction_loss: 48.7211 - kl_loss: 11.8779 - val_loss: 25.9630 - val_reconstruction_loss: 16.9081 - val_kl_loss: 9.0549
# Epoch 20/300
# 662/662 [==============================] - 34s 52ms/step - loss: 60.3748 - reconstruction_loss: 49.2574 - kl_loss: 11.8489 - val_loss: 30.5681 - val_reconstruction_loss: 21.5195 - val_kl_loss: 9.0485
# Epoch 21/300
# 662/662 [==============================] - 34s 51ms/step - loss: 61.9119 - reconstruction_loss: 49.7285 - kl_loss: 11.8528 - val_loss: 26.8304 - val_reconstruction_loss: 17.7696 - val_kl_loss: 9.0608
# Epoch 22/300
# 662/662 [==============================] - 34s 51ms/step - loss: 60.5964 - reconstruction_loss: 48.8701 - kl_loss: 11.7753 - val_loss: 27.7071 - val_reconstruction_loss: 18.7374 - val_kl_loss: 8.9697
# Epoch 23/300
# 662/662 [==============================] - 34s 51ms/step - loss: 61.0044 - reconstruction_loss: 49.4301 - kl_loss: 11.7599 - val_loss: 33.2763 - val_reconstruction_loss: 24.2505 - val_kl_loss: 9.0258
# Epoch 24/300
# 662/662 [==============================] - 34s 51ms/step - loss: 61.1504 - reconstruction_loss: 48.5347 - kl_loss: 11.7528 - val_loss: 28.8563 - val_reconstruction_loss: 19.8643 - val_kl_loss: 8.9921
# Epoch 25/300
# 662/662 [==============================] - 34s 52ms/step - loss: 58.7478 - reconstruction_loss: 46.0512 - kl_loss: 11.6917 - val_loss: 27.7251 - val_reconstruction_loss: 18.7611 - val_kl_loss: 8.9640
# Epoch 26/300
# 662/662 [==============================] - 35s 52ms/step - loss: 57.8217 - reconstruction_loss: 46.1451 - kl_loss: 11.6636 - val_loss: 27.5174 - val_reconstruction_loss: 18.5773 - val_kl_loss: 8.9401
# Epoch 27/300
# 662/662 [==============================] - 35s 52ms/step - loss: 57.1803 - reconstruction_loss: 46.0015 - kl_loss: 11.6586 - val_loss: 29.1224 - val_reconstruction_loss: 20.1410 - val_kl_loss: 8.9814
# Epoch 28/300
# 662/662 [==============================] - 34s 52ms/step - loss: 57.8162 - reconstruction_loss: 45.9807 - kl_loss: 11.6525 - val_loss: 26.6165 - val_reconstruction_loss: 17.6722 - val_kl_loss: 8.9443
# Epoch 29/300
# 662/662 [==============================] - 34s 51ms/step - loss: 58.2831 - reconstruction_loss: 46.1101 - kl_loss: 11.6296 - val_loss: 25.6242 - val_reconstruction_loss: 16.6844 - val_kl_loss: 8.9399
# Epoch 30/300
# 662/662 [==============================] - 34s 52ms/step - loss: 57.4875 - reconstruction_loss: 45.8413 - kl_loss: 11.6052 - val_loss: 29.5073 - val_reconstruction_loss: 20.5837 - val_kl_loss: 8.9237
# Epoch 31/300
# 662/662 [==============================] - 34s 52ms/step - loss: 57.4940 - reconstruction_loss: 46.0149 - kl_loss: 11.6139 - val_loss: 25.5063 - val_reconstruction_loss: 16.5397 - val_kl_loss: 8.9666
# Epoch 32/300
# 662/662 [==============================] - 34s 51ms/step - loss: 56.6570 - reconstruction_loss: 45.7387 - kl_loss: 11.5841 - val_loss: 25.4544 - val_reconstruction_loss: 16.5221 - val_kl_loss: 8.9323
# Epoch 33/300
# 662/662 [==============================] - 34s 51ms/step - loss: 57.1218 - reconstruction_loss: 45.6036 - kl_loss: 11.5483 - val_loss: 27.3222 - val_reconstruction_loss: 18.4295 - val_kl_loss: 8.8926
# Epoch 34/300
# 662/662 [==============================] - 34s 51ms/step - loss: 57.8730 - reconstruction_loss: 45.7356 - kl_loss: 11.5619 - val_loss: 27.6851 - val_reconstruction_loss: 18.7756 - val_kl_loss: 8.9095
# Epoch 35/300
# 662/662 [==============================] - 35s 52ms/step - loss: 57.2162 - reconstruction_loss: 45.7392 - kl_loss: 11.5256 - val_loss: 28.0107 - val_reconstruction_loss: 19.1430 - val_kl_loss: 8.8677
# Epoch 36/300
# 662/662 [==============================] - 35s 52ms/step - loss: 56.8307 - reconstruction_loss: 45.4485 - kl_loss: 11.4899 - val_loss: 28.8624 - val_reconstruction_loss: 19.9987 - val_kl_loss: 8.8637
# Epoch 37/300
# 662/662 [==============================] - 35s 52ms/step - loss: 57.2497 - reconstruction_loss: 45.3897 - kl_loss: 11.4807 - val_loss: 27.4695 - val_reconstruction_loss: 18.6225 - val_kl_loss: 8.8470
# Epoch 38/300
# 662/662 [==============================] - 35s 52ms/step - loss: 56.2671 - reconstruction_loss: 44.5410 - kl_loss: 11.4838 - val_loss: 24.7156 - val_reconstruction_loss: 15.8259 - val_kl_loss: 8.8897
# Epoch 39/300
# 662/662 [==============================] - 34s 51ms/step - loss: 55.7600 - reconstruction_loss: 44.4698 - kl_loss: 11.4904 - val_loss: 24.7999 - val_reconstruction_loss: 15.9139 - val_kl_loss: 8.8860
# Epoch 40/300
# 662/662 [==============================] - 34s 51ms/step - loss: 56.2493 - reconstruction_loss: 44.4992 - kl_loss: 11.4910 - val_loss: 26.0379 - val_reconstruction_loss: 17.1468 - val_kl_loss: 8.8911
# Epoch 41/300
# 662/662 [==============================] - 34s 52ms/step - loss: 56.4597 - reconstruction_loss: 44.4618 - kl_loss: 11.5018 - val_loss: 25.1603 - val_reconstruction_loss: 16.2472 - val_kl_loss: 8.9131
# Epoch 42/300
# 662/662 [==============================] - 35s 52ms/step - loss: 55.1860 - reconstruction_loss: 44.3223 - kl_loss: 11.5036 - val_loss: 27.1640 - val_reconstruction_loss: 18.2592 - val_kl_loss: 8.9048
# Epoch 43/300
# 662/662 [==============================] - 35s 52ms/step - loss: 55.5066 - reconstruction_loss: 44.2263 - kl_loss: 11.4921 - val_loss: 25.6828 - val_reconstruction_loss: 16.7771 - val_kl_loss: 8.9056
# Epoch 44/300
# 662/662 [==============================] - 34s 51ms/step - loss: 56.3344 - reconstruction_loss: 43.7796 - kl_loss: 11.4968 - val_loss: 26.2467 - val_reconstruction_loss: 17.3485 - val_kl_loss: 8.8982
# Epoch 45/300
# 662/662 [==============================] - 34s 51ms/step - loss: 54.9688 - reconstruction_loss: 43.7301 - kl_loss: 11.4842 - val_loss: 26.9130 - val_reconstruction_loss: 18.0269 - val_kl_loss: 8.8861
# Epoch 46/300
# 662/662 [==============================] - 34s 51ms/step - loss: 55.3695 - reconstruction_loss: 43.8226 - kl_loss: 11.4700 - val_loss: 25.2228 - val_reconstruction_loss: 16.3400 - val_kl_loss: 8.8829
# Epoch 47/300
# 662/662 [==============================] - 35s 53ms/step - loss: 55.8562 - reconstruction_loss: 43.7381 - kl_loss: 11.4665 - val_loss: 25.4628 - val_reconstruction_loss: 16.5804 - val_kl_loss: 8.8825
# Epoch 48/300
# 662/662 [==============================] - 34s 51ms/step - loss: 54.8640 - reconstruction_loss: 43.6482 - kl_loss: 11.4588 - val_loss: 24.5645 - val_reconstruction_loss: 15.6940 - val_kl_loss: 8.8704
# Epoch 49/300
# 662/662 [==============================] - 34s 52ms/step - loss: 55.2112 - reconstruction_loss: 43.8226 - kl_loss: 11.4436 - val_loss: 26.3712 - val_reconstruction_loss: 17.5061 - val_kl_loss: 8.8651
# Epoch 50/300
# 662/662 [==============================] - 35s 52ms/step - loss: 55.7774 - reconstruction_loss: 43.7320 - kl_loss: 11.4482 - val_loss: 25.4442 - val_reconstruction_loss: 16.5831 - val_kl_loss: 8.8611
# Epoch 51/300
# 662/662 [==============================] - 35s 53ms/step - loss: 55.5259 - reconstruction_loss: 43.7224 - kl_loss: 11.4482 - val_loss: 25.8614 - val_reconstruction_loss: 16.9825 - val_kl_loss: 8.8789
# Epoch 52/300
# 662/662 [==============================] - 34s 51ms/step - loss: 54.9566 - reconstruction_loss: 43.7808 - kl_loss: 11.4599 - val_loss: 26.5299 - val_reconstruction_loss: 17.6272 - val_kl_loss: 8.9027
# Epoch 53/300
# 662/662 [==============================] - 34s 51ms/step - loss: 55.4657 - reconstruction_loss: 43.5742 - kl_loss: 11.4664 - val_loss: 25.1426 - val_reconstruction_loss: 16.2569 - val_kl_loss: 8.8857
# Epoch 54/300
# 662/662 [==============================] - 35s 52ms/step - loss: 54.6946 - reconstruction_loss: 43.4261 - kl_loss: 11.4582 - val_loss: 24.6256 - val_reconstruction_loss: 15.7358 - val_kl_loss: 8.8898
# Epoch 55/300
# 662/662 [==============================] - 34s 51ms/step - loss: 54.9288 - reconstruction_loss: 43.3153 - kl_loss: 11.4493 - val_loss: 25.3380 - val_reconstruction_loss: 16.4517 - val_kl_loss: 8.8863
# Epoch 56/300
# 662/662 [==============================] - 34s 52ms/step - loss: 54.0180 - reconstruction_loss: 43.3669 - kl_loss: 11.4468 - val_loss: 25.9461 - val_reconstruction_loss: 17.0604 - val_kl_loss: 8.8856
# Epoch 57/300
# 662/662 [==============================] - 34s 51ms/step - loss: 54.4405 - reconstruction_loss: 43.2564 - kl_loss: 11.4415 - val_loss: 26.4567 - val_reconstruction_loss: 17.5756 - val_kl_loss: 8.8811
# Epoch 58/300
# 662/662 [==============================] - 34s 51ms/step - loss: 55.2084 - reconstruction_loss: 43.3676 - kl_loss: 11.4401 - val_loss: 24.8530 - val_reconstruction_loss: 15.9633 - val_kl_loss: 8.8897
# Epoch 59/300
# 662/662 [==============================] - 34s 52ms/step - loss: 54.0390 - reconstruction_loss: 43.3475 - kl_loss: 11.4438 - val_loss: 25.5076 - val_reconstruction_loss: 16.6167 - val_kl_loss: 8.8909
# Epoch 60/300
# 662/662 [==============================] - 34s 51ms/step - loss: 54.8155 - reconstruction_loss: 43.1979 - kl_loss: 11.4453 - val_loss: 24.9321 - val_reconstruction_loss: 16.0422 - val_kl_loss: 8.8898
# Epoch 61/300
# 662/662 [==============================] - 34s 52ms/step - loss: 54.5194 - reconstruction_loss: 43.2721 - kl_loss: 11.4434 - val_loss: 26.5028 - val_reconstruction_loss: 17.6095 - val_kl_loss: 8.8933
# Epoch 62/300
# 662/662 [==============================] - 35s 52ms/step - loss: 54.8190 - reconstruction_loss: 43.1948 - kl_loss: 11.4419 - val_loss: 24.5863 - val_reconstruction_loss: 15.7014 - val_kl_loss: 8.8849
# Epoch 63/300
# 662/662 [==============================] - 35s 53ms/step - loss: 54.3020 - reconstruction_loss: 43.1638 - kl_loss: 11.4343 - val_loss: 25.1980 - val_reconstruction_loss: 16.3205 - val_kl_loss: 8.8775

# %% [markdown]
# ## Example of prediction on the test set

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(30,20))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()

# %%
_, _, encoded_data = encoder(X_test) 
predictions = decoder(encoded_data)

for l in range(M):
    # print(l)
    _, _, encoded_data = encoder(X_test) 
    reconstruction = decoder(encoded_data)
    predictions = predictions + reconstruction
    
predictions = predictions/M
print(predictions.shape)
# Out:
# (1921, 672, 3)

# %%
def inspect_multivariate_prediction(X, y, a, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(pred))

    figs, axs = plt.subplots(len(columns) + 1, 1, sharex=True, figsize=(17,10))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
           
    axs[len(columns)].plot(np.arange(len(X[0,:,i])), a[idx,:])
    axs[len(columns)].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope, ), a[idx,:])
    axs[len(columns)].set_title('Anomaly')
    plt.show()

# %%
# Plotting predictions
target_labels = X_test_raw.columns
inspect_multivariate_prediction(X_test, X_test, A_test, predictions, target_labels, window)

# %% [markdown]
# ## Computing reconstruction error

# %%
# Function used to create non-overlapped windows starting from the TRAINING set
def build_sequences_reconstruction(df, window, stride):
    dataset = []
    temp_df = df.copy().values
    padding_len = (len(df)-window)%stride

    for idx in np.arange(0,len(temp_df)-window+1,stride):
        dataset.append(temp_df[idx:idx+window])

    dataset = np.array(dataset)
    return dataset

# %%
# Non overlapped windows - Training set
X_train_non_overlapped_P1 = build_sequences_reconstruction(X_train_raw_P1, window=window, stride=window)
X_train_non_overlapped_P2 = build_sequences_reconstruction(X_train_raw_P2, window=window, stride=window)

X_train_non_overlapped = np.concatenate([X_train_non_overlapped_P1,X_train_non_overlapped_P2],axis=0)

X_train_non_overlapped.shape
# Out:
# (65, 672, 3)

# %%
# Overlapped windows - Test set
X_test_overlapped = build_sequences_reconstruction(X_test_raw, window=window, stride=stride)
X_test_overlapped.shape
# Out:
# (1921, 672, 3)

# %%
# Making predictions on non-overlapped windows of the training set
encoded_data = encoder(X_train_non_overlapped)[-1]
print(encoded_data.shape)
train_reconstructions = decoder(encoded_data)
print(train_reconstructions.shape)

for l in range(M-1):
    encoded_data = encoder(X_train_non_overlapped)[-1]
    train_prediction = decoder(encoded_data)
    train_reconstructions = train_prediction + train_reconstructions
    
train_reconstructions = train_reconstructions/M
print(train_reconstructions.shape)
# Out:
# (65, 10)
# (65, 672, 3)
# (65, 672, 3)

# %%
# Making predictions on overlapped windows of the test set
encoded_data = encoder(X_test_overlapped)[-1]
print(encoded_data.shape)
test_reconstructions = decoder(encoded_data)
print(test_reconstructions.shape)

for l in range(M-1):
    encoded_data = encoder(X_test_overlapped)[-1]
    test_prediction = decoder(encoded_data)
    test_reconstructions = test_prediction + test_reconstructions
    
test_reconstructions = test_reconstructions/M
print(test_reconstructions.shape)
# Out:
# (1921, 10)
# (1921, 672, 3)
# (1921, 672, 3)

# %%
# Computing reconstruction error - Test set (redundant data because of overlapping)
rec_error = np.abs(X_test_overlapped-test_reconstructions) # || True - Predicted ||
rec_error.shape
# Out:
# (1921, 672, 3)

# %%
# Function used to plot predictions (reconstructions) made on training data using the model
def inspect_multivariate_prediction_reconstruction(X, y, a, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(pred))
        print('Plotting sequence number: ' + str(idx))

    figs, axs = plt.subplots(3, 1, sharex=True, figsize=(17,7))
    for i, col in enumerate(columns[:4]):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].plot(np.arange(len(X[0,:,i]), len(X[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
    plt.show()

# %%
# Plotting reconstructions of the TRAINING set
inspect_multivariate_prediction_reconstruction(X_train_non_overlapped, X_train_non_overlapped, A_train, train_reconstructions, target_labels, window)
# Out:
# Plotting sequence number: 51

# %%
# Array that will contain reconstruction errors (floor by floor) - TRAINING SET
reconstruction_errors = np.empty(shape=(0, 2))

# Computing reconstruction errors
for i in range(X_train_non_overlapped.shape[0]):
    error = np.abs(X_train_non_overlapped[i]-train_reconstructions[i])
    error = error[:,:2] # Not interested in the day of the week
    reconstruction_errors = np.concatenate((reconstruction_errors,error), axis=0)
    
mean_error = np.mean(reconstruction_errors, axis = 0) # Mean reconstruction error
std_error = np.std(reconstruction_errors, axis = 0) # Std dev of the reconstruction error
max_error = np.max(reconstruction_errors, axis = 0) # Max error on the training set
  
print(reconstruction_errors.shape)
print(mean_error)
print(std_error)
print(max_error)
# Out:
# (43680, 2)
# [0.22473901 0.22488434]
# [0.21017746 0.20924707]
# [1.90331721 1.8813864 ]

# %%
# Array that will contain reconstruction errors (floor by floor) - TEST SET

reconstruction_test = np.empty(shape=(0, 2)) # Predictions made on the test set using the model
reconstruction_errors_test = np.empty(shape=(0, 2)) # Errors made in predicting the test set

# First window
i = 0
error = np.abs(X_test_overlapped[i]-test_reconstructions[i])
error = error[:,:2] # Not interested in the day of the week
reconstruction_errors_test = np.concatenate((reconstruction_errors_test,error), axis=0)
reconstruction_test = np.concatenate((reconstruction_test, test_reconstructions[i,:,:2]), axis=0)
print(reconstruction_errors_test.shape)
print(reconstruction_test.shape)

# For all the windows following the first one we need to consider only the last "stride" elements
for i in range(1,X_test_overlapped.shape[0]):
    error = np.abs(X_test_overlapped[i,-stride:,:]-test_reconstructions[i,-stride:,:])
    error = error[:,:2] # Not interested in the day of the week
    reconstruction_errors_test = np.concatenate((reconstruction_errors_test,error), axis=0)
    reconstruction_test = np.concatenate((reconstruction_test, test_reconstructions[i,-stride:,:2]), axis=0)
                                        
print(reconstruction_errors_test.shape)
print(reconstruction_test.shape)
# Out:
# (672, 2)
# (672, 2)
# (16032, 2)
# (16032, 2)

# %%
# Function used to predict anomalies
def predict_anomalies(reconstruction_errors, error_threshold):
    
    # Inizially we don't have predicted anomalies
    anomaly_predicted = np.zeros(shape=(X_test_raw.shape[0]))
    
    # First window
    i = 0 # We start from element 0 of the test set
    seq = reconstruction_errors[0] # We start from the first window of the test set 
    for sample in seq: 
        epsilon = sample[:2] - error_threshold # We check if the reconstruction error is greater than the threshold
        if any(x>0 for x in epsilon) == True:
            anomaly_predicted[i] = 1
        i = i+1
            
    # Sequences following the first one
    for s in range(1, reconstruction_errors.shape[0]):
        for k in range (reconstruction_errors.shape[1]-stride, reconstruction_errors.shape[1]): # k in [672-stride, 672]         
            epsilon = reconstruction_errors[s,k,:2] - error_threshold # We check if the reconstruction error is greater than the threshold
            if any(x>0 for x in epsilon) == True:
                anomaly_predicted[i] = 1
            i = i+1 

    return anomaly_predicted

# %%
seed = 42
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
tfp.random.sanitize_seed(seed)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([2083866985, -350068510], dtype=int32)>

# %%
Anomaly_Test
# Out:
#        Anomaly_Label
# 59808            0.0
# 59809            0.0
# 59810            0.0
# 59811            0.0
# 59812            0.0
# ...              ...
# 75835            0.0
# 75836            0.0
# 75837            0.0
# 75838            0.0
# 75839            0.0
#
# [16032 rows x 1 columns]

# %%
# Grid search threshold parameters

range_of_val = [x for x in np.arange(4, 7, 0.1)]
best_val = [0,0]
F1_MAX = 0

for i in range_of_val:
    for j in range_of_val:
        threshold_error_mean_std_TEMP = 0
        threshold_error_mean_std_TEMP = mean_error + [i,j]*std_error # mean + n*std_dev
        anomaly_predicted_mean_std_TEMP = 0
        anomaly_predicted_mean_std_TEMP = predict_anomalies(rec_error, threshold_error_mean_std_TEMP)
        f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted_mean_std_TEMP)
        if(f1>F1_MAX):
            F1_MAX = f1
            best_val = [i,j]
            print("best threshold parameters: " + str(best_val) + " best f1: " + str(F1_MAX))
            
threshold_error_mean_std = mean_error + [best_val[0],best_val[1]]*std_error # mean + n*std_dev
anomaly_predicted_mean_std = predict_anomalies(rec_error, threshold_error_mean_std)
                
threshold_error_max = max_error # Max error on the training set
anomaly_predicted_max = predict_anomalies(rec_error, threshold_error_max)

anomaly_predicted_mean_std.sum(), anomaly_predicted_max.sum(), anomaly_predicted_mean_std.shape, anomaly_predicted_max.shape, threshold_error_mean_std, threshold_error_max
# Out:
# best threshold parameters: [4.0, 4.0] best f1: 0.7097933513027853
# best threshold parameters: [4.1, 4.0] best f1: 0.7119565217391305
# best threshold parameters: [4.499999999999998, 4.0] best f1: 0.71260199456029
# best threshold parameters: [4.899999999999997, 4.0] best f1: 0.7138964577656676
# best threshold parameters: [4.9999999999999964, 4.0] best f1: 0.7145454545454546
# best threshold parameters: [5.199999999999996, 4.0] best f1: 0.7151956323930847
# best threshold parameters: [5.599999999999994, 4.0] best f1: 0.7164995442114859
# best threshold parameters: [5.799999999999994, 4.0] best f1: 0.7171532846715328
# best threshold parameters: [5.899999999999993, 4.0] best f1: 0.7178082191780822
# best threshold parameters: [6.299999999999992, 4.0] best f1: 0.7191216834400733
# best threshold parameters: [6.3999999999999915, 4.0] best f1: 0.7197802197802198
# best threshold parameters: [6.89999999999999, 4.0] best f1: 0.7211009174311926
# (547.0,
#  146.0,
#  (16032,),
#  (16032,),
#  array([1.67496347, 1.0618726 ]),
#  array([1.90331721, 1.8813864 ]))

# %%
padding_len = (len(X_test_raw)-window)%stride
size = X_test_raw.shape[0]-padding_len
X_test_raw = X_test_raw[:size]
X_test_raw.shape[1]
# Out:
# 3

# %%
# Adding predictions and predicted anomalies to X_test_raw
X_test_raw['Reconstr_1_Floor'] = reconstruction_test[:,0] # Prediction on floor 1
X_test_raw['Reconstr_2_Floor'] = reconstruction_test[:,1] # Prediction on floor 2
X_test_raw['Anomaly_Label_GT'] = Anomaly_Test # Ground truth anomalies
X_test_raw['Anomaly_Predicted_Mean_Std'] = anomaly_predicted_mean_std[:X_test_raw.shape[0]] # Anomalies predicted using mean and std dev
X_test_raw['Anomaly_Predicted_Max'] = anomaly_predicted_max[:X_test_raw.shape[0]] # Anomalies predicted using max error on the training set
X_test_raw['Error_1_Floor'] = reconstruction_errors_test[:,0] # Prediction error on floor 1
X_test_raw['Error_2_Floor'] = reconstruction_errors_test[:,1] # Prediction error on floor 2
X_test_raw.head()
# Out:
#        CB_First_Floor  CB_Second_Floor  Day_Of_The_Week  Reconstr_1_Floor  \
# 59808       -0.110053        -0.145436              0.0         -0.109183
# 59809       -0.110053        -0.145436              0.0         -0.468589
# 59810       -0.110053        -0.093767              0.0         -0.475113
# 59811       -0.161507        -0.145436              0.0         -0.361368
# 59812       -0.161507        -0.145436              0.0         -0.355391
#
#        Reconstr_2_Floor  Anomaly_Label_GT  Anomaly_Predicted_Mean_Std  \
# 59808         -0.109952               0.0                         0.0
# 59809         -0.473292               0.0                         0.0
# 59810         -0.474947               0.0                         0.0
# 59811         -0.361952               0.0                         0.0
# 59812         -0.351746               0.0                         0.0
#
#        Anomaly_Predicted_Max  Error_1_Floor  Error_2_Floor
# 59808                    0.0       0.000870       0.035485
# 59809                    0.0       0.358536       0.327856
# 59810                    0.0       0.365060       0.381180
# 59811                    0.0       0.199861       0.216515
# 59812                    0.0       0.193884       0.206310

# %%
# Function used to plot time series
def inspect_dataframe(df, columns):
    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(30,20))
    for i, col in enumerate(columns):
        axs[i].plot(df[col])
        axs[i].set_title(col)
    plt.show()

# %%
def inspect_multivariate_prediction(X, y, a_true, a_predicted_mean_std, a_predicted_max, pred, columns, error_1F, error_2F): 
   
    figs, axs = plt.subplots(7, 1, sharex=True, figsize=(17,17)) 
    for i, col in enumerate(columns[:2]): 
        axs[i].plot(np.arange(len(X[:,i])), X[:,i]) 
        axs[i].plot(np.arange(len(X[:,i]), len(X[:,i])*2), y[:,i], color='orange') 
        axs[i].plot(np.arange(len(X[:,i]), len(X[:,i])*2), pred[:,i], color='green') 
        axs[i].set_title(col) 
        
    axs[2].plot(np.arange(len(X[:,i])), error_1F) 
    axs[2].plot(np.arange(len(X[:,i]), len(X[:,i])*2), error_1F) 
    axs[2].set_title('error_1F') 
     
    axs[3].plot(np.arange(len(X[:,i])), error_2F) 
    axs[3].plot(np.arange(len(X[:,i]), len(X[:,i])*2), error_2F) 
    axs[3].set_title('error_2F') 
            
    axs[4].plot(np.arange(len(X[:,i])), a_true) 
    axs[4].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_true) 
    axs[4].set_title('Anomaly_True') 
    
    axs[5].plot(np.arange(len(X[:,i])), a_predicted_mean_std) 
    axs[5].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_predicted_mean_std) 
    axs[5].set_title('Anomaly_Predicted_Mean_Std_Dev')
    
    axs[6].plot(np.arange(len(X[:,i])), a_predicted_max) 
    axs[6].plot(np.arange(len(X[:,i]), len(X[:,i])*2), a_predicted_max) 
    axs[6].set_title('Anomaly_Predicted_Max') 
    plt.show()

# %%
# Plotting reconstructions for a check
import datetime as dt

i=89 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
# Plotting reconstructions for a check
import datetime as dt

i=94 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
# Plotting reconstructions for a check
import datetime as dt

i=99 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
# Plotting reconstructions for a check
import datetime as dt

i=104 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
# Plotting reconstructions for a check
import datetime as dt

i=109 # da 89 in poi
j=i+5

X = np.array(X_test_raw.loc[i*672:j*672][['CB_First_Floor', 'CB_Second_Floor']])
predictions = np.array(X_test_raw.loc[i*672:j*672][['Reconstr_1_Floor', 'Reconstr_2_Floor']])
anomaly_true = X_test_raw.loc[i*672:j*672]['Anomaly_Label_GT']
anomaly_prediction_mean_std_dev = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Mean_Std']
anomaly_prediction_max = X_test_raw.loc[i*672:j*672]['Anomaly_Predicted_Max']
error_1F = X_test_raw.loc[i*672:j*672]['Error_1_Floor']
error_2F = X_test_raw.loc[i*672:j*672]['Error_2_Floor']

# Plotting predictions
inspect_multivariate_prediction(X, X, anomaly_true, anomaly_prediction_mean_std_dev, anomaly_prediction_max, predictions, target_labels, error_1F, error_2F) # X = ABB_print

# %%
anomaly_predicted = anomaly_predicted_mean_std

# Compute the confusion matrix
cm = confusion_matrix(y_true=Anomaly_Test, y_pred=anomaly_predicted)

# Compute the classification metrics
accuracy = accuracy_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
precision = precision_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
recall = recall_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Accuracy: 0.981
# Precision: 0.7185
# Recall: 0.7238
# F1: 0.7211

# %%
anomaly_predicted = anomaly_predicted_max

# Compute the confusion matrix
cm = confusion_matrix(y_true=Anomaly_Test, y_pred=anomaly_predicted)

# Compute the classification metrics
accuracy = accuracy_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
precision = precision_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
recall = recall_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
f1 = f1_score(y_true=Anomaly_Test, y_pred=anomaly_predicted)
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Accuracy: 0.9749
# Precision: 0.9795
# Recall: 0.2634
# F1: 0.4151
